# %%
import pandas as pd 
import numpy as np 
from textblob import TextBlob
import matplotlib.pyplot as plt

import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()


import json, re
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import ToktokTokenizer


from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

from gensim.models.coherencemodel import CoherenceModel
from gensim import corpora
from gensim.corpora import Dictionary
from gensim.models import LdaModel
import gensim


import random
from wordcloud import WordCloud
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
#df = pd.read_excel('Resultados Touchpoint APP Personas del 1abr al 24 May.xlsx')
df = pd.read_excel('Touchpoint APP Personas 1 May al 8 Ago Prepago.xlsx')
df.head()
# Out:
#              StartDate                EndDate             Status  \
# 0      Fecha de inicio  Fecha de finalización  Tipo de respuesta
# 1  2021-05-01 00:01:09    2021-05-01 00:02:59         IP Address
# 2  2021-04-30 00:08:19    2021-04-30 00:10:59         IP Address
# 3  2021-04-30 00:10:51    2021-04-30 00:11:03         IP Address
# 4  2021-05-01 00:14:21    2021-05-01 00:15:37         IP Address
#
#          IPAddress  Progress   Duration (in seconds)    Finished  \
# 0     Dirección IP  Progreso  Duración (en segundos)  Finalizado
# 1    181.78.16.235       100                     110        True
# 2  191.156.153.227        38                     160       False
# 3    181.78.21.213         6                      11       False
# 4    181.53.12.201       100                      76        True
#
#                  RecordedDate         ResponseId          RecipientLastName  \
# 0            Fecha registrada    ID de respuesta  Apellido del destinatario
# 1  2021-05-01 00:02:59.714000  R_3ISGyOV01BzngPO                        NaN
# 2  2021-05-01 00:11:00.156000  R_22t2EpjmNZEoqFT                        NaN
# 3  2021-05-01 00:11:04.303000  R_2y9PPrBZcRkKcoZ                        NaN
# 4  2021-05-01 00:15:38.223000  R_udHanua3i8beZtT                        NaN
#
#    ...  Q15 - Topic Sentiment Label  Q15 - Topic Sentiment Score  \
# 0  ...  Q15 - Topic Sentiment Label  Q15 - Topic Sentiment Score
# 1  ...                          NaN                          NaN
# 2  ...                          NaN                          NaN
# 3  ...                          NaN                          NaN
# 4  ...                          NaN                          NaN
#
#    Q15 - Topics  Q20 - Parent Topics  Q20 - Sentiment Polarity  \
# 0  Q15 - Topics  Q20 - Parent Topics  Q20 - Sentiment Polarity
# 1           NaN                  NaN                       NaN
# 2           NaN                  NaN                       NaN
# 3           NaN                  NaN                       NaN
# 4           NaN                  NaN                       NaN
#
#    Q20 - Sentiment Score  Q20 - Sentiment  Q20 - Topic Sentiment Label  \
# 0  Q20 - Sentiment Score  Q20 - Sentiment  Q20 - Topic Sentiment Label
# 1                    NaN              NaN                          NaN
# 2                    NaN              NaN                          NaN
# 3                    NaN              NaN                          NaN
# 4                    NaN              NaN                          NaN
#
#    Q20 - Topic Sentiment Score  Q20 - Topics
# 0  Q20 - Topic Sentiment Score  Q20 - Topics
# 1                          NaN           NaN
# 2                          NaN           NaN
# 3                          NaN           NaN
# 4                          NaN           NaN
#
# [5 rows x 53 columns]

# %%
df = df.drop([0], axis=0)
df
# Out:
#                  StartDate              EndDate      Status        IPAddress  \
# 1      2021-05-01 00:01:09  2021-05-01 00:02:59  IP Address    181.78.16.235
# 2      2021-04-30 00:08:19  2021-04-30 00:10:59  IP Address  191.156.153.227
# 3      2021-04-30 00:10:51  2021-04-30 00:11:03  IP Address    181.78.21.213
# 4      2021-05-01 00:14:21  2021-05-01 00:15:37  IP Address    181.53.12.201
# 5      2021-04-30 00:16:38  2021-04-30 00:16:47  IP Address    181.55.225.31
# ...                    ...                  ...         ...              ...
# 48048  2021-08-08 23:39:41  2021-08-08 23:40:38  IP Address    181.51.32.254
# 48049  2021-08-08 23:40:25  2021-08-08 23:43:02  IP Address    181.78.12.127
# 48050  2021-08-08 23:40:35  2021-08-08 23:43:18  IP Address  191.102.221.222
# 48051  2021-08-08 23:46:54  2021-08-08 23:48:20  IP Address    181.58.38.190
# 48052  2021-08-08 23:48:15  2021-08-08 23:49:45  IP Address    179.32.64.221
#
#       Progress Duration (in seconds) Finished                RecordedDate  \
# 1          100                   110     True  2021-05-01 00:02:59.714000
# 2           38                   160    False  2021-05-01 00:11:00.156000
# 3            6                    11    False  2021-05-01 00:11:04.303000
# 4          100                    76     True  2021-05-01 00:15:38.223000
# 5            6                     8    False  2021-05-01 00:16:48.490000
# ...        ...                   ...      ...                         ...
# 48048      100                    56     True  2021-08-08 23:40:38.430000
# 48049      100                   157     True  2021-08-08 23:43:03.328000
# 48050      100                   163     True  2021-08-08 23:43:19.277000
# 48051      100                    85     True  2021-08-08 23:48:20.431000
# 48052      100                    90     True  2021-08-08 23:49:45.987000
#
#               ResponseId RecipientLastName  ... Q15 - Topic Sentiment Label  \
# 1      R_3ISGyOV01BzngPO               NaN  ...                         NaN
# 2      R_22t2EpjmNZEoqFT               NaN  ...                         NaN
# 3      R_2y9PPrBZcRkKcoZ               NaN  ...                         NaN
# 4      R_udHanua3i8beZtT               NaN  ...                         NaN
# 5      R_pi1N5OEgj4shabD               NaN  ...                         NaN
# ...                  ...               ...  ...                         ...
# 48048  R_sToi9iywAO42BRn               NaN  ...                         NaN
# 48049  R_3kugDTodOoTWqZe               NaN  ...                         NaN
# 48050  R_2YRIKXkrkI4ZEKr               NaN  ...                         NaN
# 48051  R_1fZBz7zYj4eBFWA               NaN  ...                         NaN
# 48052  R_1ffKZbTcrdQb1j5               NaN  ...                         NaN
#
#       Q15 - Topic Sentiment Score Q15 - Topics Q20 - Parent Topics  \
# 1                             NaN          NaN                 NaN
# 2                             NaN          NaN                 NaN
# 3                             NaN          NaN                 NaN
# 4                             NaN          NaN                 NaN
# 5                             NaN          NaN                 NaN
# ...                           ...          ...                 ...
# 48048                         NaN          NaN                 NaN
# 48049                         NaN          NaN                 NaN
# 48050                         NaN      Unknown                 NaN
# 48051                         NaN          NaN                 NaN
# 48052                         NaN      Unknown                 NaN
#
#       Q20 - Sentiment Polarity Q20 - Sentiment Score Q20 - Sentiment  \
# 1                          NaN                   NaN             NaN
# 2                          NaN                   NaN             NaN
# 3                          NaN                   NaN             NaN
# 4                          NaN                   NaN             NaN
# 5                          NaN                   NaN             NaN
# ...                        ...                   ...             ...
# 48048                      NaN                   NaN             NaN
# 48049                      NaN                   NaN             NaN
# 48050                      NaN                   NaN             NaN
# 48051                      NaN                   NaN             NaN
# 48052                      NaN                   NaN             NaN
#
#       Q20 - Topic Sentiment Label Q20 - Topic Sentiment Score Q20 - Topics
# 1                             NaN                         NaN          NaN
# 2                             NaN                         NaN          NaN
# 3                             NaN                         NaN          NaN
# 4                             NaN                         NaN          NaN
# 5                             NaN                         NaN          NaN
# ...                           ...                         ...          ...
# 48048                         NaN                         NaN          NaN
# 48049                         NaN                         NaN          NaN
# 48050                         NaN                         NaN          NaN
# 48051                         NaN                         NaN          NaN
# 48052                         NaN                         NaN          NaN
#
# [48052 rows x 53 columns]

# %%
df.Q2_NPS_GROUP.value_counts()
# Out:
# Promotor     25789
# Detractor     9377
# Pasivo        8274
# Name: Q2_NPS_GROUP, dtype: int64

# %%
A = df.Q2_NPS_GROUP.value_counts()
indices = A.index
plt.pie(A, labels=indices, autopct="%0.1f %%")
plt.axis("equal")
plt.show()

# %%
dfc = df[df['Q2_NPS_GROUP']!='Promotor']
dfc
# Out:
#                  StartDate              EndDate      Status        IPAddress  \
# 4      2021-05-01 00:14:21  2021-05-01 00:15:37  IP Address    181.53.12.201
# 9      2021-05-01 00:56:56  2021-05-01 00:58:36  IP Address    191.156.52.30
# 10     2021-05-01 01:11:12  2021-05-01 01:13:28  IP Address     190.26.155.7
# 11     2021-05-01 01:15:49  2021-05-01 01:21:26  IP Address    186.29.191.43
# 13     2021-05-01 01:31:59  2021-05-01 01:35:12  IP Address    191.156.2.216
# ...                    ...                  ...         ...              ...
# 48043  2021-08-08 23:06:19  2021-08-08 23:08:27  IP Address     186.84.91.69
# 48048  2021-08-08 23:39:41  2021-08-08 23:40:38  IP Address    181.51.32.254
# 48049  2021-08-08 23:40:25  2021-08-08 23:43:02  IP Address    181.78.12.127
# 48050  2021-08-08 23:40:35  2021-08-08 23:43:18  IP Address  191.102.221.222
# 48052  2021-08-08 23:48:15  2021-08-08 23:49:45  IP Address    179.32.64.221
#
#       Progress Duration (in seconds) Finished                RecordedDate  \
# 4          100                    76     True  2021-05-01 00:15:38.223000
# 9          100                   100     True  2021-05-01 00:58:37.141000
# 10         100                   136     True  2021-05-01 01:13:29.173000
# 11         100                   336     True  2021-05-01 01:21:26.392000
# 13         100                   193     True  2021-05-01 01:35:12.335000
# ...        ...                   ...      ...                         ...
# 48043      100                   127     True  2021-08-08 23:08:27.483000
# 48048      100                    56     True  2021-08-08 23:40:38.430000
# 48049      100                   157     True  2021-08-08 23:43:03.328000
# 48050      100                   163     True  2021-08-08 23:43:19.277000
# 48052      100                    90     True  2021-08-08 23:49:45.987000
#
#               ResponseId RecipientLastName  ... Q15 - Topic Sentiment Label  \
# 4      R_udHanua3i8beZtT               NaN  ...                         NaN
# 9      R_XjMcEuP3zshnpF7               NaN  ...                         NaN
# 10     R_x5YL4kva6EbeuWJ               NaN  ...                         NaN
# 11     R_3ltBuR7i97QbFAM               NaN  ...                         NaN
# 13     R_1laRSYqAGwFA04C               NaN  ...                         NaN
# ...                  ...               ...  ...                         ...
# 48043  R_3qlYjnE8E36TyLC               NaN  ...                         NaN
# 48048  R_sToi9iywAO42BRn               NaN  ...                         NaN
# 48049  R_3kugDTodOoTWqZe               NaN  ...                         NaN
# 48050  R_2YRIKXkrkI4ZEKr               NaN  ...                         NaN
# 48052  R_1ffKZbTcrdQb1j5               NaN  ...                         NaN
#
#       Q15 - Topic Sentiment Score Q15 - Topics Q20 - Parent Topics  \
# 4                             NaN          NaN                 NaN
# 9                             NaN          NaN                 NaN
# 10                            NaN      Unknown                 NaN
# 11                            NaN      Unknown                 NaN
# 13                            NaN      Unknown                 NaN
# ...                           ...          ...                 ...
# 48043                         NaN      Unknown                 NaN
# 48048                         NaN          NaN                 NaN
# 48049                         NaN          NaN                 NaN
# 48050                         NaN      Unknown                 NaN
# 48052                         NaN      Unknown                 NaN
#
#       Q20 - Sentiment Polarity Q20 - Sentiment Score Q20 - Sentiment  \
# 4                          NaN                   NaN             NaN
# 9                            0                     5        Positive
# 10                         NaN                   NaN             NaN
# 11                         NaN                   NaN             NaN
# 13                         NaN                   NaN             NaN
# ...                        ...                   ...             ...
# 48043                      NaN                   NaN             NaN
# 48048                      NaN                   NaN             NaN
# 48049                      NaN                   NaN             NaN
# 48050                      NaN                   NaN             NaN
# 48052                      NaN                   NaN             NaN
#
#       Q20 - Topic Sentiment Label Q20 - Topic Sentiment Score Q20 - Topics
# 4                             NaN                         NaN          NaN
# 9                             NaN                         NaN      Unknown
# 10                            NaN                         NaN          NaN
# 11                            NaN                         NaN          NaN
# 13                            NaN                         NaN          NaN
# ...                           ...                         ...          ...
# 48043                         NaN                         NaN          NaN
# 48048                         NaN                         NaN          NaN
# 48049                         NaN                         NaN          NaN
# 48050                         NaN                         NaN          NaN
# 48052                         NaN                         NaN          NaN
#
# [22263 rows x 53 columns]

# %%
dfc = dfc[['Q4', 'Q12', 'Q15', 'Q18', 'Q20']]
dfc
# Out:
#                                                       Q4  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10                                                   NaN
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13                                                   NaN
# ...                                                  ...
# 48043                                                NaN
# 48048                                                NaN
# 48049                                                NaN
# 48050                                                NaN
# 48052                                                NaN
#
#                                                     Q12  \
# 4                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 13                                                  NaN
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048                                               NaN
# 48049                                               NaN
# 48050                                               NaN
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4                                                    NaN
# 9                                                    NaN
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048                                                NaN
# 48049                                                NaN
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20
# 4                                                    NaN              NaN
# 9                                                    NaN  Me parece bien
# 10                                                   NaN              NaN
# 11                                                   NaN              NaN
# 13                                                  Nada              NaN
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...              NaN
# 48048                                                NaN              NaN
# 48049                                                NaN              NaN
# 48050                       No lo entendí bien gracias 😊              NaN
# 48052                                                NaN              NaN
#
# [22263 rows x 5 columns]

# %%
dfc = dfc.fillna('')
dfc
# Out:
#                                                       Q4  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                                     Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
# [22263 rows x 5 columns]

# %%
def limpiar_texto(texto):
    """
    Función para realizar la limpieza de un texto dado.
    """
    # Eliminamos los caracteres especiales
    texto = re.sub(r'\W', ' ', str(texto))
    # Eliminado las palabras que tengo un solo caracter
    texto = re.sub(r'\s+[a-zA-Z]\s+', ' ', texto)
    # Sustituir los espacios en blanco en uno solo
    texto = re.sub(r'\s+', ' ', texto, flags=re.I)
    # Convertimos textos a minusculas
    texto = texto.lower()
    return texto

# %%
dfc["Tokens_Q4"] =  dfc.Q4.apply(limpiar_texto)
dfc["Tokens_Q12"] =  dfc.Q12.apply(limpiar_texto)
dfc["Tokens_Q15"] =  dfc.Q15.apply(limpiar_texto)
dfc["Tokens_Q18"] =  dfc.Q18.apply(limpiar_texto)
dfc["Tokens_Q20"] =  dfc.Q20.apply(limpiar_texto)
dfc
# Out:
#                                                       Q4  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                                     Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                Tokens_Q4  \
# 4                                                ninguna
# 9      cuando me quedo sin saldo no carga la app para...
# 10
# 11     tengo bastante tiempo con ustedes me le subier...
# 13
# ...                                                  ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                            Tokens_Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                               ...
# 48043  antes era mas facil encontrar hacer las cosas
# 48048
# 48049
# 48050
# 48052                         es un poco lenta la app
#
#                                               Tokens_Q15  \
# 4
# 9
# 10                                            mala señal
# 11     me cambié un mes otro operador me regrese de n...
# 13     se demora para cargar después dice lo sienten ...
# ...                                                  ...
# 48043  ya no se puede pagar la factura tampoco se pue...
# 48048
# 48049
# 48050                                                bn
# 48052          se demora un poco al entrar la aplicación
#
#                                               Tokens_Q18       Tokens_Q20
# 4
# 9                                                         me parece bien
# 10
# 11
# 13                                                  nada
# ...                                                  ...              ...
# 48043  no pude ver el consumo de mis datos tampoco pa...
# 48048
# 48049
# 48050                        no lo entendí bien gracias
# 48052
#
# [22263 rows x 10 columns]

# %%
tokenizer = ToktokTokenizer() 
dfc["Tokens_Q4"] = dfc.Tokens_Q4.apply(tokenizer.tokenize)
dfc["Tokens_Q12"] = dfc.Tokens_Q12.apply(tokenizer.tokenize)
dfc["Tokens_Q15"] = dfc.Tokens_Q15.apply(tokenizer.tokenize)
dfc["Tokens_Q18"] = dfc.Tokens_Q18.apply(tokenizer.tokenize)
dfc["Tokens_Q20"] = dfc.Tokens_Q20.apply(tokenizer.tokenize)
dfc.head()
# Out:
#                                                    Q4 Q12  \
# 4                                             Ninguna
# 9   Cuando me quedo sin saldo no carga la app para...
# 10
# 11  Tengo bastante tiempo con ustedes y me le subi...
# 13
#
#                                                   Q15    Q18              Q20  \
# 4
# 9                                                             Me parece bien
# 10                                         Mala señal
# 11  Me cambié x un mes a otro operador y me regres...
# 13  Se demora para cargar y después dice lo siente...   Nada
#
#                                             Tokens_Q4 Tokens_Q12  \
# 4                                           [ninguna]         []
# 9   [cuando, me, quedo, sin, saldo, no, carga, la,...         []
# 10                                                 []         []
# 11  [tengo, bastante, tiempo, con, ustedes, me, le...         []
# 13                                                 []         []
#
#                                            Tokens_Q15 Tokens_Q18  \
# 4                                                  []         []
# 9                                                  []         []
# 10                                      [mala, señal]         []
# 11  [me, cambié, un, mes, otro, operador, me, regr...         []
# 13  [se, demora, para, cargar, después, dice, lo, ...     [nada]
#
#             Tokens_Q20
# 4                   []
# 9   [me, parece, bien]
# 10                  []
# 11                  []
# 13                  []

# %%
import nltk
nltk.download('stopwords')

STOPWORDS = set(stopwords.words("spanish"))

def filtrar_stopword_digitos(tokens):
    """
    Filtra stopwords y digitos de una lista de tokens.
    """
    return [token for token in tokens if token not in STOPWORDS 
            and not token.isdigit()]

dfc["Tokens_Q4"] = dfc.Tokens_Q4.apply(filtrar_stopword_digitos)
dfc["Tokens_Q12"] = dfc.Tokens_Q12.apply(filtrar_stopword_digitos)
dfc["Tokens_Q15"] = dfc.Tokens_Q15.apply(filtrar_stopword_digitos)
dfc["Tokens_Q18"] = dfc.Tokens_Q18.apply(filtrar_stopword_digitos)
dfc["Tokens_Q20"] = dfc.Tokens_Q20.apply(filtrar_stopword_digitos)
dfc.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\CristhianJohnatanIzq\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                    Q4 Q12  \
# 4                                             Ninguna
# 9   Cuando me quedo sin saldo no carga la app para...
# 10
# 11  Tengo bastante tiempo con ustedes y me le subi...
# 13
#
#                                                   Q15    Q18              Q20  \
# 4
# 9                                                             Me parece bien
# 10                                         Mala señal
# 11  Me cambié x un mes a otro operador y me regres...
# 13  Se demora para cargar y después dice lo siente...   Nada
#
#                                             Tokens_Q4 Tokens_Q12  \
# 4                                           [ninguna]         []
# 9    [quedo, saldo, carga, app, poder, recargar, vez]         []
# 10                                                 []         []
# 11  [bastante, tiempo, ustedes, subieron, plan, li...         []
# 13                                                 []         []
#
#                                            Tokens_Q15 Tokens_Q18  \
# 4                                                  []         []
# 9                                                  []         []
# 10                                      [mala, señal]         []
# 11  [cambié, mes, operador, regrese, nuevo, subier...         []
# 13  [demora, cargar, después, dice, sienten, traba...         []
#
#         Tokens_Q20
# 4               []
# 9   [parece, bien]
# 10              []
# 11              []
# 13              []

# %%
stemmer = SnowballStemmer("spanish")

def stem_palabras(tokens):
    """
    Reduce cada palabra de una lista dada a su raíz.
    """
    return [stemmer.stem(token) for token in tokens]

dfc["Tokens_Q4"] = dfc.Tokens_Q4.apply(stem_palabras)
dfc["Tokens_Q12"] = dfc.Tokens_Q12.apply(stem_palabras)
dfc["Tokens_Q15"] = dfc.Tokens_Q15.apply(stem_palabras)
dfc["Tokens_Q18"] = dfc.Tokens_Q18.apply(stem_palabras)
dfc["Tokens_Q20"] = dfc.Tokens_Q20.apply(stem_palabras)
dfc.head()
# Out:
#                                                    Q4 Q12  \
# 4                                             Ninguna
# 9   Cuando me quedo sin saldo no carga la app para...
# 10
# 11  Tengo bastante tiempo con ustedes y me le subi...
# 13
#
#                                                   Q15    Q18              Q20  \
# 4
# 9                                                             Me parece bien
# 10                                         Mala señal
# 11  Me cambié x un mes a otro operador y me regres...
# 13  Se demora para cargar y después dice lo siente...   Nada
#
#                                     Tokens_Q4 Tokens_Q12  \
# 4                                    [ningun]         []
# 9   [qued, sald, carg, app, pod, recarg, vez]         []
# 10                                         []         []
# 11   [bastant, tiemp, usted, sub, plan, line]         []
# 13                                         []         []
#
#                                            Tokens_Q15 Tokens_Q18  \
# 4                                                  []         []
# 9                                                  []         []
# 10                                       [mal, señal]         []
# 11  [cambi, mes, oper, regres, nuev, sub, mil, pes...         []
# 13  [demor, carg, despues, dic, sient, trabaj, ser...         []
#
#        Tokens_Q20
# 4              []
# 9   [parec, bien]
# 10             []
# 11             []
# 13             []

# %%
list_Q4 = dfc["Tokens_Q4"].tolist()
list_Q12 = dfc["Tokens_Q12"].tolist()
list_Q15 = dfc["Tokens_Q15"].tolist()
list_Q18 = dfc["Tokens_Q18"].tolist()
list_Q20 = dfc["Tokens_Q20"].tolist()

list_Q4 = [x for x in list_Q4 if x!= []]
list_Q12 = [x for x in list_Q12 if x!= []]
list_Q15 = [x for x in list_Q15 if x!= []]
list_Q18 = [x for x in list_Q18 if x!= []]
list_Q20 = [x for x in list_Q20 if x!= []]

# %%
#list_Q15

# %%
Lista_general = list_Q4+list_Q12+list_Q15+list_Q18
#print(Lista_general)

# %%
bigram = gensim.models.Phrases(Lista_general, min_count=5, threshold=10) 
trigram = gensim.models.Phrases(bigram[Lista_general], threshold=10)  


bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

print(trigram_mod[bigram_mod[Lista_general[15]]])

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]
# Out:
# ['mal', 'servici']

# %%
bigram

# %%
data_words_bigrams = make_bigrams(Lista_general)

# %%
diccionario = Dictionary(data_words_bigrams)
print(f'Número de tokens: {len(diccionario)}')
# Out:
# Número de tokens: 4664

# %%
print(diccionario)
# Out:
# Dictionary(4664 unique tokens: ['ningun', 'app', 'carg', 'pod', 'qued']...)

# %%
diccionario.filter_extremes(no_below=2, no_above = 0.9)
print(f'Número de tokens: {len(diccionario)}')
# Out:
# Número de tokens: 2197

# %%
print(diccionario)
# Out:
# Dictionary(2197 unique tokens: ['ningun', 'app', 'carg', 'pod', 'qued']...)

# %%
corpus = [diccionario.doc2bow(noticia) for noticia in data_words_bigrams]
# Mostramos el BOW de una noticia
print(corpus[6])
# Out:
# [(23, 1)]

# %%
lda = LdaModel(corpus=corpus, id2word=diccionario, 
               num_topics=9, random_state=35, 
               chunksize=1000, iterations=200, passes=40, alpha='auto')

# %%
topicos = lda.print_topics(num_words=5, num_topics=20)
for topico in topicos:
    print(topico)
# Out:
# (0, '0.120*"dat" + 0.113*"internet" + 0.103*"mal" + 0.080*"lent" + 0.068*"señal"')
# (1, '0.080*"sald" + 0.061*"activ" + 0.045*"paquet" + 0.031*"revis" + 0.027*"dias"')
# (2, '0.105*"hac" + 0.088*"recarg" + 0.054*"pod" + 0.046*"realiz" + 0.030*"wifi"')
# (3, '0.105*"funcion" + 0.058*"nunc" + 0.038*"pas" + 0.034*"acced" + 0.026*"facil"')
# (4, '0.154*"pud" + 0.121*"registr" + 0.098*"equip" + 0.064*"compr" + 0.041*"ningun"')
# (5, '0.102*"dej" + 0.100*"pued" + 0.086*"app" + 0.078*"ver" + 0.069*"ingres"')
# (6, '0.202*"pag" + 0.150*"factur" + 0.126*"servici" + 0.035*"sirv" + 0.031*"sal"')
# (7, '0.068*"plan" + 0.052*"clar" + 0.048*"consult" + 0.042*"cuent" + 0.037*"clar_hog"')
# (8, '0.107*"aplic" + 0.070*"llam" + 0.053*"carg" + 0.046*"telefon" + 0.044*"asesor"')

# %%
import pyLDAvis.gensim_models

lda_display = pyLDAvis.gensim_models.prepare(lda, corpus, diccionario, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el839215346104294242188433082"></div>
# <script type="text/javascript">
#
# var ldavis_el839215346104294242188433082_data = {"mdsDat": {"x": [-0.04262665930460912, -0.04419990548131446, -0.04891502316379396, -0.04378044623859434, -0.04042258981730785, 0.43896334579417345, -0.03711341624569823, -0.13835786410056888, -0.043547441442286686], "y": [-0.06071498060870627, -0.054217364510713434, -0.10705077183728243, -0.05228662865651983, -0.04982930786521908, 0.0829853797307022, -0.12195192931013592, 0.4183848697604578, -0.05531926670258278], "topics": [1, 2, 3, 4, 5, 6, 7, 8, 9], "cluster": [1, 1, 1, 1, 1, 1, 1, 1, 1], "Freq": [9.391546060096644, 6.668616058563511, 12.11281846314274, 7.2644443011432696, 7.290215284801299, 16.737508977196853, 12.782887993112265, 19.6951751176286, 8.05678774431482]}, "tinfo": {"Term": ["pag", "factur", "servici", "dej", "pued", "pud", "hac", "dat", "app", "internet", "ver", "registr", "mal", "recarg", "aplic", "plan", "ingres", "funcion", "equip", "lent", "clar", "consult", "se\u00f1al", "sald", "llam", "pod", "cuent", "numer", "compr", "dic", "dat", "internet", "mal", "lent", "se\u00f1al", "pesim", "respuest", "mejor", "cae", "conexion", "buen", "red", "contrat", "pon", "acces", "tan", "descarg_factur", "cobertur", "cupon", "va", "obten", "cumpl", "part", "voz", "informacion", "demasi", "avec", "caid", "brind", "television", "sald", "activ", "paquet", "revis", "dias", "cuant", "consum_dat", "abrir", "logr", "minut", "ten", "dos", "com", "referent", "bien", "anterior", "falt", "veo", "mas", "hoy", "aun", "clav", "quit", "rob", "comunic_asesor", "entiend", "q", "compart", "parec", "vari", "hac", "recarg", "pod", "realiz", "wifi", "solucion", "mir", "compr_paquet", "encuentr", "siempr", "intent", "cambi_clav", "medi", "tampoc", "comunic", "trat", "oper", "dispon", "moment", "proces", "corre", "hic", "toc", "ped", "voy", "llev", "pse", "clar_play", "ser", "casi", "funcion", "nunc", "pas", "acced", "facil", "clar_vide", "da", "quer", "se", "abre", "prepag", "aplicacion", "naveg", "asi", "gig", "recib", "pes", "sim", "solucion_problem", "dese", "gestion", "utiliz", "promocion", "vez", "agreg_numer", "cad", "uso", "present", "dificil", "total", "pud", "registr", "equip", "compr", "ningun", "busc", "verific", "respond", "adquir", "pagin", "fij", "tiend", "sac", "solicitud", "inici", "netflix", "dij", "trasl", "plataform", "soport", "ultim", "primer", "continu", "qued_carg", "credit", "inici_sesion", "imei", "mierd", "cel", "plan_postpag", "dej", "pued", "app", "ver", "ingres", "numer", "dic", "permit", "eleg", "actualiz", "entrar", "famili_amig", "consum", "nuev", "product", "benefici", "cambi_numer", "amig", "pid", "averigu", "hor", "asoci", "inscrib", "famili", "bloque", "contact", "asoci_cuent", "agreg", "tv", "ademas", "pag", "factur", "servici", "sirv", "sal", "sab", "tecnic", "client", "deb", "equip_financi", "lleg", "usted", "dia", "habl_asesor", "detall", "cos", "quej", "report", "envi", "despues", "registr_imei", "cuot", "financi", "sig", "complic", "porqu", "personal", "peor", "ver_detall", "manej", "plan", "clar", "consult", "cuent", "clar_hog", "celul", "aparec", "necesit", "hog", "inform", "si", "line", "opcion", "quier", "cambi", "cancel", "movil", "sol", "encontr", "cobr", "mes", "qued", "error", "solicit", "valor", "posibl", "nombr", "muestr", "ofrec", "dan", "aplic", "llam", "carg", "telefon", "asesor", "conect", "demor", "fall", "vec", "contest", "problem", "tiemp", "chat", "comun", "atencion", "esper", "cas", "much", "pregunt", "rap", "ayud", "habl", "cort", "atiend", "baj", "quis", "dan_solucion", "preci", "ocasion", "lin"], "Freq": [1836.0, 1365.0, 1145.0, 1210.0, 1184.0, 798.0, 902.0, 802.0, 1024.0, 754.0, 928.0, 629.0, 684.0, 759.0, 615.0, 944.0, 816.0, 544.0, 510.0, 532.0, 723.0, 669.0, 455.0, 381.0, 403.0, 462.0, 581.0, 503.0, 329.0, 474.0, 801.2686606291877, 753.5725262113418, 683.4614892218985, 531.5433055097906, 454.4334793918122, 309.10371503756124, 144.97545344886896, 126.81680221748033, 114.54470440884282, 109.3211706361631, 102.31761886366682, 100.96 ...

# %%
lda_5 = LdaModel(corpus=corpus, id2word=diccionario, 
               num_topics=5, random_state=35, 
               chunksize=1000, iterations=200, passes=40, alpha='auto')

# %%
import pyLDAvis.gensim_models

lda_display = pyLDAvis.gensim_models.prepare(lda_5, corpus, diccionario, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1612425092840396964533576297"></div>
# <script type="text/javascript">
#
# var ldavis_el1612425092840396964533576297_data = {"mdsDat": {"x": [-0.11439947837138488, -0.13650359663584818, 0.4178245418341275, -0.07418641518077804, -0.09273505164611635], "y": [0.20124556789813894, -0.37447472187778674, -0.025169373799903798, 0.044214646421755655, 0.15418388135779568], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [17.31208975982463, 17.64943570157872, 40.02999836774987, 11.426260378568626, 13.582215792278152]}, "tinfo": {"Term": ["pag", "factur", "servici", "pud", "ver", "registr", "cuent", "internet", "dej", "mal", "pued", "equip", "numer", "app", "hog", "lent", "line", "aparec", "plan", "hac", "ingres", "se\u00f1al", "inform", "llam", "recarg", "movil", "dat", "clar", "eleg", "carg", "servici", "internet", "mal", "lent", "se\u00f1al", "llam", "sirv", "pesim", "asesor", "tecnic", "conect", "client", "respuest", "contest", "mejor", "usted", "chat", "cae", "comunic", "conexion", "ofrec", "buen", "red", "referent", "atencion", "contrat", "falt", "contact", "usuari", "cas", "pag", "factur", "ver", "sald", "activ", "consum", "sab", "paquet", "cobr", "pas", "equip_financi", "lleg", "revis", "mes", "qued", "dias", "cuant", "valor", "muestr", "minut", "mism", "hor", "dos", "ahor", "com", "bien", "anterior", "dia", "naveg", "habl_asesor", "dej", "pued", "app", "plan", "hac", "ingres", "recarg", "clar", "consult", "dat", "aplic", "clar_hog", "funcion", "dic", "celul", "pod", "necesit", "si", "realiz", "opcion", "permit", "compr", "cambi", "quier", "cancel", "entrar", "sal", "nunc", "wifi", "solucion", "cuent", "hog", "line", "movil", "carg", "product", "demor", "fall", "acced", "solicit", "facil", "respond", "adquir", "clar_vide", "abrir", "dan", "averigu", "abre", "asoci", "prepag", "pospag", "bloque", "pregunt", "da_opcion", "solucion_problem", "despues", "atiend", "baj", "vez", "comunic_asesor", "pud", "registr", "equip", "numer", "aparec", "inform", "eleg", "actualiz", "famili_amig", "telefon", "ningun", "nuev", "error", "da", "pid", "se", "fij", "tiend", "comun", "famili", "corre", "asoci_cuent", "detall", "bloqu", "much", "agreg", "acces", "rap", "tv", "inici"], "Freq": [1776.0, 1321.0, 1233.0, 835.0, 906.0, 659.0, 596.0, 734.0, 1288.0, 665.0, 1260.0, 534.0, 496.0, 1089.0, 435.0, 518.0, 409.0, 443.0, 966.0, 908.0, 868.0, 443.0, 386.0, 394.0, 765.0, 317.0, 764.0, 739.0, 324.0, 291.0, 1232.416339100518, 733.295081736221, 665.082454614847, 517.2663912407345, 442.2431693595665, 394.0633542569723, 342.6863584155836, 300.83854534383283, 245.83776513292196, 189.99049663912385, 190.91437336170387, 183.7557080409547, 141.1394475651549, 132.22942954456332, 123.47539026494103, 117.83341703138203, 114.99497480588613, 111.53578824183388, 110.90020949744378, 106.4460875754598, 105.66094001854705, 99.63878935029551, 98.31294143630424, 89.76583410565195, 86.21146010416659, 84.33467884018373, 80.62881877079211, 80.90609968446434, 79.98592011704193, 78.47505419695774, 1775.9369072354282, 1320.621186198101, 906.1031760441707, 361.993097549449, 274.94307379880416, 247.34537602126653, 238.8321453298385, 204.9306439862484, 168.14113142990524, 168.23678505175585, 148.2887047422356, 139.1609429987281, 138.69307227596641, 137.19932608606686, 136.2858147429743, 120.29190369265797, 119.82411465531203, 116.4009005985239, 101.43542060192408, 98.40981614100214, 88.0671530436242, 87.32674476586429, 85.29018148424669, 84.81473735650988, 81.40854303956183, 79.59180688108945, 78.87302189981473, 72.92842994955043, 72.59075994483169, 72.05942548869994, 1287.308658946335, 1259.457340774037, 1088.6639845032541, 965.6118431385847, 908.0770698905235, 867.3832723805916, 764.7342716944964, 738.7996782787704, 684.0927224829487, 763.3429656049703, 589.2606875087225, 533.4309576501653, 507.3341228265715, 504.0218572944605, 479.5719977284194, 464.84963540252534, 443.903925578553, 408.3181122044865, 401.99479964971704, 396.74725614294016, 377.7610678710573, 371.5687659148108, 365.646186990796, 365.7982916190206, 318.83752934507777, 313. ...

# %%
lda_4 = LdaModel(corpus=corpus, id2word=diccionario, 
               num_topics=4, random_state=35, 
               chunksize=1000, iterations=200, passes=40, alpha='auto')

# %%
import pyLDAvis.gensim_models

lda_display = pyLDAvis.gensim_models.prepare(lda_4, corpus, diccionario, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el839215346104914242559797890"></div>
# <script type="text/javascript">
#
# var ldavis_el839215346104914242559797890_data = {"mdsDat": {"x": [0.16211632741763815, 0.1263134258785919, -0.40275346759201475, 0.11432371429578454], "y": [-0.3464386542268537, 0.18055911079441297, -0.02783405923522098, 0.19371360266766172], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [18.948963872556725, 10.776294423088165, 58.2344524642225, 12.040289240132617]}, "tinfo": {"Term": ["servici", "internet", "mal", "pag", "lent", "se\u00f1al", "factur", "cancel", "llam", "dej", "pued", "activ", "sirv", "app", "sab", "pesim", "ver", "ningun", "plan", "paquet", "hac", "pud", "solucion", "ingres", "asesor", "tecnic", "pas", "cobr", "recarg", "clar", "servici", "internet", "mal", "lent", "se\u00f1al", "llam", "sirv", "pesim", "solucion", "asesor", "client", "respuest", "contest", "problem", "mejor", "clar_vide", "chat", "cae", "conexion", "ofrec", "buen", "red", "hor", "comun", "atencion", "contrat", "esper", "usuari", "cas", "ped", "pon", "activ", "sab", "ningun", "paquet", "equip_financi", "qued", "revis", "cuant", "consum_dat", "valor", "nombr", "usted", "minut", "quer", "com", "bien", "referent", "contact", "habl_asesor", "hic", "bloqu", "quej", "pregunt", "reclam", "fech", "report", "netflix", "cuot", "financi", "form", "pag", "factur", "dej", "pued", "app", "ver", "plan", "hac", "pud", "ingres", "recarg", "clar", "registr", "consult", "cuent", "aplic", "equip", "numer", "clar_hog", "funcion", "dic", "aparec", "celul", "pod", "necesit", "hog", "inform", "si", "line", "realiz", "dat", "cancel", "tecnic", "cobr", "pas", "fall", "acced", "mes", "dias", "solicit", "abrir", "comunic", "dan", "averigu", "abre", "fij", "prepag", "dos", "bloque", "dia", "falt", "much", "llev", "rap", "gig", "ayud", "da_opcion", "habl", "solucion_problem", "pes", "envi", "dese"], "Freq": [1251.0, 745.0, 675.0, 1864.0, 525.0, 449.0, 1386.0, 322.0, 400.0, 1240.0, 1213.0, 279.0, 348.0, 1049.0, 243.0, 306.0, 951.0, 222.0, 930.0, 208.0, 875.0, 868.0, 266.0, 836.0, 250.0, 188.0, 185.0, 185.0, 737.0, 712.0, 1250.8671784436215, 744.2921298031085, 675.0646242258975, 525.0374340422724, 448.8974212572752, 399.98662805976613, 347.8451704938434, 305.37618653805583, 265.48665750484463, 249.54469245509742, 186.53216655677588, 143.28279118208488, 134.238173783591, 126.59144289725133, 125.35788096648932, 119.02453146105266, 116.75264013626504, 113.24421761220444, 108.06752974166326, 107.26823272705069, 101.16704368635084, 99.8165965632971, 98.63514717418657, 91.02291367537842, 87.54301241615002, 85.61476693941106, 81.17141948400555, 81.20724489880358, 79.67339219882089, 77.84097140649624, 78.65432546443925, 278.85729167484334, 242.23348905758124, 221.50472942138262, 207.8592069259689, 150.40792061827958, 138.24209043565304, 140.6730135209463, 121.54903276624428, 121.26237960878721, 118.07570735836491, 110.69688943021903, 107.44020689134045, 99.83023958622545, 97.51900231667497, 82.5903307414342, 80.75312710726791, 81.86373709232014, 73.77321677323988, 73.10568940657062, 71.21301049193204, 70.16454479101535, 70.11585251426894, 67.89159016749333, 65.04755223027826, 63.70364824207886, 59.08752920646896, 56.05604310378959, 53.48031500145569, 49.199017712261615, 48.855264773439934, 1863.4654611988774, 1385.714884213542, 1239.9120522735168, 1213.083325803702, 1048.5813881487618, 950.7772090879915, 930.0593860350793, 874.6483480784417, 867.93979960107, 835.4610517768327, 736.5907219800497, 711.6000563204831, 684.3705896245789, 658.918040822029, 572.0408479702401, 567.5789936639436, 554.5838136382442, 514.8243228228079, 513.8135395392469, 488.67459845590326, 485.4786104460274, 459.7856868133971, 461.93142586602426, 447.7493108912797, 427.57657617241347, 416.9144912658432, 401.2862384978918, 393.2973850629943, 392.018119689068, 387.2175151416939, 728.1592369503093, 321.6691107139861, 187.69680918933534, 184.81897554283324, 184.92241719327873, 163.37455178927272, 162.6906141290931, 150.80829387323234, 132.22998558012995, 128.3789295162111, 114.46832818059002, 109.573 ...

# %%
pyLDAvis.save_html(lda_display, 'lda_General_4_V3.html')
lda_4.save('Lda_4_Model')

# %%
lda_prueba = LdaModel.load('Lda_4_Model')

# %%
dfc2 = df[df['Q2_NPS_GROUP']!='Promotor']
dfc2 = dfc.fillna('')
dfc2
# Out:
#                                                       Q4  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                                     Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                        Tokens_Q4  \
# 4                                       [ningun]
# 9      [qued, sald, carg, app, pod, recarg, vez]
# 10                                            []
# 11      [bastant, tiemp, usted, sub, plan, line]
# 13                                            []
# ...                                          ...
# 48043                                         []
# 48048                                         []
# 48049                                         []
# 48050                                         []
# 48052                                         []
#
#                             Tokens_Q12  \
# 4                                   []
# 9                                   []
# 10                                  []
# 11                                  []
# 13                                  []
# ...                                ...
# 48043  [mas, facil, encontr, hac, cos]
# 48048                               []
# 48049                               []
# 48050                               []
# 48052                      [lent, app]
#
#                                               Tokens_Q15  \
# 4                                                     []
# 9                                                     []
# 10                                          [mal, señal]
# 11     [cambi, mes, oper, regres, nuev, sub, mil, pes...
# 13     [demor, carg, despues, dic, sient, trabaj, ser...
# ...                                                  ...
# 48043  [pued, pag, factur, tampoc, pued, ver, consum,...
# 48048                                                 []
# 48049                                                 []
# 48050                                               [bn]
# 48052                             [demor, entrar, aplic]
#
#                                          Tokens_Q18     Tokens_Q20
# 4                                                []             []
# 9                                                []  [parec, bien]
# 10                                               []             []
# 11                                               []             []
# 13                                               []             []
# ...                                             ...            ...
# 48043  [pud, ver, consum, dat, tampoc, pag, factur]             []
# 48048                                            []             []
# 48049                                            []             []
# 48050                         [entend, bien, graci]             []
# 48052                                            []             []
#
# [22263 rows x 10 columns]

# %%
def Limpiar_Caracter(texto):
    if len(texto) == 1 or texto == ',':
        texto = ''
    else:
        texto = texto
    return texto

# %%
dfc2["Tokens_Q4"] =  dfc2.Q4.apply(limpiar_texto)
dfc2["Tokens_Q12"] =  dfc2.Q12.apply(limpiar_texto)
dfc2["Tokens_Q15"] =  dfc2.Q15.apply(limpiar_texto)
dfc2["Tokens_Q18"] =  dfc2.Q18.apply(limpiar_texto)
dfc2["Tokens_Q20"] =  dfc2.Q20.apply(limpiar_texto)

dfc2["Tokens_Q4"] =  dfc2.Q4.apply(Limpiar_Caracter)
dfc2["Tokens_Q12"] =  dfc2.Q12.apply(Limpiar_Caracter)
dfc2["Tokens_Q15"] =  dfc2.Q15.apply(Limpiar_Caracter)
dfc2["Tokens_Q18"] =  dfc2.Q18.apply(Limpiar_Caracter)
dfc2["Tokens_Q20"] =  dfc2.Q20.apply(Limpiar_Caracter)

dfc2
# Out:
#                                                       Q4  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                                     Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                Tokens_Q4  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                              Tokens_Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                               Tokens_Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                               Tokens_Q18       Tokens_Q20
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
# [22263 rows x 10 columns]

# %%
dfc2['Opinion'] = ''

for i in dfc2.index:
    dfc2.loc[i,'Opinion'] = str(dfc2.loc[i,'Tokens_Q12']) + " " + str(dfc2.loc[i,'Tokens_Q15']) + " " + str(dfc2.loc[i,'Tokens_Q18']) 
    
dfc2
# Out:
#                                                       Q4  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                                     Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                Tokens_Q4  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                              Tokens_Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                               Tokens_Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                               Tokens_Q18       Tokens_Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                  Opinion
# 4
# 9
# 10                                           Mala señal
# 11      Me cambié x un mes a otro operador y me regre...
# 13      Se demora para cargar y después dice lo sient...
# ...                                                  ...
# 48043  Antes era mas facil encontrar y hacer las cosa...
# 48048
# 48049
# 48050                   Bn  No lo entendí bien gracias 😊
# 48052  Es un poco lenta la app Se demora un poco al e...
#
# [22263 rows x 11 columns]

# %%
dfc2['Opinion'] = dfc2['Opinion'].apply(tokenizer.tokenize)
dfc2['Opinion'] = dfc2['Opinion'].apply(filtrar_stopword_digitos)
dfc2['Opinion'] = dfc2['Opinion'].apply(stem_palabras)
dfc2['Opinion']
# Out:
# 4                                                       []
# 9                                                       []
# 10                                            [mal, señal]
# 11       [me, cambi, x, mes, oper, regres, nuev, sub, m...
# 13       [se, demor, carg, despues, dic, sient, trabaj,...
#                                ...
# 48043    [antes, mas, facil, encontr, hac, cos, ya, pue...
# 48048                                                   []
# 48049                                                   []
# 48050                     [bn, no, entend, bien, graci, 😊]
# 48052            [es, lent, app, se, demor, entrar, aplic]
# Name: Opinion, Length: 22263, dtype: object

# %%
for i in dfc2.index:
    
    if dfc2.loc[i,'Opinion']==[]:
        dfc2.drop([i], inplace=True)

dfc2
# Out:
#                                                       Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                                     Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18 Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...  ..
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                Tokens_Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                              Tokens_Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                               Tokens_Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                               Tokens_Q18 Tokens_Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...        ...
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                  Opinion
# 10                                          [mal, señal]
# 11     [me, cambi, x, mes, oper, regres, nuev, sub, m...
# 13     [se, demor, carg, despues, dic, sient, trabaj,...
# 27     [no, muestr, line, no, aparec, dat, line, cons...
# 32                                               [jjjjj]
# ...                                                  ...
# 48041  [llev, vari, mes, trat, den, mejor, preci, pla...
# 48042                        [no, aparec, factur, agost]
# 48043  [antes, mas, facil, encontr, hac, cos, ya, pue...
# 48050                   [bn, no, entend, bien, graci, 😊]
# 48052          [es, lent, app, se, demor, entrar, aplic]
#
# [7131 rows x 11 columns]

# %%
diccionario.doc2bow(dfc2.loc[10,'Opinion'])
# Out:
# [(44, 1), (54, 1)]

# %%
dfc2['Tópico'] = ""
for i in dfc2.index:
    try:
        
        bow_comentario = diccionario.doc2bow(dfc2.loc[i,'Opinion'])
        distribucion_noticia = lda_4[bow_comentario]

        dist_contrib = [topico[1] for topico in lda_4[bow_comentario]]

        if (dist_contrib[0] > dist_contrib[1]) & (dist_contrib[0] > dist_contrib[2]) & (dist_contrib[0] > dist_contrib[3]):
            dfc2.loc[i,'Tópico'] = 1
        elif (dist_contrib[1] > dist_contrib[0]) & (dist_contrib[1] > dist_contrib[2]) & (dist_contrib[1] > dist_contrib[3]):
            dfc2.loc[i,'Tópico'] = 2
        elif (dist_contrib[2] > dist_contrib[0]) & (dist_contrib[2] > dist_contrib[1]) & (dist_contrib[2] > dist_contrib[3]):
            dfc2.loc[i,'Tópico'] = 3
        elif (dist_contrib[3] > dist_contrib[0]) & (dist_contrib[3] > dist_contrib[1]) & (dist_contrib[3] > dist_contrib[2]):
            dfc2.loc[i,'Tópico'] = 4
        
    except:
        print('No')

# %%
dfc2.Tópico.value_counts()
# Out:
# 3    6903
# 1     185
# 2      26
# 4      17
# Name: Tópico, dtype: int64

# %%
dfc2
# Out:
#                                                       Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                                     Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18 Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...  ..
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                Tokens_Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                              Tokens_Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                               Tokens_Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                               Tokens_Q18 Tokens_Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...        ...
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                  Opinion Tópico
# 10                                          [mal, señal]      3
# 11     [me, cambi, x, mes, oper, regres, nuev, sub, m...      3
# 13     [se, demor, carg, despues, dic, sient, trabaj,...      3
# 27     [no, muestr, line, no, aparec, dat, line, cons...      3
# 32                                               [jjjjj]      3
# ...                                                  ...    ...
# 48041  [llev, vari, mes, trat, den, mejor, preci, pla...      3
# 48042                        [no, aparec, factur, agost]      3
# 48043  [antes, mas, facil, encontr, hac, cos, ya, pue...      3
# 48050                   [bn, no, entend, bien, graci, 😊]      3
# 48052          [es, lent, app, se, demor, entrar, aplic]      3
#
# [7131 rows x 12 columns]

# %%
dfc2['RecordedDate'] = df['RecordedDate']
dfc2['Q2_NPS_GROUP'] = df['Q2_NPS_GROUP']
dfc2['Q2'] = df['Q2']
dfc2['Q3'] = df['Q3']
dfc2['Q9'] = df['Q9']
dfc2['Q11'] = df['Q11']
dfc2['Nombre del cliente App'] = df['Nombre del cliente App']
dfc2['ID cuenta o Telefono App'] = df['ID cuenta o Telefono App']
dfc2['email App'] = df['email App']
dfc2['Segmento App'] = df['Segmento App']
dfc2['Modulo App'] = df['Modulo App']

# %%
dfc2
# Out:
#                                                       Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                                     Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18 Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...  ..
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                Tokens_Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                              Tokens_Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                               Tokens_Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                               Tokens_Q18 Tokens_Q20  ...  \
# 10                                                                   ...
# 11                                                                   ...
# 13                                                  Nada             ...
# 27     No pide consultar nada acerca de mi línea 3132...             ...
# 32                                                                   ...
# ...                                                  ...        ...  ...
# 48041                                                                ...
# 48042  No me aparece factura para el 3102177480 de ag...             ...
# 48043  No pude ver el consumo de mis datos y tampoco ...             ...
# 48050                       No lo entendí bien gracias 😊             ...
# 48052                                                                ...
#
#       Q2_NPS_GROUP Q2                                                 Q3  \
# 10       Detractor  5                        El funcionamiento de la app
# 11       Detractor  5                                      Otras razones
# 13       Detractor  0                        El funcionamiento de la app
# 27       Detractor  0                        El funcionamiento de la app
# 32       Detractor  1                     El registro o ingreso a la app
# ...            ... ..                                                ...
# 48041    Detractor  5                                      Otras razones
# 48042       Pasivo  8                                      Otras razones
# 48043    Detractor  1                        El funcionamiento de la app
# 48050    Detractor  6  El registro o ingreso a la app,El funcionamien...
# 48052    Detractor  5                        El funcionamiento de la app
#
#                                                       Q9  \
# 10                                                   NaN
# 11                                                   NaN
# 13                                                   NaN
# 27                                                   NaN
# 32                                     Por otras razones
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                                NaN
# 48050  La facilidad para registrarte,La facilidad par...
# 48052                                                NaN
#
#                                                      Q11  \
# 10                    La facilidad para descargar la app
# 11                                                   NaN
# 13                              Rapidez de la aplicación
# 27                                     Por otras razones
# 32                                                   NaN
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                  Por otras razones
# 48050  La facilidad para descargar la app,La facilida...
# 48052                                  Por otras razones
#
#                      Nombre del cliente App ID cuenta o Telefono App  \
# 10                       Heyder Mesa Prieto               3144597332
# 11      Maria Elvi Acero           Gonzalez               3114559290
# 13          Jerson Steven Builes Castrillon               3117710110
# 27              Omar Jairo Moreno Hernandez               3132339396
# 32                    Robinson Butron Alian               3226216529
# ...                                     ...                      ...
# 48041             Yeimy Milena Diaz Jimenez               3102624152
# 48042                 Paulina Zambrano Diaz               3102177480
# 48043            Maria Paula Cardona Lozano               3224311507
# 48050  Prospero Guillermo Coronado Cantillo               3126177396
# 48052         Freenzen Armando Osorio Tovar               3175080765
#
#                           email App Segmento App            Modulo App
# 10           heidermesa@hotmail.com          pre      pre_detalle_plan
# 11          elviraacero14@gmail.com          pre          pre_elegidos
# 13              yozmansbc@gmail.com          pre    pre_consulta_saldo
# 27           prensaenmoto@gmail.com          pre    pre_consulta_saldo
# 32        solucionesgenco@gmail.com          pre      pre_detalle_plan
# ...                             ...          ...                   ...
# 48041          mileosanwo@gmail.com          pre  pre_gestionar_equipo
# 48042       dentalceramica@yahoo.es          pre      pre_detalle_plan
# 48043     cardonapaula191@gmail.com          pre    pre_consulta_saldo
# 48050  prosperocoronado30@gmail.com          pre          pre_elegidos
# 48052    osorioeljunior10@gmail.com          pre          pre_elegidos
#
# [7131 rows x 23 columns]

# %%
lista_ordenada = ['RecordedDate', 'Q2_NPS_GROUP', 'Q2', 'Q3', 'Q4', 'Q9', 'Q12', 'Q11', 'Q15', 'Q18', 'Q20', 'Opinion', 'Tópico', 'Segmento App', 'Modulo App', 'Nombre del cliente App', 'ID cuenta o Telefono App', 'email App', 'Segmento App']
dfc2 = dfc2[lista_ordenada]
dfc2
# Out:
#                      RecordedDate Q2_NPS_GROUP Q2  \
# 10     2021-05-01 01:13:29.173000    Detractor  5
# 11     2021-05-01 01:21:26.392000    Detractor  5
# 13     2021-05-01 01:35:12.335000    Detractor  0
# 27     2021-05-01 05:46:19.079000    Detractor  0
# 32     2021-05-01 06:03:56.409000    Detractor  1
# ...                           ...          ... ..
# 48041  2021-08-08 23:05:23.967000    Detractor  5
# 48042  2021-08-08 23:07:34.573000       Pasivo  8
# 48043  2021-08-08 23:08:27.483000    Detractor  1
# 48050  2021-08-08 23:43:19.277000    Detractor  6
# 48052  2021-08-08 23:49:45.987000    Detractor  5
#
#                                                       Q3  \
# 10                           El funcionamiento de la app
# 11                                         Otras razones
# 13                           El funcionamiento de la app
# 27                           El funcionamiento de la app
# 32                        El registro o ingreso a la app
# ...                                                  ...
# 48041                                      Otras razones
# 48042                                      Otras razones
# 48043                        El funcionamiento de la app
# 48050  El registro o ingreso a la app,El funcionamien...
# 48052                        El funcionamiento de la app
#
#                                                       Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                                       Q9  \
# 10                                                   NaN
# 11                                                   NaN
# 13                                                   NaN
# 27                                                   NaN
# 32                                     Por otras razones
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                                NaN
# 48050  La facilidad para registrarte,La facilidad par...
# 48052                                                NaN
#
#                                                     Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q11  \
# 10                    La facilidad para descargar la app
# 11                                                   NaN
# 13                              Rapidez de la aplicación
# 27                                     Por otras razones
# 32                                                   NaN
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                  Por otras razones
# 48050  La facilidad para descargar la app,La facilida...
# 48052                                  Por otras razones
#
#                                                      Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18 Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...  ..
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                  Opinion Tópico Segmento App  \
# 10                                          [mal, señal]      3          pre
# 11     [me, cambi, x, mes, oper, regres, nuev, sub, m...      3          pre
# 13     [se, demor, carg, despues, dic, sient, trabaj,...      3          pre
# 27     [no, muestr, line, no, aparec, dat, line, cons...      3          pre
# 32                                               [jjjjj]      3          pre
# ...                                                  ...    ...          ...
# 48041  [llev, vari, mes, trat, den, mejor, preci, pla...      3          pre
# 48042                        [no, aparec, factur, agost]      3          pre
# 48043  [antes, mas, facil, encontr, hac, cos, ya, pue...      3          pre
# 48050                   [bn, no, entend, bien, graci, 😊]      3          pre
# 48052          [es, lent, app, se, demor, entrar, aplic]      3          pre
#
#                  Modulo App                Nombre del cliente App  \
# 10         pre_detalle_plan                    Heyder Mesa Prieto
# 11             pre_elegidos   Maria Elvi Acero           Gonzalez
# 13       pre_consulta_saldo       Jerson Steven Builes Castrillon
# 27       pre_consulta_saldo           Omar Jairo Moreno Hernandez
# 32         pre_detalle_plan                 Robinson Butron Alian
# ...                     ...                                   ...
# 48041  pre_gestionar_equipo             Yeimy Milena Diaz Jimenez
# 48042      pre_detalle_plan                 Paulina Zambrano Diaz
# 48043    pre_consulta_saldo            Maria Paula Cardona Lozano
# 48050          pre_elegidos  Prospero Guillermo Coronado Cantillo
# 48052          pre_elegidos         Freenzen Armando Osorio Tovar
#
#       ID cuenta o Telefono App                     email App Segmento App
# 10                  3144597332        heidermesa@hotmail.com          pre
# 11                  3114559290       elviraacero14@gmail.com          pre
# 13                  3117710110           yozmansbc@gmail.com          pre
# 27                  3132339396        prensaenmoto@gmail.com          pre
# 32                  3226216529     solucionesgenco@gmail.com          pre
# ...                        ...                           ...          ...
# 48041               3102624152          mileosanwo@gmail.com          pre
# 48042               3102177480       dentalceramica@yahoo.es          pre
# 48043               3224311507     cardonapaula191@gmail.com          pre
# 48050               3126177396  prosperocoronado30@gmail.com          pre
# 48052               3175080765    osorioeljunior10@gmail.com          pre
#
# [7131 rows x 19 columns]

# %%
dfc2['Tema'] = dfc2['Tópico']

# %%
dfc2
# Out:
#                      RecordedDate Q2_NPS_GROUP Q2  \
# 10     2021-05-01 01:13:29.173000    Detractor  5
# 11     2021-05-01 01:21:26.392000    Detractor  5
# 13     2021-05-01 01:35:12.335000    Detractor  0
# 27     2021-05-01 05:46:19.079000    Detractor  0
# 32     2021-05-01 06:03:56.409000    Detractor  1
# ...                           ...          ... ..
# 48041  2021-08-08 23:05:23.967000    Detractor  5
# 48042  2021-08-08 23:07:34.573000       Pasivo  8
# 48043  2021-08-08 23:08:27.483000    Detractor  1
# 48050  2021-08-08 23:43:19.277000    Detractor  6
# 48052  2021-08-08 23:49:45.987000    Detractor  5
#
#                                                       Q3  \
# 10                           El funcionamiento de la app
# 11                                         Otras razones
# 13                           El funcionamiento de la app
# 27                           El funcionamiento de la app
# 32                        El registro o ingreso a la app
# ...                                                  ...
# 48041                                      Otras razones
# 48042                                      Otras razones
# 48043                        El funcionamiento de la app
# 48050  El registro o ingreso a la app,El funcionamien...
# 48052                        El funcionamiento de la app
#
#                                                       Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                                       Q9  \
# 10                                                   NaN
# 11                                                   NaN
# 13                                                   NaN
# 27                                                   NaN
# 32                                     Por otras razones
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                                NaN
# 48050  La facilidad para registrarte,La facilidad par...
# 48052                                                NaN
#
#                                                     Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q11  \
# 10                    La facilidad para descargar la app
# 11                                                   NaN
# 13                              Rapidez de la aplicación
# 27                                     Por otras razones
# 32                                                   NaN
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                  Por otras razones
# 48050  La facilidad para descargar la app,La facilida...
# 48052                                  Por otras razones
#
#                                                      Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18 Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...  ..
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                  Opinion Tópico Segmento App  \
# 10                                          [mal, señal]      3          pre
# 11     [me, cambi, x, mes, oper, regres, nuev, sub, m...      3          pre
# 13     [se, demor, carg, despues, dic, sient, trabaj,...      3          pre
# 27     [no, muestr, line, no, aparec, dat, line, cons...      3          pre
# 32                                               [jjjjj]      3          pre
# ...                                                  ...    ...          ...
# 48041  [llev, vari, mes, trat, den, mejor, preci, pla...      3          pre
# 48042                        [no, aparec, factur, agost]      3          pre
# 48043  [antes, mas, facil, encontr, hac, cos, ya, pue...      3          pre
# 48050                   [bn, no, entend, bien, graci, 😊]      3          pre
# 48052          [es, lent, app, se, demor, entrar, aplic]      3          pre
#
#                  Modulo App                Nombre del cliente App  \
# 10         pre_detalle_plan                    Heyder Mesa Prieto
# 11             pre_elegidos   Maria Elvi Acero           Gonzalez
# 13       pre_consulta_saldo       Jerson Steven Builes Castrillon
# 27       pre_consulta_saldo           Omar Jairo Moreno Hernandez
# 32         pre_detalle_plan                 Robinson Butron Alian
# ...                     ...                                   ...
# 48041  pre_gestionar_equipo             Yeimy Milena Diaz Jimenez
# 48042      pre_detalle_plan                 Paulina Zambrano Diaz
# 48043    pre_consulta_saldo            Maria Paula Cardona Lozano
# 48050          pre_elegidos  Prospero Guillermo Coronado Cantillo
# 48052          pre_elegidos         Freenzen Armando Osorio Tovar
#
#       ID cuenta o Telefono App                     email App Segmento App Tema
# 10                  3144597332        heidermesa@hotmail.com          pre    3
# 11                  3114559290       elviraacero14@gmail.com          pre    3
# 13                  3117710110           yozmansbc@gmail.com          pre    3
# 27                  3132339396        prensaenmoto@gmail.com          pre    3
# 32                  3226216529     solucionesgenco@gmail.com          pre    3
# ...                        ...                           ...          ...  ...
# 48041               3102624152          mileosanwo@gmail.com          pre    3
# 48042               3102177480       dentalceramica@yahoo.es          pre    3
# 48043               3224311507     cardonapaula191@gmail.com          pre    3
# 48050               3126177396  prosperocoronado30@gmail.com          pre    3
# 48052               3175080765    osorioeljunior10@gmail.com          pre    3
#
# [7131 rows x 20 columns]

# %%
dfc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7131 entries, 10 to 48052
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   RecordedDate              7131 non-null   object
#  1   Q2_NPS_GROUP              7054 non-null   object
#  2   Q2                        7054 non-null   object
#  3   Q3                        6963 non-null   object
#  4   Q4                        7131 non-null   object
#  5   Q9                        1574 non-null   object
#  6   Q12                       7131 non-null   object
#  7   Q11                       4263 non-null   object
#  8   Q15                       7131 non-null   object
#  9   Q18                       7131 non-null   object
#  10  Q20                       7131 non-null   object
#  11  Opinion                   7131 non-null   object
#  12  Tópico                    7131 non-null   object
#  13  Segmento App              7008 non-null   object
#  14  Modulo App                7131 non-null   object
#  15  Nombre del cliente App    7130 non-null   object
#  16  ID cuenta o Telefono App  6684 non-null   object
#  17  email App                 7126 non-null   object
#  18  Segmento App              7008 non-null   object
#  19  Tema                      7131 non-null   object
# dtypes: object(20)
# memory usage: 1.4+ MB

# %%
dfc2.to_csv('Modelamiento_Topicos_General_Consolidado.csv', index=False, sep=';')
