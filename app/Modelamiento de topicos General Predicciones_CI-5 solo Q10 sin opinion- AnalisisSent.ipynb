# %%
import pandas as pd 
import numpy as np 
from textblob import TextBlob
import matplotlib.pyplot as plt

import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()


import json, re
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import ToktokTokenizer


from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

from gensim.models.coherencemodel import CoherenceModel
from gensim import corpora
from gensim.corpora import Dictionary
from gensim.models import LdaModel
import gensim


import random
from wordcloud import WordCloud
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
#df = pd.read_excel('Resultados Touchpoint APP Personas del 1abr al 24 May.xlsx')
df = pd.read_excel('Touchpoint APP Personas 1 May al 8 Ago Prepago.xlsx')
df.head()
# Out:
#              StartDate                EndDate             Status  \
# 0      Fecha de inicio  Fecha de finalización  Tipo de respuesta
# 1  2021-05-01 00:01:09    2021-05-01 00:02:59         IP Address
# 2  2021-04-30 00:08:19    2021-04-30 00:10:59         IP Address
# 3  2021-04-30 00:10:51    2021-04-30 00:11:03         IP Address
# 4  2021-05-01 00:14:21    2021-05-01 00:15:37         IP Address
#
#          IPAddress  Progress   Duration (in seconds)    Finished  \
# 0     Dirección IP  Progreso  Duración (en segundos)  Finalizado
# 1    181.78.16.235       100                     110        True
# 2  191.156.153.227        38                     160       False
# 3    181.78.21.213         6                      11       False
# 4    181.53.12.201       100                      76        True
#
#                  RecordedDate         ResponseId          RecipientLastName  \
# 0            Fecha registrada    ID de respuesta  Apellido del destinatario
# 1  2021-05-01 00:02:59.714000  R_3ISGyOV01BzngPO                        NaN
# 2  2021-05-01 00:11:00.156000  R_22t2EpjmNZEoqFT                        NaN
# 3  2021-05-01 00:11:04.303000  R_2y9PPrBZcRkKcoZ                        NaN
# 4  2021-05-01 00:15:38.223000  R_udHanua3i8beZtT                        NaN
#
#    ...  Q15 - Topic Sentiment Label  Q15 - Topic Sentiment Score  \
# 0  ...  Q15 - Topic Sentiment Label  Q15 - Topic Sentiment Score
# 1  ...                          NaN                          NaN
# 2  ...                          NaN                          NaN
# 3  ...                          NaN                          NaN
# 4  ...                          NaN                          NaN
#
#    Q15 - Topics  Q20 - Parent Topics  Q20 - Sentiment Polarity  \
# 0  Q15 - Topics  Q20 - Parent Topics  Q20 - Sentiment Polarity
# 1           NaN                  NaN                       NaN
# 2           NaN                  NaN                       NaN
# 3           NaN                  NaN                       NaN
# 4           NaN                  NaN                       NaN
#
#    Q20 - Sentiment Score  Q20 - Sentiment  Q20 - Topic Sentiment Label  \
# 0  Q20 - Sentiment Score  Q20 - Sentiment  Q20 - Topic Sentiment Label
# 1                    NaN              NaN                          NaN
# 2                    NaN              NaN                          NaN
# 3                    NaN              NaN                          NaN
# 4                    NaN              NaN                          NaN
#
#    Q20 - Topic Sentiment Score  Q20 - Topics
# 0  Q20 - Topic Sentiment Score  Q20 - Topics
# 1                          NaN           NaN
# 2                          NaN           NaN
# 3                          NaN           NaN
# 4                          NaN           NaN
#
# [5 rows x 53 columns]

# %%
df = df.drop([0], axis=0)
df
# Out:
#                  StartDate              EndDate      Status        IPAddress  \
# 1      2021-05-01 00:01:09  2021-05-01 00:02:59  IP Address    181.78.16.235
# 2      2021-04-30 00:08:19  2021-04-30 00:10:59  IP Address  191.156.153.227
# 3      2021-04-30 00:10:51  2021-04-30 00:11:03  IP Address    181.78.21.213
# 4      2021-05-01 00:14:21  2021-05-01 00:15:37  IP Address    181.53.12.201
# 5      2021-04-30 00:16:38  2021-04-30 00:16:47  IP Address    181.55.225.31
# ...                    ...                  ...         ...              ...
# 48048  2021-08-08 23:39:41  2021-08-08 23:40:38  IP Address    181.51.32.254
# 48049  2021-08-08 23:40:25  2021-08-08 23:43:02  IP Address    181.78.12.127
# 48050  2021-08-08 23:40:35  2021-08-08 23:43:18  IP Address  191.102.221.222
# 48051  2021-08-08 23:46:54  2021-08-08 23:48:20  IP Address    181.58.38.190
# 48052  2021-08-08 23:48:15  2021-08-08 23:49:45  IP Address    179.32.64.221
#
#       Progress Duration (in seconds) Finished                RecordedDate  \
# 1          100                   110     True  2021-05-01 00:02:59.714000
# 2           38                   160    False  2021-05-01 00:11:00.156000
# 3            6                    11    False  2021-05-01 00:11:04.303000
# 4          100                    76     True  2021-05-01 00:15:38.223000
# 5            6                     8    False  2021-05-01 00:16:48.490000
# ...        ...                   ...      ...                         ...
# 48048      100                    56     True  2021-08-08 23:40:38.430000
# 48049      100                   157     True  2021-08-08 23:43:03.328000
# 48050      100                   163     True  2021-08-08 23:43:19.277000
# 48051      100                    85     True  2021-08-08 23:48:20.431000
# 48052      100                    90     True  2021-08-08 23:49:45.987000
#
#               ResponseId RecipientLastName  ... Q15 - Topic Sentiment Label  \
# 1      R_3ISGyOV01BzngPO               NaN  ...                         NaN
# 2      R_22t2EpjmNZEoqFT               NaN  ...                         NaN
# 3      R_2y9PPrBZcRkKcoZ               NaN  ...                         NaN
# 4      R_udHanua3i8beZtT               NaN  ...                         NaN
# 5      R_pi1N5OEgj4shabD               NaN  ...                         NaN
# ...                  ...               ...  ...                         ...
# 48048  R_sToi9iywAO42BRn               NaN  ...                         NaN
# 48049  R_3kugDTodOoTWqZe               NaN  ...                         NaN
# 48050  R_2YRIKXkrkI4ZEKr               NaN  ...                         NaN
# 48051  R_1fZBz7zYj4eBFWA               NaN  ...                         NaN
# 48052  R_1ffKZbTcrdQb1j5               NaN  ...                         NaN
#
#       Q15 - Topic Sentiment Score Q15 - Topics Q20 - Parent Topics  \
# 1                             NaN          NaN                 NaN
# 2                             NaN          NaN                 NaN
# 3                             NaN          NaN                 NaN
# 4                             NaN          NaN                 NaN
# 5                             NaN          NaN                 NaN
# ...                           ...          ...                 ...
# 48048                         NaN          NaN                 NaN
# 48049                         NaN          NaN                 NaN
# 48050                         NaN      Unknown                 NaN
# 48051                         NaN          NaN                 NaN
# 48052                         NaN      Unknown                 NaN
#
#       Q20 - Sentiment Polarity Q20 - Sentiment Score Q20 - Sentiment  \
# 1                          NaN                   NaN             NaN
# 2                          NaN                   NaN             NaN
# 3                          NaN                   NaN             NaN
# 4                          NaN                   NaN             NaN
# 5                          NaN                   NaN             NaN
# ...                        ...                   ...             ...
# 48048                      NaN                   NaN             NaN
# 48049                      NaN                   NaN             NaN
# 48050                      NaN                   NaN             NaN
# 48051                      NaN                   NaN             NaN
# 48052                      NaN                   NaN             NaN
#
#       Q20 - Topic Sentiment Label Q20 - Topic Sentiment Score Q20 - Topics
# 1                             NaN                         NaN          NaN
# 2                             NaN                         NaN          NaN
# 3                             NaN                         NaN          NaN
# 4                             NaN                         NaN          NaN
# 5                             NaN                         NaN          NaN
# ...                           ...                         ...          ...
# 48048                         NaN                         NaN          NaN
# 48049                         NaN                         NaN          NaN
# 48050                         NaN                         NaN          NaN
# 48051                         NaN                         NaN          NaN
# 48052                         NaN                         NaN          NaN
#
# [48052 rows x 53 columns]

# %%
df.Q2_NPS_GROUP.value_counts()
# Out:
# Promotor     25789
# Detractor     9377
# Pasivo        8274
# Name: Q2_NPS_GROUP, dtype: int64

# %%
A = df.Q2_NPS_GROUP.value_counts()
indices = A.index
plt.pie(A, labels=indices, autopct="%0.1f %%")
plt.axis("equal")
plt.show()

# %%
dfc = df[df['Q2_NPS_GROUP']!='Promotor']
dfc
# Out:
#                  StartDate              EndDate      Status        IPAddress  \
# 4      2021-05-01 00:14:21  2021-05-01 00:15:37  IP Address    181.53.12.201
# 9      2021-05-01 00:56:56  2021-05-01 00:58:36  IP Address    191.156.52.30
# 10     2021-05-01 01:11:12  2021-05-01 01:13:28  IP Address     190.26.155.7
# 11     2021-05-01 01:15:49  2021-05-01 01:21:26  IP Address    186.29.191.43
# 13     2021-05-01 01:31:59  2021-05-01 01:35:12  IP Address    191.156.2.216
# ...                    ...                  ...         ...              ...
# 48043  2021-08-08 23:06:19  2021-08-08 23:08:27  IP Address     186.84.91.69
# 48048  2021-08-08 23:39:41  2021-08-08 23:40:38  IP Address    181.51.32.254
# 48049  2021-08-08 23:40:25  2021-08-08 23:43:02  IP Address    181.78.12.127
# 48050  2021-08-08 23:40:35  2021-08-08 23:43:18  IP Address  191.102.221.222
# 48052  2021-08-08 23:48:15  2021-08-08 23:49:45  IP Address    179.32.64.221
#
#       Progress Duration (in seconds) Finished                RecordedDate  \
# 4          100                    76     True  2021-05-01 00:15:38.223000
# 9          100                   100     True  2021-05-01 00:58:37.141000
# 10         100                   136     True  2021-05-01 01:13:29.173000
# 11         100                   336     True  2021-05-01 01:21:26.392000
# 13         100                   193     True  2021-05-01 01:35:12.335000
# ...        ...                   ...      ...                         ...
# 48043      100                   127     True  2021-08-08 23:08:27.483000
# 48048      100                    56     True  2021-08-08 23:40:38.430000
# 48049      100                   157     True  2021-08-08 23:43:03.328000
# 48050      100                   163     True  2021-08-08 23:43:19.277000
# 48052      100                    90     True  2021-08-08 23:49:45.987000
#
#               ResponseId RecipientLastName  ... Q15 - Topic Sentiment Label  \
# 4      R_udHanua3i8beZtT               NaN  ...                         NaN
# 9      R_XjMcEuP3zshnpF7               NaN  ...                         NaN
# 10     R_x5YL4kva6EbeuWJ               NaN  ...                         NaN
# 11     R_3ltBuR7i97QbFAM               NaN  ...                         NaN
# 13     R_1laRSYqAGwFA04C               NaN  ...                         NaN
# ...                  ...               ...  ...                         ...
# 48043  R_3qlYjnE8E36TyLC               NaN  ...                         NaN
# 48048  R_sToi9iywAO42BRn               NaN  ...                         NaN
# 48049  R_3kugDTodOoTWqZe               NaN  ...                         NaN
# 48050  R_2YRIKXkrkI4ZEKr               NaN  ...                         NaN
# 48052  R_1ffKZbTcrdQb1j5               NaN  ...                         NaN
#
#       Q15 - Topic Sentiment Score Q15 - Topics Q20 - Parent Topics  \
# 4                             NaN          NaN                 NaN
# 9                             NaN          NaN                 NaN
# 10                            NaN      Unknown                 NaN
# 11                            NaN      Unknown                 NaN
# 13                            NaN      Unknown                 NaN
# ...                           ...          ...                 ...
# 48043                         NaN      Unknown                 NaN
# 48048                         NaN          NaN                 NaN
# 48049                         NaN          NaN                 NaN
# 48050                         NaN      Unknown                 NaN
# 48052                         NaN      Unknown                 NaN
#
#       Q20 - Sentiment Polarity Q20 - Sentiment Score Q20 - Sentiment  \
# 4                          NaN                   NaN             NaN
# 9                            0                     5        Positive
# 10                         NaN                   NaN             NaN
# 11                         NaN                   NaN             NaN
# 13                         NaN                   NaN             NaN
# ...                        ...                   ...             ...
# 48043                      NaN                   NaN             NaN
# 48048                      NaN                   NaN             NaN
# 48049                      NaN                   NaN             NaN
# 48050                      NaN                   NaN             NaN
# 48052                      NaN                   NaN             NaN
#
#       Q20 - Topic Sentiment Label Q20 - Topic Sentiment Score Q20 - Topics
# 4                             NaN                         NaN          NaN
# 9                             NaN                         NaN      Unknown
# 10                            NaN                         NaN          NaN
# 11                            NaN                         NaN          NaN
# 13                            NaN                         NaN          NaN
# ...                           ...                         ...          ...
# 48043                         NaN                         NaN          NaN
# 48048                         NaN                         NaN          NaN
# 48049                         NaN                         NaN          NaN
# 48050                         NaN                         NaN          NaN
# 48052                         NaN                         NaN          NaN
#
# [22263 rows x 53 columns]

# %%
dfc.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', 'Q19', 'Q2_NPS_GROUP', 'Q2',
#        'Q3', 'Q4', 'Q9', 'Q10', 'Q11', 'Q12', 'Q15', 'Q26_1', 'Q22_1', 'Q18',
#        'Q24_1', 'Q20', 'Nombre del cliente App', 'ID cuenta o Telefono App',
#        'email App', 'Segmento App', 'Modulo App', 'Accion',
#        'Q_DataPolicyViolations', 'Q15 - Parent Topics',
#        'Q15 - Sentiment Polarity', 'Q15 - Sentiment Score', 'Q15 - Sentiment',
#        'Q15 - Topic Sentiment Label', 'Q15 - Topic Sentiment Score',
#        'Q15 - Topics', 'Q20 - Parent Topics', 'Q20 - Sentiment Polarity',
#        'Q20 - Sentiment Score', 'Q20 - Sentiment',
#        'Q20 - Topic Sentiment Label', 'Q20 - Topic Sentiment Score',
#        'Q20 - Topics'],
#       dtype='object')

# %%
###  CI  agrego Q10,  
dfc = dfc[['Q4','Q10', 'Q12', 'Q15', 'Q18', 'Q20']]
dfc
# Out:
#                                                       Q4  Q10  \
# 4                                                Ninguna  NaN
# 9      Cuando me quedo sin saldo no carga la app para...  NaN
# 10                                                   NaN  NaN
# 11     Tengo bastante tiempo con ustedes y me le subi...  NaN
# 13                                                   NaN  NaN
# ...                                                  ...  ...
# 48043                                                NaN  NaN
# 48048                                                NaN  NaN
# 48049                                                NaN  NaN
# 48050                                                NaN  NaN
# 48052                                                NaN  NaN
#
#                                                     Q12  \
# 4                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 13                                                  NaN
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048                                               NaN
# 48049                                               NaN
# 48050                                               NaN
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4                                                    NaN
# 9                                                    NaN
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048                                                NaN
# 48049                                                NaN
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20
# 4                                                    NaN              NaN
# 9                                                    NaN  Me parece bien
# 10                                                   NaN              NaN
# 11                                                   NaN              NaN
# 13                                                  Nada              NaN
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...              NaN
# 48048                                                NaN              NaN
# 48049                                                NaN              NaN
# 48050                       No lo entendí bien gracias 😊              NaN
# 48052                                                NaN              NaN
#
# [22263 rows x 6 columns]

# %%
dfc = dfc.fillna('')
dfc
# Out:
#                                                       Q4 Q10  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...  ..
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                                     Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
# [22263 rows x 6 columns]

# %%
def limpiar_texto(texto):
    """
    Función para realizar la limpieza de un texto dado.
    """
    # Eliminamos los caracteres especiales
    texto = re.sub(r'\W', ' ', str(texto))
    # Eliminamos comas y /
    texto = re.sub(r',', ' ', str(texto))
    texto = re.sub(r'/', ' ', str(texto))
    # Eliminado las palabras que tengo un solo caracter
    texto = re.sub(r'\s+[a-zA-Z]\s+', ' ', texto)
    # Sustituir los espacios en blanco en uno solo
    texto = re.sub(r'\s+', ' ', texto, flags=re.I)
    # Convertimos textos a minusculas
    texto = texto.lower()
    return texto

# %%
dfc["Tokens_Q4"] =  dfc.Q4.apply(limpiar_texto)
dfc["Tokens_Q10"] =  dfc.Q10.apply(limpiar_texto)#'Q10'
dfc["Tokens_Q12"] =  dfc.Q12.apply(limpiar_texto)
dfc["Tokens_Q15"] =  dfc.Q15.apply(limpiar_texto)
dfc["Tokens_Q18"] =  dfc.Q18.apply(limpiar_texto)
dfc["Tokens_Q20"] =  dfc.Q20.apply(limpiar_texto)
dfc
# Out:
#                                                       Q4 Q10  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...  ..
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                                     Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                Tokens_Q4 Tokens_Q10  \
# 4                                                ninguna
# 9      cuando me quedo sin saldo no carga la app para...
# 10
# 11     tengo bastante tiempo con ustedes me le subier...
# 13
# ...                                                  ...        ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                            Tokens_Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                               ...
# 48043  antes era mas facil encontrar hacer las cosas
# 48048
# 48049
# 48050
# 48052                         es un poco lenta la app
#
#                                               Tokens_Q15  \
# 4
# 9
# 10                                            mala señal
# 11     me cambié un mes otro operador me regrese de n...
# 13     se demora para cargar después dice lo sienten ...
# ...                                                  ...
# 48043  ya no se puede pagar la factura tampoco se pue...
# 48048
# 48049
# 48050                                                bn
# 48052          se demora un poco al entrar la aplicación
#
#                                               Tokens_Q18       Tokens_Q20
# 4
# 9                                                         me parece bien
# 10
# 11
# 13                                                  nada
# ...                                                  ...              ...
# 48043  no pude ver el consumo de mis datos tampoco pa...
# 48048
# 48049
# 48050                        no lo entendí bien gracias
# 48052
#
# [22263 rows x 12 columns]

# %% [markdown]
# ######  Analisis de sentimientos

# %%
from sentiment_analysis_spanish import sentiment_analysis
sentiment = sentiment_analysis.SentimentAnalysisSpanish()

# %%
dfSent=df.fillna('')

# %%
dfSent["Tokens_Q4"] =  dfSent.Q4.apply(limpiar_texto)
dfSent["Tokens_Q10"] =  dfSent.Q10.apply(limpiar_texto)#'Q10'
dfSent["Tokens_Q12"] =  dfSent.Q12.apply(limpiar_texto)
dfSent["Tokens_Q15"] =  dfSent.Q15.apply(limpiar_texto)
dfSent["Tokens_Q18"] =  dfSent.Q18.apply(limpiar_texto)
dfSent["Tokens_Q20"] =  dfSent.Q20.apply(limpiar_texto)
dfSent.head()
# Out:
#             StartDate             EndDate      Status        IPAddress  \
# 1 2021-05-01 00:01:09 2021-05-01 00:02:59  IP Address    181.78.16.235
# 2 2021-04-30 00:08:19 2021-04-30 00:10:59  IP Address  191.156.153.227
# 3 2021-04-30 00:10:51 2021-04-30 00:11:03  IP Address    181.78.21.213
# 4 2021-05-01 00:14:21 2021-05-01 00:15:37  IP Address    181.53.12.201
# 5 2021-04-30 00:16:38 2021-04-30 00:16:47  IP Address    181.55.225.31
#
#    Progress  Duration (in seconds) Finished            RecordedDate  \
# 1       100                    110     True 2021-05-01 00:02:59.714
# 2        38                    160    False 2021-05-01 00:11:00.156
# 3         6                     11    False 2021-05-01 00:11:04.303
# 4       100                     76     True 2021-05-01 00:15:38.223
# 5         6                      8    False 2021-05-01 00:16:48.490
#
#           ResponseId RecipientLastName  ... Q20 - Sentiment  \
# 1  R_3ISGyOV01BzngPO                    ...
# 2  R_22t2EpjmNZEoqFT                    ...
# 3  R_2y9PPrBZcRkKcoZ                    ...
# 4  R_udHanua3i8beZtT                    ...
# 5  R_pi1N5OEgj4shabD                    ...
#
#   Q20 - Topic Sentiment Label Q20 - Topic Sentiment Score Q20 - Topics  \
# 1
# 2
# 3
# 4
# 5
#
#   Tokens_Q4 Tokens_Q10 Tokens_Q12 Tokens_Q15 Tokens_Q18 Tokens_Q20
# 1
# 2
# 3
# 4   ninguna
# 5
#
# [5 rows x 59 columns]

# %%
dfSent["Sent_Q4"] =  np.where(dfSent["Q4"]!='', dfSent.Q4.apply(sentiment.sentiment),'')
dfSent["Sent_Q10"] = np.where(dfSent["Q10"]!='', dfSent.Q10.apply(sentiment.sentiment),'') #'Q10'
dfSent["Sent_Q12"] = np.where(dfSent["Q12"]!='', dfSent.Q12.apply(sentiment.sentiment),'')
dfSent["Sent_Q15"] = np.where(dfSent["Q15"]!='', dfSent.Q15.apply(sentiment.sentiment),'')
dfSent["Sent_Q18"] = np.where(dfSent["Q18"]!='', dfSent.Q18.apply(sentiment.sentiment),'')
dfSent["Sent_Q20"] = np.where(dfSent["Q20"]!='', dfSent.Q20.apply(sentiment.sentiment),'')

# %%
dfSent.to_csv('AnalisisSentimientos_CI.csv', index=False, sep=';')

# %%
tokenizer = ToktokTokenizer() 
dfc["Tokens_Q4"] = dfc.Tokens_Q4.apply(tokenizer.tokenize)
dfc["Tokens_Q10"] = dfc.Tokens_Q10.apply(tokenizer.tokenize) #Q10
dfc["Tokens_Q12"] = dfc.Tokens_Q12.apply(tokenizer.tokenize)
dfc["Tokens_Q15"] = dfc.Tokens_Q15.apply(tokenizer.tokenize)
dfc["Tokens_Q18"] = dfc.Tokens_Q18.apply(tokenizer.tokenize)
dfc["Tokens_Q20"] = dfc.Tokens_Q20.apply(tokenizer.tokenize)
dfc.head()
# Out:
#                                                    Q4 Q10 Q12  \
# 4                                             Ninguna
# 9   Cuando me quedo sin saldo no carga la app para...
# 10
# 11  Tengo bastante tiempo con ustedes y me le subi...
# 13
#
#                                                   Q15    Q18              Q20  \
# 4
# 9                                                             Me parece bien
# 10                                         Mala señal
# 11  Me cambié x un mes a otro operador y me regres...
# 13  Se demora para cargar y después dice lo siente...   Nada
#
#                                             Tokens_Q4 Tokens_Q10 Tokens_Q12  \
# 4                                           [ninguna]         []         []
# 9   [cuando, me, quedo, sin, saldo, no, carga, la,...         []         []
# 10                                                 []         []         []
# 11  [tengo, bastante, tiempo, con, ustedes, me, le...         []         []
# 13                                                 []         []         []
#
#                                            Tokens_Q15 Tokens_Q18  \
# 4                                                  []         []
# 9                                                  []         []
# 10                                      [mala, señal]         []
# 11  [me, cambié, un, mes, otro, operador, me, regr...         []
# 13  [se, demora, para, cargar, después, dice, lo, ...     [nada]
#
#             Tokens_Q20
# 4                   []
# 9   [me, parece, bien]
# 10                  []
# 11                  []
# 13                  []

# %%
import nltk
nltk.download('stopwords')

STOPWORDS = set(stopwords.words("spanish"))

def filtrar_stopword_digitos(tokens):
    """
    Filtra stopwords y digitos de una lista de tokens.
    """
    return [token for token in tokens if token not in STOPWORDS 
            and not token.isdigit()]

dfc["Tokens_Q4"] = dfc.Tokens_Q4.apply(filtrar_stopword_digitos)
dfc["Tokens_Q10"] = dfc.Tokens_Q10.apply(filtrar_stopword_digitos)#Q10
dfc["Tokens_Q12"] = dfc.Tokens_Q12.apply(filtrar_stopword_digitos)
dfc["Tokens_Q15"] = dfc.Tokens_Q15.apply(filtrar_stopword_digitos)
dfc["Tokens_Q18"] = dfc.Tokens_Q18.apply(filtrar_stopword_digitos)
dfc["Tokens_Q20"] = dfc.Tokens_Q20.apply(filtrar_stopword_digitos)
dfc.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\CristhianJohnatanIzq\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                    Q4 Q10 Q12  \
# 4                                             Ninguna
# 9   Cuando me quedo sin saldo no carga la app para...
# 10
# 11  Tengo bastante tiempo con ustedes y me le subi...
# 13
#
#                                                   Q15    Q18              Q20  \
# 4
# 9                                                             Me parece bien
# 10                                         Mala señal
# 11  Me cambié x un mes a otro operador y me regres...
# 13  Se demora para cargar y después dice lo siente...   Nada
#
#                                             Tokens_Q4 Tokens_Q10 Tokens_Q12  \
# 4                                           [ninguna]         []         []
# 9    [quedo, saldo, carga, app, poder, recargar, vez]         []         []
# 10                                                 []         []         []
# 11  [bastante, tiempo, ustedes, subieron, plan, li...         []         []
# 13                                                 []         []         []
#
#                                            Tokens_Q15 Tokens_Q18  \
# 4                                                  []         []
# 9                                                  []         []
# 10                                      [mala, señal]         []
# 11  [cambié, mes, operador, regrese, nuevo, subier...         []
# 13  [demora, cargar, después, dice, sienten, traba...         []
#
#         Tokens_Q20
# 4               []
# 9   [parece, bien]
# 10              []
# 11              []
# 13              []

# %%
## validaciones
val=dfc[["Tokens_Q10"]]
for i in val.index:
    if val.loc[i,'Tokens_Q10']==[]:
        val.drop([i], inplace=True)
val
# Out:
#                             Tokens_Q10
# 32            [ja, entrar, clar, vide]
# 64                 [encuentr, necesit]
# 171                              [tod]
# 263                             [sirv]
# 274                       [tan, facil]
# ...                                ...
# 47885                      [fall, app]
# 47908  [app, sirv, ocup, espaci, sirv]
# 47943     [simylador, fe, financiamit]
# 47952           [dificil, cre, usuari]
# 48034           [anterior, dej, acced]
#
# [853 rows x 1 columns]

# %%
STOPWORDS
# Out:
# {'a',
#  'al',
#  'algo',
#  'algunas',
#  'algunos',
#  'ante',
#  'antes',
#  'como',
#  'con',
#  'contra',
#  'cual',
#  'cuando',
#  'de',
#  'del',
#  'desde',
#  'donde',
#  'durante',
#  'e',
#  'el',
#  'ella',
#  'ellas',
#  'ellos',
#  'en',
#  'entre',
#  'era',
#  'erais',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esa',
#  'esas',
#  'ese',
#  'eso',
#  'esos',
#  'esta',
#  'estaba',
#  'estabais',
#  'estaban',
#  'estabas',
#  'estad',
#  'estada',
#  'estadas',
#  'estado',
#  'estados',
#  'estamos',
#  'estando',
#  'estar',
#  'estaremos',
#  'estará',
#  'estarán',
#  'estarás',
#  'estaré',
#  'estaréis',
#  'estaría',
#  'estaríais',
#  'estaríamos',
#  'estarían',
#  'estarías',
#  'estas',
#  'este',
#  'estemos',
#  'esto',
#  'estos',
#  'estoy',
#  'estuve',
#  'estuviera',
#  'estuvierais',
#  'estuvieran',
#  'estuvieras',
#  'estuvieron',
#  'estuviese',
#  'estuvieseis',
#  'estuviesen',
#  'estuvieses',
#  'estuvimos',
#  'estuviste',
#  'estuvisteis',
#  'estuviéramos',
#  'estuviésemos',
#  'estuvo',
#  'está',
#  'estábamos',
#  'estáis',
#  'están',
#  'estás',
#  'esté',
#  'estéis',
#  'estén',
#  'estés',
#  'fue',
#  'fuera',
#  'fuerais',
#  'fueran',
#  'fueras',
#  'fueron',
#  'fuese',
#  'fueseis',
#  'fuesen',
#  'fueses',
#  'fui',
#  'fuimos',
#  'fuiste',
#  'fuisteis',
#  'fuéramos',
#  'fuésemos',
#  'ha',
#  'habida',
#  'habidas',
#  'habido',
#  'habidos',
#  'habiendo',
#  'habremos',
#  'habrá',
#  'habrán',
#  'habrás',
#  'habré',
#  'habréis',
#  'habría',
#  'habríais',
#  'habríamos',
#  'habrían',
#  'habrías',
#  'habéis',
#  'había',
#  'habíais',
#  'habíamos',
#  'habían',
#  'habías',
#  'han',
#  'has',
#  'hasta',
#  'hay',
#  'haya',
#  'hayamos',
#  'hayan',
#  'hayas',
#  'hayáis',
#  'he',
#  'hemos',
#  'hube',
#  'hubiera',
#  'hubierais',
#  'hubieran',
#  'hubieras',
#  'hubieron',
#  'hubiese',
#  'hubieseis',
#  'hubiesen',
#  'hubieses',
#  'hubimos',
#  'hubiste',
#  'hubisteis',
#  'hubiéramos',
#  'hubiésemos',
#  'hubo',
#  'la',
#  'las',
#  'le',
#  'les',
#  'lo',
#  'los',
#  'me',
#  'mi',
#  'mis',
#  'mucho',
#  'muchos',
#  'muy',
#  'más',
#  'mí',
#  'mía',
#  'mías',
#  'mío',
#  'míos',
#  'nada',
#  'ni',
#  'no',
#  'nos',
#  'nosotras',
#  'nosotros',
#  'nuestra',
#  'nuestras',
#  'nuestro',
#  'nuestros',
#  'o',
#  'os',
#  'otra',
#  'otras',
#  'otro',
#  'otros',
#  'para',
#  'pero',
#  'poco',
#  'por',
#  'porque',
#  'que',
#  'quien',
#  'quienes',
#  'qué',
#  'se',
#  'sea',
#  'seamos',
#  'sean',
#  'seas',
#  'sentid',
#  'sentida',
#  'sentidas',
#  'sentido',
#  'sentidos',
#  'seremos',
#  'será',
#  'serán',
#  'serás',
#  'seré',
#  'seréis',
#  'sería',
#  'seríais',
#  'seríamos',
#  'serían',
#  'serías',
#  'seáis',
#  'siente',
#  'sin',
#  'sintiendo',
#  'sobre',
#  'sois',
#  'somos',
#  'son',
#  'soy',
#  'su',
#  'sus',
#  'suya',
#  'suyas',
#  'suyo',
#  'suyos',
#  'sí',
#  'también',
#  'tanto',
#  'te',
#  'tendremos',
#  'tendrá',
#  'tendrán',
#  'tendrás',
#  'tendré',
#  'tendréis',
#  'tendría',
#  'tendríais',
#  'tendríamos',
#  'tendrían',
#  'tendrías',
#  'tened',
#  'tenemos',
#  'tenga',
#  'tengamos',
#  'tengan',
#  'tengas',
#  'tengo',
#  'tengáis',
#  'tenida',
#  'tenidas',
#  'tenido',
#  'tenidos',
#  'teniendo',
#  'tenéis',
#  'tenía',
#  'teníais',
#  'teníamos',
#  'tenían',
#  'tenías',
#  'ti',
#  'tiene',
#  'tienen',
#  'tienes',
#  'todo',
#  'todos',
#  'tu',
#  'tus',
#  'tuve',
#  'tuviera',
#  'tuvierais',
#  'tuvieran',
#  'tuvieras',
#  'tuvieron',
#  'tuviese',
#  'tuvieseis',
#  'tuviesen',
#  'tuvieses',
#  'tuvimos',
#  'tuviste',
#  'tuvisteis',
#  'tuviéramos',
#  'tuviésemos',
#  'tuvo',
#  'tuya',
#  'tuyas',
#  'tuyo',
#  'tuyos',
#  'tú',
#  'un',
#  'una',
#  'uno',
#  'unos',
#  'vosotras',
#  'vosotros',
#  'vuestra',
#  'vuestras',
#  'vuestro',
#  'vuestros',
#  'y',
#  'ya',
#  'yo',
#  'él',
#  'éramos'}

# %%
stemmer = SnowballStemmer("spanish")

def stem_palabras(tokens):
    """
    Reduce cada palabra de una lista dada a su raíz.
    """
    return [stemmer.stem(token) for token in tokens]

dfc["Tokens_Q4"] = dfc.Tokens_Q4.apply(stem_palabras)
dfc["Tokens_Q10"] = dfc.Tokens_Q10.apply(stem_palabras) #Q10
dfc["Tokens_Q12"] = dfc.Tokens_Q12.apply(stem_palabras)
dfc["Tokens_Q15"] = dfc.Tokens_Q15.apply(stem_palabras)
dfc["Tokens_Q18"] = dfc.Tokens_Q18.apply(stem_palabras)
dfc["Tokens_Q20"] = dfc.Tokens_Q20.apply(stem_palabras)
dfc.head()
# Out:
#                                                    Q4 Q10 Q12  \
# 4                                             Ninguna
# 9   Cuando me quedo sin saldo no carga la app para...
# 10
# 11  Tengo bastante tiempo con ustedes y me le subi...
# 13
#
#                                                   Q15    Q18              Q20  \
# 4
# 9                                                             Me parece bien
# 10                                         Mala señal
# 11  Me cambié x un mes a otro operador y me regres...
# 13  Se demora para cargar y después dice lo siente...   Nada
#
#                                     Tokens_Q4 Tokens_Q10 Tokens_Q12  \
# 4                                    [ningun]         []         []
# 9   [qued, sald, carg, app, pod, recarg, vez]         []         []
# 10                                         []         []         []
# 11   [bastant, tiemp, usted, sub, plan, line]         []         []
# 13                                         []         []         []
#
#                                            Tokens_Q15 Tokens_Q18  \
# 4                                                  []         []
# 9                                                  []         []
# 10                                       [mal, señal]         []
# 11  [cambi, mes, oper, regres, nuev, sub, mil, pes...         []
# 13  [demor, carg, despues, dic, sient, trabaj, ser...         []
#
#        Tokens_Q20
# 4              []
# 9   [parec, bien]
# 10             []
# 11             []
# 13             []

# %%
list_Q4 = dfc["Tokens_Q4"].tolist()
list_Q10 = dfc["Tokens_Q10"].tolist() #Q10
list_Q12 = dfc["Tokens_Q12"].tolist()
list_Q15 = dfc["Tokens_Q15"].tolist()
list_Q18 = dfc["Tokens_Q18"].tolist()
list_Q20 = dfc["Tokens_Q20"].tolist()

list_Q4 = [x for x in list_Q4 if x!= []]
list_Q10 = [x for x in list_Q10 if x!= []] #Q10
list_Q12 = [x for x in list_Q12 if x!= []]
list_Q15 = [x for x in list_Q15 if x!= []]
list_Q18 = [x for x in list_Q18 if x!= []]
list_Q20 = [x for x in list_Q20 if x!= []]

# %%
dfc["Tokens_Q4"]
# Out:
# 4                                         [ningun]
# 9        [qued, sald, carg, app, pod, recarg, vez]
# 10                                              []
# 11        [bastant, tiemp, usted, sub, plan, line]
# 13                                              []
#                            ...
# 48043                                           []
# 48048                                           []
# 48049                                           []
# 48050                                           []
# 48052                                           []
# Name: Tokens_Q4, Length: 22263, dtype: object

# %%
list_Q4
# Out:
# [['ningun'],
#  ['qued', 'sald', 'carg', 'app', 'pod', 'recarg', 'vez'],
#  ['bastant', 'tiemp', 'usted', 'sub', 'plan', 'line'],
#  ['actualiz', 'dat'],
#  ['fall', 'servici', 'tv', 'internet', 'app', 'ayud'],
#  ['cae', 'cad', 'dat'],
#  ['sirv'],
#  ['numer', 'mio', 'dej', 'cambi', 'line'],
#  ['dic', 'duplic', 'recarg', 've', 'reflej', 'confus'],
#  ['vec', 'demor', 'abrir'],
#  ['tv', 'internet', 'pesim'],
#  ['buen',
#   'dias',
#   'ubic',
#   'cuid',
#   'bogot',
#   'barri',
#   'triunf',
#   'sur',
#   'ciud',
#   'señal',
#   'regul',
#   'servici',
#   'hac',
#   'part'],
#  ['cobertur', 'part', 'funcion'],
#  ['se', 'encuentr', 'inform'],
#  ['pued', 'ingres', 'plan', 'hog'],
#  ['mal', 'servici'],
#  ['multipl', 'opcion', 'oper'],
#  ['opcion', 'pag', 'inclu', 'nequi'],
#  ['actualiz', 'dat', 'tiemp', 'real'],
#  ['mejor', 'paquet', 'prepag', 'dat', 'mejor', 'servici', 'client'],
#  ['encontr', 'com', 'registr', 'segund', 'imei'],
#  ['aplic', 'lent'],
#  ['mejor', 'calid', 'señal', 'señal', 'funcion', 'bien'],
#  ['cas',
#   'call',
#   'cas',
#   'llam',
#   'ofrec',
#   'meg',
#   'cedul',
#   'ven',
#   'vec',
#   'equip',
#   'mega'],
#  ['acept',
#   'cobr',
#   'mas',
#   'cambiar',
#   'oper',
#   'consum',
#   'gb',
#   'regal',
#   'lueg',
#   'cobr'],
#  ['clar',
#   'fall',
#   'nadi',
#   'pued',
#   'reclam',
#   'apen',
#   'lleg',
#   'dia',
#   'cobr',
#   'vuelv',
#   'insoport',
#   'perd',
#   'client',
#   'segu',
#   'perdiend'],
#  ['form', 'ver', 'line'],
#  ['señal',
#   'mal',
#   'taxi',
#   'part',
#   'qued',
#   'señal',
#   'pag',
#   'plan',
#   'car',
#   'nesecit',
#   'plan',
#   'barat',
#   'mism',
#   'benefici'],
#  ['pud', 'pag'],
#  ['problem', 'tecnic', 'permit', 'registr', 'nuev', 'equip'],
#  ['sol',
#   'pued',
#   'mejor',
#   'plan',
#   'pued',
#   'modific',
#   'baj',
#   'dese',
#   'obten',
#   'plan',
#   'parej',
#   'ten',
#   'dos',
#   'mism',
#   'plan'],
#  ['cobr', 'acord'],
#  ['pued', 'pag'],
#  ['use', 'app', 'mefuncion'],
#  ['dandom',
#   'cuent',
#   'familiar',
#   'clar',
#   'dad',
#   'much',
#   'meg',
#   'voy',
#   'retir',
#   'mañan',
#   'empiez',
#   'papele',
#   'retir'],
#  ['espaci', 'quej', 'bastant'],
#  ['ofrec',
#   'plan',
#   'dij',
#   'dab',
#   'mes',
#   'gratis',
#   'pares',
#   'falt',
#   'respet',
#   'dig',
#   'mentir'],
#  ['ningun'],
#  ['bloqu',
#   'equip',
#   'financi',
#   'clar',
#   'nombr',
#   'deud',
#   'celul',
#   'si',
#   'nombr',
#   'dan',
#   'solucion',
#   'factur'],
#  ['reserv'],
#  ['pod', 'sac', 'reposicion'],
#  ['mal', 'clar', 'todo'],
#  ['atencion', 'telefon', 'pront', 'respuest'],
#  ['present', 'deficient', 'naveg', 'solucion', 'problem'],
#  ['proces', 'registr'],
#  ['vec',
#   'suel',
#   'mir',
#   'valor',
#   'restant',
#   'equip',
#   'dic',
#   'ningun',
#   'equip',
#   'financi',
#   'si'],
#  ['cobertur'],
#  ['da', 'met', 'comun', 'famili', 'amig'],
#  ['sencill', 'falt', 'realiz', 'comp'],
#  ['encuentr', 'opcion', 'cambi', 'numer', 'famili', 'amig'],
#  ['señal'],
#  ['trat',
#   'recuper',
#   'clav',
#   'clar',
#   'vide',
#   'app',
#   'permit',
#   'acced',
#   'ayud',
#   'recib',
#   'solucion'],
#  ['pued', 'carg', 'celular', 'pse'],
#  ['funcion', 'conte', 'minut', 'paquet', 'borr', 'fech', 'activ', 'minut'],
#  ['dan', 'respuest', 'numer', 'telefon'],
#  ['acept'],
#  ['servici', 'famili', 'amig', 'funcion'],
#  ['solucion', 'dat'],
#  ['ingres', 'clar', 'vide', 'problem'],
#  ['cae', 'red'],
#  ['costos', 'servici'],
#  ['se', 'pod', 'cambi', 'elej', 'voz', 'result', 'numer', 'lan', 'esper'],
#  ['mal', 'servici'],
#  ['demor', 'carg'],
#  ['permit', 'pag', 'tarjet', 'credit', 'internacional'],
#  ['encuentr',
#   'necesit',
#   'demasi',
#   'complic',
#   'enred',
#   'funcion',
#   'envi',
#   'codig',
#   'verif'],
#  ['demor', 'ne', 'atencion', 'mal', 'cobertur', 'zon'],
#  ['sirv', 'funcion', 'trab'],
#  ['intent', 'registr', 'nuev', 'equip', 'compr', 'permit', 'hac'],
#  ['3g', 'moment', 'señal', 'deficient'],
#  ['lent'],
#  ['pued', 'acced', 'product', 'hog', 'solicit', 'trasl'],
#  ['pesim', 'servici', 'bloque', 'sald', 'avis', 'pop', 'up', 'mensaj', 'text'],
#  ['mal', 'dat', 'gb', 'utiz', 'lent', 'toc', 'pag', 'plan', 'rout', 'wifi'],
#  ['servici'],
#  ['avec', 'fall'],
#  ['trat',
#   'utiliz',
#   'app',
#   'registr',
#   'equip',
#   'pued',
#   'indic',
#   'problem',
#   'servidor',
#   'app',
#   'permit'],
#  ['cre', 'cos', 'web', 'aqu', 'vicevers'],
#  ['verd', 'moment', 'ningun'],
#  ['señal', 'oper', 'deterior'],
#  ['carg', 'app', 'duplic', 'dat', 'primer', 'vez', 'siempr', 'haci'],
#  ['vec', 'señal', 'lent'],
#  ['compr', 'celul', 'aparec', 'registr'],
#  ['pag', 'gener', 'registr'],
#  ['permit', 'pag', 'trjet', 'credit'],
#  ['dia',
#   'pag',
#   'siempr',
#   'sal',
#   'deb',
#   'ahor',
#   'disqu',
#   'dev',
#   'si',
#   'ser',
#   'asi',
#   'supon',
#   'app',
#   'bien',
#   'inform'],
#  ['an', 'quit', 'castig'],
#  ['entiend', 'si', 'plan', 'econom', 'lleg', 'cobr', 'aparec', 'carr'],
#  ['cobertur', 'servici'],
#  ['mal', 'aplic', 'radi', 'interrump', 'demaci'],
#  ['lent'],
#  ['logr',
#   'ingres',
#   'aparec',
#   'deb',
#   'asoci',
#   'cuent',
#   'problem',
#   'hac',
#   'rat'],
#  ['primer', 'version', 'clar', 'mir', 'encuentr', 'opcion', 'pas', 'tiemp'],
#  ['señal', 'red', 'baj'],
#  ['pesim', 'servici', 'general'],
#  ['dej', 'pag', 'tarjey'],
#  ['mal'],
#  ['ahor', 'empec', 'usarl'],
#  ['malooo', 'servici', 'factur', 're', 'mal'],
#  ['inscrib', 'eleg', 'famili', 'amig', 'funcion'],
#  ['cobr', 'mas', 'coj', 'bien', 'internet'],
#  ['nuev',
#   'line',
#   'sig',
#   'recib',
#   'llam',
#   'mensaj',
#   'titul',
#   'anterior',
#   'tal',
#   'motiv',
#   'pued',
#   'descarg',
#   'app',
#   'nequi'],
#  ['pued', 'cerr', 'sesion'],
#  ['pued', 'hac', 'llam', 'internacional'],
#  ['mal', 'servici'],
#  ['ofrec', 'servici', 'descarg', 'si', 'funcion'],
#  ['pud', 'registr', 'equip'],
#  ['deb', 'ten', 'chat'],
#  ['mal', 'señal'],
#  ['nunc',
#   'atiend',
#   'person',
#   'maquin',
#   'satisfac',
#   'dud',
#   'adem',
#   'cancel',
#   'tiemp',
#   'siempr',
#   'tan',
#   'mand',
#   'mensaj',
#   'cobr'],
#  ['ingres', 'ocasion', 'detien'],
#  ['señal',
#   'pesim',
#   'pod',
#   'conect',
#   'smart',
#   'tv',
#   'internet',
#   'señal',
#   'comun',
#   '7n',
#   'asesor',
#   'pesim'],
#  ['pag', 'registr'],
#  ['rob', 'recarg'],
#  ['servici', 'personaliz', 'servici', 'dat', 'cual'],
#  ['servici', 'bloqu', 'injust'],
#  ['encuentr', 'solucion', 'inconvenient'],
#  ['mal', 'cobertur', 'vari', 'punt'],
#  ['permit', 'registr', 'equip'],
#  ['intent', 'hac', 'recarg', 'tres', 'vec', 'dej', 'hac'],
#  ['demor', 'tom', 'pel', 'hac', 'compr', 'sald'],
#  ['señal', 'internet', 'lent', 'mal', 'servici', 'demasi'],
#  ['facil', 'acces', 'inform', 'servici', 'robot', 'restring'],
#  ['deb',
#   'quit',
#   'opcion',
#   'pag',
#   'compr',
#   'paquet',
#   'recarg',
#   'dej',
#   'inclu',
#   'factur',
#   'much',
#   'vec',
#   'compr',
#   'siempr'],
#  ['inform', 'dan', 'inform', 'complet'],
#  ['aparec', 'clar', 'hog', 'sol', 'movil'],
#  ['atencion', 'asesor', 'tiemp', 'esper', 'pes'],
#  ['pued',
#   'cambi',
#   'numer',
#   'cc',
#   'esti',
#   'nombr',
#   'mam',
#   'ahor',
#   'necesit',
#   'nombr',
#   'posibl'],
#  ['complic', 'pag', 'quier', 'compr', 'app', 'pued', 'pag', 'ahorr', 'man'],
#  ['encuentr', 'buen', 'asistent', 'quer', 'hac', 'reclam', 'peticion'],
#  ['aplic'],
#  ['maner', 'actualiz', 'dat'],
#  ['encuentr', 'opcion', 'necesari', 'ademas', 'public', 'engañ'],
#  ['pued', 'pag', 'mifactur', 'sistem', 'reconoc', 'numer', 'mifactur'],
#  ['funcion'],
#  ['servici', 'intermitent'],
#  ['servici', 'client', 'proced', 'suspencion', 'lin', 'telefon', 'arbitrari'],
#  ['atencion',
#   'servici',
#   'client',
#   'ecuentr',
#   'quien',
#   'dirig',
#   'soport',
#   'portabil',
#   'proet'],
#  ['deb', 'qued', 'tod', 'llam', 'registr', 'salient', 'entrant'],
#  ['permit', 'realiz', 'pag'],
#  ['sirv'],
#  ['deberi', 'funcion', 'dat', 'erramient', 'consult'],
#  ['denunci', 'rob', 'equip', 'bloqu'],
#  ['servici', 'client'],
#  ['inutil',
#   'comunic',
#   'call',
#   'cent',
#   'automatiz',
#   'necesit',
#   'habl',
#   'gent',
#   'real',
#   'brind',
#   'solucion',
#   'llam',
#   'caen'],
#  ['sab', 'aprob', 'credit'],
#  ['mal', 'señal'],
#  ['dej', 'ingres', 'cuent'],
#  ['mal', 'señal', 'dond', 'viv', 'cobertur', 'anten'],
#  ['actualiz',
#   'inform',
#   'tiemp',
#   'hac',
#   'recarg',
#   'aparec',
#   'registr',
#   'maner',
#   'inmediat'],
#  ['chat',
#   'solicit',
#   'respuest',
#   'asesor',
#   'siempr',
#   'dic',
#   'conexion',
#   'cae',
#   'piens',
#   'finaliz',
#   'chat',
#   'dar',
#   'respuest'],
#  ['graci'],
#  ['solucion',
#   'peticion',
#   'habl',
#   'accesor',
#   'atiend',
#   'clar',
#   'cre',
#   'dueñ',
#   'numer'],
#  ['servici'],
#  ['hic', 'recarg', 'descont', 'mont', 'activ', 'recarg'],
#  ['pued', 'pag', 'servici', 'hog', 'opcion'],
#  ['internet',
#   'relent',
#   'moment',
#   'dond',
#   'funcion',
#   'ciud',
#   'va',
#   'señal',
#   'dat',
#   'cog',
#   'quier',
#   'llam',
#   'clar',
#   'siempr',
#   'reinic'],
#  ['facebook', 'funcion', 'internet', 'wifi', 'dej', 'ver', 'conten'],
#  ['gust'],
#  ['permit', 'asoci', 'numer', 'post', 'pag', 'aplic'],
#  ['permit', 'activ', 'benefici', 'clar'],
#  ['car'],
#  ['quit',
#   'sald',
#   'compr',
#   'paquet',
#   'cans',
#   'llam',
#   'ver',
#   'suced',
#   'respuest',
#   'parec',
#   'mal',
#   'servici'],
#  ['aparec', 'solucion', 'movil', 'hog'],
#  ['entiend', 'dej', 'realiz', 'oper', 'busc'],
#  ['lent'],
#  ['sirv',
#   'da',
#   'solucion',
#   'client',
#   'ahi',
#   'sol',
#   'escrib',
#   'convien',
#   'empres'],
#  ['quej', 'recl', 'atencion', 'usuari'],
#  ['aparec', 'opcion', 'realiz', 'quej', 'reclam'],
#  ['mal', 'señal', 'voz', 'dat'],
#  ['pid', 'acces', 'quier', 'auroriz'],
#  ['registr', 'avec'],
#  ['pesim', 'servici', 'tecnic', 'servici', 'client'],
#  ['quier', 'averigu', 'clar', 'hog', 'permit'],
#  ['chat', 'pued', 'pregunt', 'si', 'manej', 'app', 'servici', 'client'],
#  ['respuest', 'clar', 'pregunt', 'ningun', 'respuest', 'empres'],
#  ['señal'],
#  ['play', 'stor', 'prepag'],
#  ['requier',
#   'activ',
#   'puert',
#   'pod',
#   'trabaj',
#   'impos',
#   'atiend',
#   'pesim',
#   'atencion'],
#  ['segu', 'cobr', 'cort', 'plan'],
#  ['lentitud', 'amig', 'intuit', 'confus'],
#  ['siempr',
#   'realiz',
#   'pag',
#   'factur',
#   'medi',
#   'entid',
#   'bancari',
#   'convirt',
#   'problem',
#   'registt',
#   'pag',
#   'tiemp'],
#  ['ladron'],
#  ['impos', 'solicit', 'visit', 'tecnic'],
#  ['xxx'],
#  ['inconvenient',
#   'sim',
#   'clar',
#   'solucion',
#   'dis',
#   'aser',
#   'ame',
#   'principal',
#   'culp',
#   'bloque',
#   'sim'],
#  ['sal', 'imei', 'duplic', 'intent', 'registr', 'funcion'],
#  ['acced', 'logr', 'encontr', 'inform', 'necesit', 'aunqu', 'rap', 'app'],
#  ['app',
#   'funcion',
#   'internet',
#   'mal',
#   'casi',
#   'nunc',
#   'señal',
#   'unic',
#   'lleg',
#   'mensaj',
#   'text',
#   'toc',
#   'pag'],
#  ['sirv', 'esencial'],
#  ['atencion', 'usuari', 'wassapp'],
#  ['cobr', 'pact', 'factur'],
#  ['contest'],
#  ['sirv', 'aplic', 'pod', 'ingres', 'hac', 'dias'],
#  ['facil', 'aplic'],
#  ['veo', 'util'],
#  ['porqu', 'servici', 'ladron'],
#  ['posibl', 'ingres', 'app'],
#  ['entiend', 'valor', 'factur', 'pag', 'lleg', 'alto', 'veint', 'mil', 'pes'],
#  ['servici',
#   'hog',
#   'llev',
#   'mes',
#   'servici',
#   'pesim',
#   'remal',
#   'asta',
#   'moment',
#   'servici',
#   'toc',
#   'esper',
#   'asta'],
#  ['recarg', 'paquet', 'consum', 'instant'],
#  ['nunc', 'pued', 'pag', 'desact', 'bloque'],
#  ['dej', 'asoci', 'cuent'],
#  ['inform', 'suficient', 'form', 'comunic', 'algun', 'asesor'],
#  ['utiliz', 'cuent', 'corre'],
#  ['nunc', 'atiend', 'peticion', 'pesim', 'internet', 'preci', 'tal', 'alto'],
#  ['hac',
#   'dos',
#   'mes',
#   'trat',
#   'cambi',
#   'clav',
#   'sid',
#   'posibl',
#   'llam',
#   'clar',
#   'den',
#   'informacion',
#   'porq',
#   'tampoc',
#   'solucion'],
#  ['quier', 'cabxel', 'plan', 'pon', 'mas', 'trab'],
#  ['x',
#   'recib',
#   'factur',
#   'clar',
#   'hog',
#   'baj',
#   'cotiz',
#   'pas',
#   'dias',
#   'servici',
#   'suspend',
#   'notif'],
#  ['lent', 'algun', 'vec'],
#  ['avec',
#   'posibl',
#   'entrar',
#   'ala',
#   'app',
#   'apart',
#   'llam',
#   'pesim',
#   'servici',
#   'comunic'],
#  ['cuent',
#   'usuari',
#   'perd',
#   'antigüed',
#   'clar',
#   'quer',
#   'volv',
#   'retom',
#   'servici',
#   'descuent',
#   'pandemi',
#   'urgent'],
#  ['envi',
#   'factur',
#   'notif',
#   'tiemp',
#   'despues',
#   'dic',
#   'usuari',
#   'person',
#   'pag',
#   'deud',
#   'tiemp',
#   'fin',
#   'mal',
#   'servici'],
#  ['much', 'cos', 'pantall', 'deb', 'ser', 'simpl', 'veo', 'hac', 'pasatiemp'],
#  ['da', 'respuest'],
#  ['promet',
#   'dijeron',
#   'clar',
#   'music',
#   'propagand',
#   'ciert',
#   'dic',
#   'mes',
#   'gratis',
#   'lueg',
#   'pag'],
#  ['servici', 'funcion', 'bien', 'part', 'ver', 'vide', 'internet'],
#  ['q',
#   'dieron',
#   'promocion',
#   'tres',
#   'mes',
#   'apart',
#   'dijeron',
#   'tendri',
#   'line',
#   'fij'],
#  ['encuentr', 'opcion', 'desactiv', 'public'],
#  ['mal', 'inform', 'servici'],
#  ['quier', 'sab', 'cuent', 'hog', 'cancel', 'pued'],
#  ['motiv', 'señal', 'comun', 'red', 'tan', 'buen', 'region'],
#  ['entiend', 'dur', 'minut', 'eligido6'],
#  ['maner', 'hac', 'co', 'sult', 'as', 'hor', 'internet'],
#  ['recib', 'elgid'],
#  ['rezachaz'],
#  ['solucion',
#   'problem',
#   'his',
#   'pag',
#   'instruccion',
#   'si',
#   'internet',
#   'estab',
#   'mal',
#   'sig',
#   'mal',
#   'dia'],
#  ['eleg'],
#  ['hol'],
#  ['inform', 'drl', 'modem'],
#  ['dijeron',
#   'famili',
#   'amig',
#   'cost',
#   'hoy',
#   'recib',
#   'factur',
#   'veo',
#   'nunc',
#   'pud',
#   'usar',
#   'siempr',
#   'sal',
#   'numer',
#   'inscrit',
#   'sald'],
#  ['funcion', 'deb', 'ten'],
#  ['permit',
#   'envi',
#   'mensaj',
#   'cambi',
#   'clav',
#   'wifi',
#   'apares',
#   'error',
#   'llav',
#   'aplic',
#   'hag',
#   'cambi',
#   'clav'],
#  ['encuentr', 'opcion', 'recarg', 'celul'],
#  ['llev',
#   'dias',
#   'pod',
#   'hac',
#   'llam',
#   'dan',
#   'solucion',
#   'burl',
#   'pag',
#   'si',
#   'oportun',
#   'necesit',
#   'respuest'],
#  ['problem',
#   'internet',
#   'factur',
#   'dificil',
#   'contact',
#   'acesor',
#   'despej',
#   'dud',
#   'pesim',
#   'atencion'],
#  ['registr',
#   'plan',
#   'cuent',
#   'muestr',
#   'error',
#   'non',
#   'asesor',
#   'comercial',
#   'dij',
#   'arregl',
#   'moment',
#   'clar',
#   'fals'],
#  ['nunc', 'asesor', 'line'],
#  ['hac',
#   'rat',
#   'trat',
#   'cambi',
#   'contraseñ',
#   'wifi',
#   'result',
#   'impos',
#   'pod',
#   'encontr',
#   'opcion'],
#  ['red', 'internet', 'señal', 'selul', 'avec', 'mal'],
#  ['realiz', 'carg', 'plan', 'compr'],
#  ['actualiz', 'factur', 'nuev', 'servici', 'hog'],
#  ['califuc'],
#  ['mal', 'servici'],
#  ['dej', 'ver', 'product', 'plan', 'celul', 'sol', 'dej', 'ver', 'hog'],
#  ['pued', 'habl', 'asesor', 'quej', 'rob'],
#  ['rob', 'sald', 'dej', 'usar', 'ladron'],
#  ['detall', 'consum', 'fech', 'activ', 'vencimient'],
#  ['xx'],
#  ['necesit',
#   'sac',
#   'equip',
#   'celul',
#   'neg',
#   'credit',
#   'plan',
#   'celul',
#   'hac',
#   'tiemp',
#   'deb'],
#  ['ok'],
#  ['dieron', 'solucion', 'problem'],
#  ['cobr', 'servici', 'estipul'],
#  ['servici', 'client', 'llam', 'demor', 'nefast'],
#  ['plan', 'ilimit', 'resuslt', 'mensaj', 'text'],
#  ['b', 'hi', 'nj'],
#  ['inform', 'medi', 'paquet', 'adquir', 'deb', 'mostr', 'hor', 'vencimient'],
#  ['mal', 'informacion'],
#  ['llev',
#   'mes',
#   'trat',
#   'comunic',
#   'usted',
#   'pues',
#   'necesit',
#   'cambi',
#   'contraseñ',
#   'internet',
#   'pod',
#   'veo',
#   'dispuest',
#   'cambi',
#   'oper'],
#  ['agend', 'turn', 'sirv'],
#  ['gust',
#   'opcion',
#   'pod',
#   'habl',
#   'consultor',
#   'realiz',
#   'solucion',
#   'consumidor',
#   'tedios',
#   'llam'],
#  ['ae',
#   'pued',
#   'diafrut',
#   'benefici',
#   'registr',
#   'si',
#   'usa',
#   'chat',
#   'pers',
#   'tiemp',
#   'ineficient'],
#  ['much', 'vec', 'compr', 'conten', 'app', 'hac', 'compr', 'lleg', 'conten'],
#  ['requier'],
#  ['inici', 'sesion', 'aparec', 'mensaj', 'abiert', 'disposit'],
#  ['funcion'],
#  ['put',
#   'mierd',
#   'servici',
#   'hog',
#   'encim',
#   'contest',
#   'lin',
#   'atencion',
#   'asquer'],
#  ['mejor', 'servici', 'señal', 'dat', 'lent'],
#  ['sabri',
#   'dec',
#   'si',
#   'si',
#   'famili',
#   'amig',
#   'activ',
#   'demas',
#   'año',
#   'quer',
#   'activ',
#   'asta',
#   'hoy',
#   'pud',
#   'logr',
#   'dur'],
#  ['pag', 'plan', 'minim', 'pued', 'hac', 'medi', 'pag'],
#  ['benefici', 'occion'],
#  ['pag', 'financi', 'equip', 'enrred', 'clarid', 'transparent'],
#  ['lleg', 'mensaj', 'duplic', 'plan', 'total', 'fals'],
#  ['casi', 'nunc', 'funcion'],
#  ['deb',
#   'funcion',
#   'dat',
#   'wifi',
#   'vec',
#   'necesit',
#   'recarg',
#   'solucion',
#   'problem',
#   'wifi',
#   'dat',
#   'wifi',
#   'funci'],
#  ['chat',
#   'bot',
#   'perd',
#   'tiemp',
#   'modific',
#   'app',
#   'opcion',
#   'clar',
#   'hog',
#   'desaparec',
#   'aap'],
#  ['solucion'],
#  ['trat',
#   'cambi',
#   'clav',
#   'wifi',
#   'casi',
#   'impos',
#   'siempr',
#   'mand',
#   'inform',
#   'corre',
#   'viej',
#   'sig',
#   'cambi',
#   'clav',
#   'mehak'],
#  ['app',
#   'dej',
#   'consult',
#   'tiend',
#   'dic',
#   'pued',
#   'carg',
#   'pagin',
#   'muestr',
#   'celular',
#   'vent'],
#  ['intent',
#   'muestr',
#   'factur',
#   'clar',
#   'hog',
#   'aparec',
#   'ningun',
#   'lad',
#   'sol',
#   'aparec',
#   'celul'],
#  ['respondi', 'solicit'],
#  ['drja', 'ver', 'factur', 'pag'],
#  ['lent', 'pagin', 'ventan'],
#  ['sirv', 'pag', 'sald', 'solicit', 'unnpaz', 'salv'],
#  ['adquir',
#   'plan',
#   'usted',
#   'fij',
#   'pes',
#   'llev',
#   'dos',
#   'recib',
#   'pag',
#   'ningun',
#   'lleg',
#   'tal',
#   'valor',
#   'mil',
#   'pes',
#   'falt',
#   'seri'],
#  ['quier',
#   'cambi',
#   'plan',
#   'econom',
#   'opcion',
#   'sol',
#   'mejor',
#   'plan',
#   'dispon'],
#  ['bloqu', 'llam', 'vari', 'vec', 'solucion'],
#  ['caig', 'señal', 'tan', 'frecuent'],
#  ['hac', 'interact'],
#  ['simul', 'credit'],
#  ['pued', 'pag', 'tarjet', 'debit', 'sol', 'credit'],
#  ['servici', 'client'],
#  ['facil', 'baj', 'app'],
#  ['tel', 'favor', 'necesit'],
#  ['vec', 'lent'],
#  ['sal', 'menu'],
#  ['mal', 'servicion', 'llam'],
#  ['sirv', 'ofrec'],
#  ['señal'],
#  ['requier',
#   'servici',
#   'cuent',
#   'hog',
#   'està',
#   'app',
#   'restring',
#   'sol',
#   'line',
#   'movil'],
#  ['quier', 'adquir', 'netflix', 'app', 'funcion'],
#  ['aparec',
#   'cuent',
#   'clar',
#   'hog',
#   'np',
#   'pod',
#   'pag',
#   'factur',
#   'usted',
#   'cort',
#   'servici',
#   'avis',
#   'rob',
#   'pag',
#   'ppr',
#   'men'],
#  ['plan',
#   'nuev',
#   'clar',
#   'inclu',
#   'favorit',
#   'lleg',
#   'contrat',
#   'servici',
#   'colabor',
#   'asistent',
#   'automotriz'],
#  ['asta', 'moment', 'funcion', 'bien'],
#  ['llev', 'mes', 'problem', 'product', 'clar', 'hog', 'solucion', 'difinit'],
#  ['chat', 'encuentr', 'repuest', 'va', 'consult'],
#  ['nesecit',
#   'nuev',
#   'equip',
#   'pued',
#   'gestion',
#   'aun',
#   'deb',
#   'dos',
#   'cuot',
#   'equival',
#   'cambi',
#   'oper'],
#  ['servici', 'client'],
#  ['cad', 'vez', 'ingres', 'pid', 'asoci', 'cuent', 'logr', 'hac'],
#  ['inform', 'cuent', 'pag', 'realiz', 'anterior'],
#  ['problem',
#   'registaram',
#   'registr',
#   'pagin',
#   'dio',
#   'problem',
#   'esper',
#   'pued',
#   'aregl'],
#  ['inform',
#   'detall',
#   'apps',
#   'inclu',
#   'consum',
#   'recib',
#   'constant',
#   'mensaj',
#   'error'],
#  ['pued', 'cambi', 'plan', 'aunqu', 'bot', 'dic', 'si', 'pued'],
#  ['encuentr', 'solicit', 'atiend', 'requer', 'hech', 'vari', 'vec', 'telefon'],
#  ['conect'],
#  ['sirv'],
#  ['agend', 'cit'],
#  ['registr', 'dej', 'ver', 'factur'],
#  ['pued',
#   'entrar',
#   'quej',
#   'recl',
#   'cobr',
#   '7mil',
#   'pes',
#   'factur',
#   'plan',
#   'cerr'],
#  ['pued', 'hac', 'recarg', 'pag', 'tarjet'],
#  ['da', 'solucion', 'pued', 'report', 'fall', 'funcion', 'internet', 'movil'],
#  ['mejor', 'promocion'],
#  ['internet', 'lent'],
#  ['asesor',
#   'respond',
#   'llam',
#   'mal',
#   'servici',
#   'internet',
#   'dan',
#   'solucion'],
#  ['mal', 'señal'],
#  ['aparec', 'opcion', 'busqued'],
#  ['limit',
#   'client',
#   'cas',
#   'necesit',
#   'orientacion',
#   'suspension',
#   'temporal',
#   'servici',
#   'pued',
#   'acced',
#   'infornacion'],
#  ['encontr', 'punt', 'autoriz', 'ubic', 'vez', 'qued', 'perd'],
#  ['pued', 'cancel', 'suscripcion', 'dijeron', 'chat'],
#  ['necesit',
#   'cancel',
#   'plan',
#   'movil',
#   'cambi',
#   'econom',
#   'encuentr',
#   'opcion',
#   'hac',
#   'colabor',
#   'favor'],
#  ['facil', 'naveg', 'encontr', 'product'],
#  ['pued',
#   'acced',
#   'clar',
#   'vide',
#   'registr',
#   'contraseñ',
#   'permit',
#   'cambi',
#   'envi',
#   'inici',
#   'sesion'],
#  ['servici',
#   'clar',
#   'hog',
#   'ocasion',
#   'regul',
#   'app',
#   'dej',
#   'sult',
#   'valor',
#   'pag',
#   'clar',
#   'hog'],
#  ['veo', 'cuent', 'movil'],
#  ['permit', 'agreg', 'eleg'],
#  ['opcion',
#   'valid',
#   'registr',
#   'llam',
#   'line',
#   'ejempl',
#   'pued',
#   'ver',
#   'llam',
#   'dia',
#   'anterior'],
#  ['recarg',
#   'movil',
#   'app',
#   'facebook',
#   'permit',
#   'ver',
#   'imagen',
#   'pregunt',
#   'usar',
#   'dat',
#   'ver',
#   'vide'],
#  ['necesit', 'ver', 'equip', 'financi', 'sal', 'gener', 'factur'],
#  ['dinam'],
#  ['pud', 'asoci', 'cuent', 'product', 'aparec'],
#  ['fall', 'dat'],
#  ['internet',
#   'pesim',
#   'ayer',
#   'cancel',
#   'consult',
#   'virtual',
#   'mujer',
#   'terribl',
#   'hoy',
#   'ven',
#   'cbi',
#   'modem',
#   'avis'],
#  ['mal',
#   'servici',
#   'line',
#   'atencion',
#   'client',
#   'much',
#   'ocasion',
#   'señal',
#   'regul'],
#  ['report', 'consum', 'dat'],
#  ['servici', 'pes', 'internet', 'mantien', 'caid', 'cad', 'rat'],
#  ['pesim', 'servici', 'client'],
#  ['tip', 'internet', 'clav', 'complic'],
#  ['mejor', 'ceñal', 'veloc', 'mism'],
#  ['trat', 'ingres', 'seguimient', 'envi', 'terribl', 'pued', 'ingres'],
#  ['mal', 'servici'],
#  ['respond', 'mensaj', 'visit', 'tecnic', 'aparec', 'ningun', 'opcion'],
#  ['sirv', 'ayud', 'client', 'inconvenient', 'tecnic'],
#  ['cambi', 'tarif', 'avis'],
#  ['hac', 'adelant', 'sald', 'pag', 'cuand', 'recarg'],
#  ['clar', 'dan', 'opcion', 'baj', 'plan'],
#  ['encontr', 'inform', 'paquet', 'hbo'],
#  ['sald', 'dej', 'comun', 'moment', 'necesit', 'llam', 'dic', 'sald'],
#  ['permit',
#   'solicit',
#   'cambi',
#   'solicitud',
#   'sol',
#   'dic',
#   'plan',
#   'benefici',
#   'si',
#   'quier',
#   'pued',
#   'solicit',
#   'condicion'],
#  ['pued', 'ver', 'cacit', 'clar', 'hog'],
#  ['dic', 'cobertur', 'señal', 'siempr', 'baj', 'inest'],
#  ['com',
#   'posibl',
#   'señal',
#   'dat',
#   'pued',
#   'llam',
#   'celul',
#   'porq',
#   'sal',
#   'sol',
#   'llam',
#   'emergent'],
#  ['servici', 'internet', 'pesim'],
#  ['dese', 'pag', 'cuent', 'sal'],
#  ['pud', 'hac', 'recarg', 'celul'],
#  ['ubier', 'medi', 'pag'],
#  ['dej', 'registr', 'desasoci', 'eleg', 'servici', 'postpag', 'fij'],
#  ['trat', 'ver', 'factur', 'sal', 'nombr', 'veo', 'clar', 'hog'],
#  ['aplic'],
#  ['clar', 'cobr', 'supuest', 'servici', 'app', 'aparec'],
#  ['aparec', 'opcion', 'revis', 'cuent', 'clar', 'hog'],
#  ['dis',
#   'ofrec',
#   'meg',
#   'dand',
#   'sol',
#   'meg',
#   'cumpl',
#   'promet',
#   'client',
#   'si',
#   'ciert',
#   'esper',
#   'mensaj'],
#  ['cae', 'señal'],
#  ['pied', 'comunic', 'algui', 'aclar', 'vari', 'dud'],
#  ['pesim',
#   'atencion',
#   'mal',
#   'servici',
#   'destac',
#   'porqu',
#   'siqu',
#   'factur',
#   'bien',
#   'cobr',
#   'dem',
#   'complet',
#   'rob'],
#  ['ten', 'veloc', 'internet'],
#  ['sal', 'wl', 'cresit'],
#  ['mal', 'servici', 'dat', 'voz', 'vent', 'engañ'],
#  ['sal',
#   'palabr',
#   'complet',
#   'necesit',
#   'sab',
#   'fech',
#   'vencimient',
#   'plan',
#   'aparec',
#   'fech',
#   'incorrect',
#   'mes',
#   'duracion'],
#  ['nunc', 'funcion'],
#  ['escond',
#   'opcion',
#   'pqr',
#   'nunc',
#   'podes',
#   'solicit',
#   'revision',
#   'tecnic',
#   'servici',
#   'fij'],
#  ['compliqu', 'pag', 'line'],
#  ['fall', 'conect'],
#  ['clar', 'facilit', 'servici'],
#  ['trat',
#   'rob',
#   'cuent',
#   'dos',
#   'vec',
#   'espos',
#   'rob',
#   'sac',
#   'cuent',
#   'netflix',
#   'entonc',
#   'segur'],
#  ['mal',
#   'serbisi',
#   'promet',
#   'cos',
#   'client',
#   'factur',
#   'apares',
#   'boy',
#   'cambi',
#   'empres',
#   'mism',
#   'rason'],
#  ['llev',
#   'dias',
#   'esper',
#   'solucion',
#   'television',
#   'siempr',
#   'sal',
#   'excus',
#   'si',
#   'mand',
#   'factur',
#   'pag',
#   'puntual',
#   'pesim',
#   'servici'],
#  ['posibl',
#   'ingres',
#   'clar',
#   'hog',
#   'pued',
#   'consult',
#   'opcion',
#   'realiz',
#   'consult',
#   'pag'],
#  ['trat', 'asoci', 'app', 'empres', 'numer', 'registr', 'sid', 'posibl'],
#  ['teneteng',
#   'servici',
#   'hog',
#   'ahor',
#   'ingres',
#   'poatpag',
#   'celul',
#   'encuentr',
#   'inform',
#   'graci'],
#  ['moment',
#   'ingres',
#   'dat',
#   'tarjet',
#   'dic',
#   'pued',
#   'efectu',
#   'pag',
#   'pued',
#   'tarjet',
#   'credit',
#   'asi'],
#  ['posibl', 'encontr', 'inclu', 'line', 'prepag', 'tampoc', 'ver', 'hog'],
#  ['pued', 'ingres', 'eleg'],
#  ['reflej', 'inmediat', 'pag'],
#  ['señal', 'intermitent'],
#  ['compr', 'plan', 'mg', 'sol', '10mg'],
#  ['lent', 'sal', 'dej', 'termin', 'transaccion', 'terribl', 'dec', 'nefast'],
#  ['pork',
#   'necesit',
#   'inform',
#   'acerc',
#   'escandal',
#   'cobr',
#   'factur',
#   'eh',
#   'recib',
#   'respuest',
#   'hag'],
#  ['gui', 'manej', 'ejempl', 'marc', 'internacional'],
#  ['nunc', 'dan', 'respuest', 'nunc', 'solucikn'],
#  ['señal', 'pobr', 'lent', 'internet'],
#  ['trasl', 'servici', 'pesim'],
#  ['fall', 'recarg', 'siempr', 'asi'],
#  ['demor', 'respond', 'cualqui', 'solicitud'],
#  ['minut', 'costos', 'pued', 'hac', 'adelant', 'sal'],
#  ['pod', 'agreg', 'comun', 'amig', 'famili', 'numer', 'necesit', 'explic'],
#  ['vari',
#   'product',
#   'sol',
#   'muestr',
#   'servici',
#   'movil',
#   'servici',
#   'empresarial',
#   'hog',
#   'descarg',
#   'factur'],
#  ['pued', 'hac', 'recarg', 'inclu', 'factur', 'clar', 'hog'],
#  ['poc', 'inform', 'atencion'],
#  ['moment',
#   'agreg',
#   'contact',
#   'ser',
#   'ilimit',
#   'dic',
#   'list',
#   'llen',
#   'ningun',
#   'moment',
#   'eh',
#   'usad',
#   'servici'],
#  ['falt', 'product'],
#  ['plataform',
#   'practic',
#   'dig',
#   'quier',
#   'met',
#   'eleg',
#   'llam',
#   'impos',
#   'encontr',
#   'requer',
#   'veo',
#   'necesi'],
#  ['opcion', 'report', 'quej', 'recl', 'medi'],
#  ['señal', 'dat', 'internet', 'plan', 'correspond', 'lent', 'pie', 'anten'],
#  ['solucion', 'inquietud'],
#  ['ladron', 'mañan', 'cancel', 'line'],
#  ['quier',
#   'sab',
#   'sald',
#   'voz',
#   'dat',
#   'facilit',
#   'pid',
#   'demasi',
#   'dat',
#   'registr',
#   'public'],
#  ['dej', 'ingres', 'brnrficis', 'app'],
#  ['nunc', 'da', 'solucion', 'problem', 'demor'],
#  ['encuentr', 'facil', 'servici', 'requer'],
#  ['soluion', 'problem'],
#  ['descuent', 'product', 'consum'],
#  ['encuentr', 'informacion', 'facil', 'lent'],
#  ['confus'],
#  ['sol',
#   'muestr',
#   'clar',
#   'movil',
#   'line',
#   'hog',
#   'pod',
#   'pag',
#   'facil',
#   'rap'],
#  ['cobertur'],
#  ['bien'],
#  ['graci'],
#  ['sirv', 'quej'],
#  ['necesit',
#   'visit',
#   'tecnic',
#   'dan',
#   'respuest',
#   'dificil',
#   'agend',
#   'visit',
#   'medi',
#   'clar'],
#  ['registr', 'numer', 'famili'],
#  ['se', 'encuentr', 'com', 'pag', 'hog'],
#  ['dej', 'ver', 'servici'],
#  ['qued', 'algun', 'cuot', 'si', 'pag'],
#  ['paquet',
#   'mas',
#   'acces',
#   'preci',
#   'memor',
#   'mas',
#   'benefici',
#   'usuari',
#   'clar',
#   'graci'],
#  ['aparec', 'plan', 'pospag', 'consult'],
#  ['siempr', 'aparec', 'nombr', 'mal', 'escrit'],
#  ['llev', 'dos', 'dias', 'clar', 'fall', 'conexion'],
#  ['buen'],
#  ['sid', 'posibl', 'hac', 'recarg', 'carg', 'factur', 'clar', 'hog'],
#  ['gener', 'cobr', 'absurd', 'factur'],
#  ['pod', 'realiz', 'compr', 'product', 'medi', 'app', 'anterior', 'echo'],
#  ['ueuue'],
#  ['bien', 'recarg', 'pid', 'dat', 'parec', 'innecesari', 'funcion', 'bien'],
#  ['clarid', 'punt'],
#  ['internet', 'lent'],
#  ['n'],
#  ['registr', 'line', 'sal', 'plan', 'nesecit'],
#  ['sirv'],
#  ['sol', 'llev', 'minut', 'usandol'],
#  ['demor', 'carg'],
#  ['sugur', 'equip'],
#  ['medi', 'app', 'atencion', 'client', 'llam', 'vec', 'pid', 'hac', 'app'],
#  ['segur', 'suplant'],
#  ['resuelv'],
#  ['recib', 'meg', 'card'],
#  ['comun', 'consultor'],
#  ['si', 'des', 'conoc', 'inconform', 'arriend', 'llam', 'des', 'graci'],
#  ['inform', 'recib', 'paquet', 'anterior', 'correct'],
#  ['internet', 'puest', 'lent', 'quit', 'capac', 'cup'],
#  ['dej', 'ver', 'cuent', 'clar', 'hog'],
#  ['dej', 'registr', 'core'],
#  ['dificil', 'hac', 'reposicion', 'sim', 'card'],
#  ['pod', 'ahor', 'pued', 'carg', 'recarg', 'celul', 'factur', 'clar', 'hog'],
#  ['muestr', 'fech', 'hor', 'venc', 'paquet', 'compr'],
#  ['ingres',
#   'numer',
#   'prepag',
#   'clar',
#   'espos',
#   'dic',
#   'registr',
#   'entonc',
#   'entiend',
#   'com',
#   'hac',
#   'clar',
#   'respuest'],
#  ['sirv',
#   'necesit',
#   'factur',
#   'clar',
#   'hog',
#   'aparec',
#   'opcion',
#   'ningun',
#   'lad'],
#  ['dijeron',
#   'esper',
#   'minut',
#   'lueg',
#   'sal',
#   'mensaj',
#   'cancel',
#   'falt',
#   'respuest',
#   'sol',
#   'necesit',
#   'cancel',
#   'servivi'],
#  ['aplic', 'confus'],
#  ['adquir',
#   'product',
#   'sid',
#   'posibl',
#   'disfrut',
#   'bien',
#   'señal',
#   'lent',
#   'interrump'],
#  ['quier', 'entrar', 'clar', 'hog', 'permit'],
#  ['mejor', 'preci', 'paquet', 'promocion', 'dat'],
#  ['solucion', 'basur'],
#  ['kn'],
#  ['conr',
#   'constand',
#   'factur',
#   'quincen',
#   'dec',
#   'falt',
#   'dia',
#   'oar',
#   'quincen',
#   'impos',
#   'atac',
#   'mas',
#   'rus'],
#  ['inform',
#   'bien',
#   'quier',
#   'recuper',
#   'clav',
#   'clar',
#   'vide',
#   'ne',
#   'envi',
#   'corre',
#   'dic',
#   'dar',
#   'clik',
#   'aca',
#   'vuelv',
#   'llev',
#   'pag',
#   'clar',
#   'vide'],
#  ['accesibil', 'menud', 'present', 'demor', 'fall'],
#  ['sirv', 'adquir', 'plan', 'inmediat', 'recarg'],
#  ['pues', 'aves', 'pid', 'registr', 'vez', 'molest'],
#  ['car', 'demasi', 'car'],
#  ['pag'],
#  ['aparec', 'enlac', 'pag', 'factur'],
#  ['llam', 'señal', 'pesim'],
#  ['señal', 'pesim', 'moment'],
#  ['dan', 'solucion', 'problem'],
#  ['pued', 'ingres', 'clar', 'vide'],
#  ['pesim', 'app'],
#  ['entiend', 'rap'],
#  ['falt', 'inform', 'servici', 'contrat'],
#  ['comun', 'dificil'],
#  ['pod', 'consult', 'cup', 'dispon', 'compr'],
#  ['clar',
#   'vide',
#   'sirv',
#   'ped',
#   'repetidor',
#   'adquir',
#   'servici',
#   'nunc',
#   'lleg',
#   'lleg',
#   'factur',
#   'app',
#   'sirv',
#   'mal',
#   'servici'],
#  ['dej', 'acced', 'avmi', 'cuent', 'clar', 'hog', 'normal', 'haci'],
#  ['sient',
#   'descontent',
#   'usted',
#   'falt',
#   'respet',
#   'promet',
#   'servici',
#   'convenc',
#   'lueg',
#   'dic',
#   'promocion',
#   'verd',
#   'suspender'],
#  ['manipul', 'cup', 'financi', 'equip'],
#  ['señal', 'pesim'],
#  ['pas',
#   'plan',
#   'va',
#   'mil',
#   'pes',
#   'apart',
#   'quit',
#   'gig',
#   'sol',
#   'dieron',
#   'gig',
#   'descontent',
#   'servici'],
#  ['pas', 'autenticacion'],
#  ['ole'],
#  ['maa'],
#  ['cobertur', 'servici', 'internet', 'hog', 'television', 'siti', 'viviend'],
#  ['da', 'mism', 'van', 'dar', 'respuest'],
#  ['dificil', 'registr', 'clar', 'vide'],
#  ['encuentr', 'solucion', 'brind', 'inform', 'incomplet'],
#  ['senal', 'dat', 'viv', 'caid'],
#  ['servici', 'client'],
#  ['quier', 'averigu', 'equip'],
#  ['usted', 'unas', 'rat'],
#  ['solucion', 'servici'],
#  ['señal',
#   'clar',
#   'mes',
#   'diciembr',
#   'ven',
#   'present',
#   'much',
#   'fall',
#   'red',
#   '4g'],
#  ['visit',
#   'program',
#   'clar',
#   'hog',
#   'cancel',
#   'vec',
#   'pod',
#   'hac',
#   'seguimient',
#   'medi',
#   'aplic'],
#  ['app',
#   'permit',
#   'recarg',
#   'sald',
#   'aplic',
#   'aun',
#   'sald',
#   'dic',
#   'form',
#   'pag',
#   'tarjet',
#   'cual',
#   'pose'],
#  ['n'],
#  ['correct',
#   'envi',
#   'inform',
#   'line',
#   'mism',
#   'titul',
#   'si',
#   'asi',
#   'podr',
#   'solicit',
#   'servici',
#   'sol',
#   'pospag',
#   'line',
#   'prepag'],
#  ['falt', 'catalog', 'complet', 'smartwh'],
#  ['bloqu',
#   'cuent',
#   'hac',
#   'aproxim',
#   'mes',
#   'aparec',
#   'numer',
#   'prepag',
#   'carg',
#   'nombr',
#   'nunc',
#   'solicit'],
#  ['señal', 'debil', 'internet', 'baj'],
#  ['inform', 'dat', 'deb', 'ser', 'mas', 'visual', 'igual', 'fech', 'cort'],
#  ['pud', 'hac', 'pag'],
#  ['aplic',
#   'pag',
#   'factur',
#   'clar',
#   'hog',
#   'ahor',
#   'opcion',
#   'muestr',
#   'historial',
#   'pag'],
#  ['regal', 'cupon', 'clar', 'vide'],
#  ['dificil', 'ingres'],
#  ['habilit', 'plan', 'post', 'pag', 'men', 'preci', 'mil', 'maxim'],
#  ['facil', 'manej', 'deb', 'exist', 'tutorial'],
#  ['consig',
#   'sab',
#   'cual',
#   'chat',
#   'hog',
#   'usted',
#   'resuelv',
#   'ningun',
#   'medi'],
#  ['plan', 'costos'],
#  ['señal', 'cae', 'segu'],
#  ['cambi', 'equip', 'instal', 'aplic', 'dej', 'entrar', 'cuent', 'solucion'],
#  ['encuentr', 'opcion', 'aument', 'gig', 'clar'],
#  ['actualiz', 'permanent', 'hac', 'app', 'benefici'],
#  ['brind',
#   'buen',
#   'inform',
#   'adquir',
#   'plan',
#   'hog',
#   'fech',
#   'dic',
#   'busqu',
#   'seguimient',
#   'sal',
#   'apart',
#   'pon',
#   'fech',
#   'cumpl'],
#  ['pud', 'encontr', 'com', 'pag', 'plan', 'postpag', 'celul'],
#  ['lent'],
#  ['utilic',
#   'plan',
#   'dos',
#   'mes',
#   'necesit',
#   'descuent',
#   'factur',
#   'pod',
#   'cancel'],
#  ['contest'],
#  ['internet',
#   'mantien',
#   'caid',
#   'igual',
#   'servici',
#   'tel',
#   'fij',
#   'frustrant',
#   'teletrabaj',
#   'servici',
#   'mal',
#   'verd'],
#  ['internet', 'lent'],
#  ['dan', 'ningun', 'soport', 'real'],
#  ['atencion', 'oportun'],
#  ['dan', 'solucion'],
#  ['benefici',
#   'amig',
#   'familiar',
#   'unic',
#   'permit',
#   'llam',
#   'gratis',
#   'sol',
#   'numer',
#   'agreg'],
#  ['sal', 'men', 'factur', 'cancel'],
#  ['gustari',
#   'encontr',
#   'mas',
#   'clar',
#   'opcion',
#   'uso',
#   'conten',
#   'ingres',
#   'app'],
#  ['pud', 'volv', 'ver', 'dat', 'plan', 'pospag', 'form', 'pag', 'app'],
#  ['chat', 'deb', 'ser', 'person', 'maquin', 'da', 'solucion'],
#  ['caid', 'sistem'],
#  ['dej', 'carg', 'factur', 'hog', 'recarg'],
#  ['privac', 'dat', 'consum'],
#  ['impos', 'adquir', 'netflix', 'apres', 'registr'],
#  ['acuerd', 'valor', 'plan', 'empez', 'pag', 'distint'],
#  ['dat', 'lent', 'app', 'lent', 'red', 'caid'],
#  ['realiz',
#   'portabil',
#   'movist',
#   'oper',
#   'clar',
#   'manifest',
#   'valor',
#   'pag',
#   'lleg',
#   'valor',
#   'mas',
#   'alto'],
#  ['consult'],
#  ['bien'],
#  ['señal', 'dat', 'internet', 'pauperrim'],
#  ['demasi', 'opcion', 'facilit', 'busqued', 'app'],
#  ['inconform',
#   'aument',
#   'valor',
#   'factur',
#   'movil',
#   'solicit',
#   'plan',
#   'ido',
#   'aument',
#   'pag'],
#  ['mal', 'internet', 'señal'],
#  ['omit'],
#  ['engañ',
#   'veloc',
#   'internet',
#   'demasi',
#   'lent',
#   'sol',
#   'sirv',
#   'whatsapp',
#   'facebook'],
#  ['mal', 'servici', 'asesor'],
#  ['sal', 'llam'],
#  ['dan', 'obsion', 'mejor', 'plan', 'comunic', 'acesor'],
#  ['app', 'demasi', 'lent'],
#  ['paquet',
#   'inclu',
#   'wtf',
#   '1gb',
#   'vig',
#   'dias',
#   'activ',
#   'venc',
#   'mas',
#   'info',
#   'www',
#   'clar',
#   'com',
#   'co',
#   'activ',
#   'ciert',
#   'activ'],
#  ['llam', 'vec', 'cuelg', 'aca', 'tampoc', 'dan', 'solucion'],
#  ['dej', 'agreg', 'contact', 'amig'],
#  ['asco',
#   'cobr',
#   'cos',
#   'uso',
#   'pon',
#   'paquet',
#   'da',
#   'gan',
#   'porqu',
#   'empres'],
#  ['necesit',
#   'compr',
#   'paquet',
#   'inclu',
#   'voy',
#   'pag',
#   'daviplat',
#   'nequi',
#   'opcion',
#   'pag'],
#  ['nunc', 'lleg', 'recarg'],
#  ['opcion', 'renov', 'equip', 'sol', 'chat', 'lent'],
#  ['tant',
#   'cos',
#   'nos',
#   'ingres',
#   'hac',
#   'quier',
#   'revis',
#   'si',
#   'pued',
#   'compr',
#   'celu',
#   'cuot',
#   'clar',
#   'encuentr',
#   'opcion'],
#  ['chat', 'respond', 'solicitud', 'natali', 'hoy'],
#  ['caen', 'dat'],
#  ['llam', 'esper'],
#  ['dan', 'respuest', 'solicitud'],
#  ['cobertur', 'tenu', 'señal', 'demasi'],
#  ['xx'],
#  ['vec', 'servici', 'chat', 'lent'],
#  ['pued',
#   'cambi',
#   'clav',
#   'wifi',
#   'intent',
#   'vari',
#   'celular',
#   'pued',
#   'sol',
#   'dic',
#   'moment',
#   'pued',
#   'atend'],
#  ['supuest', 'cup', 'ahor', 'quit'],
#  ['realic',
#   'tres',
#   'llam',
#   'line',
#   'servici',
#   'client',
#   'hac',
#   'cambi',
#   'plan',
#   'tres',
#   'llam',
#   'dijeron',
#   'sistem'],
#  ['respuest', 'concret'],
#  ['informacion', 'avec', 'concuerd'],
#  ['mal', 'internet', 'cae', 'señal'],
#  ['usted',
#   'pregunt',
#   'si',
#   'recom',
#   'aclar',
#   'recom',
#   'aplic',
#   'total',
#   'diferent',
#   'aplic',
#   'veo',
#   'problemit',
#   'dificult'],
#  ['señal', 'mal', 'pesim'],
#  ['se', 'com', 'mir', 'factur', 'movil', 'financi'],
#  ['da', 'solucion', 'necesit'],
#  ['buen'],
#  ['pes', 'satisfac', 'client'],
#  ['demor', 'carg', 'lent'],
#  ['mañ'],
#  ['pued', 'acced', 'clar', 'hog'],
#  ['demor',
#   'solusion',
#   'problem',
#   'eleg',
#   'asign',
#   'plan',
#   'dej',
#   'ingres',
#   'si',
#   'internet',
#   'cae'],
#  ['encuentr',
#   'opcion',
#   'registr',
#   'imei',
#   'segun',
#   'indic',
#   'pagin',
#   'web',
#   'clar',
#   'colombi'],
#  ['opcion'],
#  ['eleg',
#   'famili',
#   'pued',
#   'comunic',
#   'mig',
#   'cost',
#   'segun',
#   'dic',
#   'public',
#   'necesit',
#   'sab',
#   'app',
#   'respuest'],
#  ['servici',
#   'client',
#   'pesim',
#   'complic',
#   'clar',
#   'vide',
#   'ingres',
#   'numer',
#   'eleg'],
#  ['pod',
#   'clu',
#   'product',
#   'usted',
#   'pued',
#   'icar',
#   'product',
#   'much',
#   'info',
#   'inutil'],
#  ['facil', 'agil'],
#  ['dat', 'plan', 'porqu', 'pued', 'entrar', 'aplic', 'facil', 'desastr'],
#  ['plan', 'actual', 'pued', 'compart', 'dat', 'gig', 'parec', 'absurd'],
#  ['cae'],
#  ['permit', 'revis', 'visit', 'tecnic', 'clar', 'hog'],
#  ['pod', 'comunic', 'ningun', 'asesor', 'informacion'],
#  ['ten',
#   'opcion',
#   'cancel',
#   'ten',
#   'llam',
#   'numer',
#   'contest',
#   'abus',
#   'suscrib',
#   'cos',
#   'pag',
#   'uso'],
#  ['com', 'recari', 'oper', 'sald'],
#  ['u'],
#  ['tiemp',
#   'respuest',
#   'sobretod',
#   'porqu',
#   'baj',
#   'ley',
#   'funcion',
#   'si',
#   'conect',
#   'vpn',
#   'acas',
#   'prohib',
#   'ley',
#   'colombian',
#   'regul'],
#  ['falt', 'opcion', 'contact', 'pon', 'quej'],
#  ['compr', 'paquet', 'voz', 'minut', 'pag', 'factur', 'moment', 'activ'],
#  ['pued', 'pag', 'tarjet', 'credit', 'daviviend', 'ingres', 'dat'],
#  ['aplic', 'clar', 'dej', 'ingres', 'siqu', 'ver', 'factur'],
#  ['graci', 'buen'],
#  ['servici', 'tan', 'mal', 'hor', 'tel', 'an', 'siev'],
#  ['person', 'inscrit', 'pod', 'llam'],
#  ['mensaj',
#   'lug',
#   'client',
#   'clar',
#   'mes',
#   'mes',
#   'cumpl',
#   'pag',
#   'hoy',
#   'demordoenel',
#   'pag',
#   'envi',
#   'mnsje',
#   'suspension',
#   'irrit',
#   'j'],
#  ['avec', 'internet', 'lent', 'pas', 'caid'],
#  ['mal', 'atencion', 'servici', 'client', 'incumpl', 'plan'],
#  ['pud', 'registr', 'equip'],
#  ['aparec',
#   'fech',
#   'cort',
#   'factur',
#   'dej',
#   'ver',
#   'pag',
#   'realiz',
#   'factur',
#   'cort',
#   'actual'],
#  ['segun', 'app', 'servici', 'clar', 'pued', 'realiz', 'pag'],
#  ['mejor', 'señal'],
#  ['mal'],
#  ['pued', 'recarg', 'line', 'sald', 'line'],
#  ['numer',
#   'aparec',
#   'app',
#   'mio',
#   'nadi',
#   'da',
#   'razon',
#   'realiz',
#   'tramit',
#   'busc',
#   'asesor',
#   'sab',
#   'omit',
#   'inform'],
#  ['trat',
#   'comunic',
#   'oper',
#   'ime',
#   'equip',
#   'registr',
#   'dej',
#   'sal',
#   'llam',
#   'nesesit',
#   'solucion'],
#  ['quier', 'ingres', '4lin', 'telefon', 'llam', 'gratis', 'encuentr', 'facil'],
#  ['pued', 'asoci', 'negr', 'celul'],
#  ['mal', 'cobertur'],
#  ['caig', 'men', 'red'],
#  ['manten', 'minut', 'usad', 'tiemp'],
#  ['cobertur', 'meg', 'vec', 'wassap', 'sirv', 'demor'],
#  ['cad', 'vez', 'quit', 'benefici', 'client'],
#  ['mal', 'calid', 'product'],
#  ['com', 'mierd'],
#  ['pas',
#   'pospag',
#   'sol',
#   'aparec',
#   'cuent',
#   'hog',
#   'dieron',
#   'pin',
#   'clar',
#   'vide',
#   'gig',
#   'duplic',
#   'ningun',
#   'servici'],
#  ['recarg', 'paquet', 'autoriz', 'rob', 'minut'],
#  ['deb', 'ser', 'obligatori', 'registr'],
#  ['solucion'],
#  ['lleg', 'mensaj', 'celul'],
#  ['quier', 'cancel', 'servici'],
#  ['acept', 'contraseñ'],
#  ['aparecen',
#   'servici',
#   'corre',
#   'aparec',
#   'anclad',
#   'cuent',
#   'mal',
#   'servici',
#   'pesim',
#   'plataform'],
#  ['aparesc', 'tod', 'lin', 'nombr', 'clar'],
#  ['disponibil', 'servici', 'demor', 'gestion'],
#  ['util'],
#  ['lleg',
#   'mensaj',
#   'cobr',
#   'cos',
#   'porez',
#   'piens',
#   'retir',
#   'cambi',
#   'oper',
#   'graci'],
#  ['lent', 'internet', 'solicitud', 'envi', 'respond'],
#  ['permit',
#   'ten',
#   'registr',
#   'plan',
#   'movil',
#   'plan',
#   'hog',
#   'mism',
#   'tiemp',
#   'veo',
#   'pued',
#   'anex',
#   'cuent',
#   'hog',
#   'pendient',
#   'del',
#   'factur'],
#  ['comienz', 'dificil', 'adapt'],
#  ['aparec', 'product', 'clar'],
#  ['hag', 'recarg', 'activ', 'paquet'],
#  ['poc', 'promocion', 'agot', 'rap'],
#  ['sirv', 'diari', 'señal', 'mal', 'funcion'],
#  ['mal', 'senal'],
#  ['lent', 'mal', 'internet', 'siend', '4g'],
#  ['pued', 'cancel', 'plan'],
#  ['pued', 'acced', 'clar', 'hog', 'consult', 'pag', 'etc'],
#  ['permit',
#   'seleccion',
#   'servici',
#   'line',
#   'movil',
#   'sol',
#   'configur',
#   'servici',
#   'hog'],
#  ['pud', 'registr', 'numer', 'famili', 'amig'],
#  ['atencion',
#   'personaliz',
#   'traves',
#   'herramient',
#   'garant',
#   'equip',
#   'compr'],
#  ['señal', 'part', 'mal'],
#  ['servici', 'client'],
#  ['menu', 'complej', 'posibl', 'acced', 'pag', 'line', 'movil'],
#  ['extrem',
#   'lent',
#   'pag',
#   'servici',
#   'deb',
#   'intent',
#   'vari',
#   'vec',
#   'dia',
#   'cuot',
#   'celul',
#   'envi',
#   'mensaj',
#   'bloqu',
#   'clr'],
#  ['dej',
#   'cancel',
#   'factur',
#   'clar',
#   'hog',
#   'aparec',
#   'opcion',
#   'si',
#   'actualiz'],
#  ['entorn', 'pag', 'fall', 'pag', 'toqu', 'aplicacion', 'error'],
#  ['encuentr', 'cuent', 'hog'],
#  ['usted',
#   'hij',
#   'put',
#   'ladron',
#   'ademas',
#   'servici',
#   'client',
#   'call',
#   'cent',
#   'mierd',
#   'llen',
#   'gent',
#   'mediocr',
#   'cuelg'],
#  ['dej', 'entrar', 'famili', 'amig'],
#  ['opcion', 'chat', 'line', 'asesor'],
#  ['falt',
#   'inform',
#   'hic',
#   'recarg',
#   'encuentr',
#   'inform',
#   'mism',
#   'recarg',
#   'sol',
#   'voz',
#   'sol',
#   'dat'],
#  ['internet', 'hog', 'mal'],
#  ['dan', 'benefici', 'promet'],
#  ['mal', 'señal', 'dat', 'funcion', 'vec'],
#  ['pesim', 'servici', 'sirv', 'señal', 'app', 'lent', 'dificil', 'ingres'],
#  ['busc', 'equip', 'compr', 'med', 'razon'],
#  ['agent', 'dispon', 'posibil', 'escrib', 'pqr'],
#  ['señal', 'pon', 'mal', 'rat', 'dat', 'funcion', 'bien'],
#  ['entiend', 'bien', 'aplic'],
#  ['trat', 'pon', 'eleg', 'sal', 'error'],
#  ['atencion', 'client'],
#  ['señal', 'mal', 'vec'],
#  ['c'],
#  ['clar',
#   'general',
#   'equip',
#   'mont',
#   'lleg',
#   'van',
#   'report',
#   'dat',
#   'credit',
#   'experient',
#   'financi',
#   'sid',
#   'excelent'],
#  ['dan', 'solucion', 'soport'],
#  ['falt', 'señal'],
#  ['ffalt', 'servici', 'persoaliz'],
#  ['mejor', 'señal', 'ciert', 'part'],
#  ['intent', 'valid', 'registrart', 'eleg', 'siempr', 'aparec', 'error'],
#  ['pued', 'compart', 'gig'],
#  ['dic', 'repuest', 'nesecit'],
#  ['cobr', 'cambi', 'numer', 'amig', 'famili'],
#  ['mejor', 'cobertur', 'señal', 'rapidez', 'naveg'],
#  ['hor', 'ingres', 'tiend', 'benefici', 'darl', 'tras', 'devuelv', 'inici'],
#  ['dej', 'compr', 'paquet', 'ten', 'dar'],
#  ['servici', 'punt', 'atencion'],
#  ['retir',
#   'veo',
#   'cumpl',
#   'dic',
#   'aun',
#   'ausuari',
#   'voy',
#   'mir',
#   'retir',
#   'incumpl',
#   'plan',
#   'eleg'],
#  ['lent', 'veloc', 'internet'],
#  ['falt', 'item', 'interaccion', 'client', 'line', 'atencion', 'uso'],
#  ['elimin', 'cuent'],
#  ['mejor', 'atencion', 'client'],
#  ['pued', 'ver', 'clar', 'hog'],
#  ['señal', 'television', 'solucion'],
#  ['pued', 'hac', 'recarg', 'pag'],
#  ['señal', 'intermitent', 'uso', 'red'],
#  ['respond', 'quier'],
#  ['comunicacion', 'peticion', 'asistent', 'dispon', 'moment'],
#  ['infrma', 'clar'],
#  ['atencion', 'punt', 'clar', 'desastr', 'floridablanc', 'santand'],
#  ['vec', 'hac', 'factur', 'mal'],
#  ['mal', 'señal'],
#  ['clar', 'vide'],
#  ['mal', 'red'],
#  ['muestr', 'cup', 'dispon', 'financi', 'equip'],
#  ['quier', 'sab', 'unas', 'cos', 'pued', 'hac'],
#  ['bon', 'regal', 'recarg'],
#  ['encuentr',
#   'solucion',
#   'busc',
#   'tampoc',
#   'encuentr',
#   'dond',
#   'dej',
#   'quej',
#   'recl'],
#  ['nom', 'dej', 'reemplz', 'equip', 'registr'],
#  ['servici',
#   'hog',
#   'malisim',
#   'celul',
#   'llev',
#   'años',
#   'uds',
#   'redujeron',
#   'pag',
#   'dat',
#   'dijeron',
#   'dat',
#   'igual'],
#  ['dar',
#   'form',
#   'pag',
#   'sab',
#   'cumpl',
#   'trat',
#   'dia',
#   'realiz',
#   'report',
#   'ta',
#   'mal',
#   'hech'],
#  ['asesor',
#   'solucion',
#   'tod',
#   'inquietud',
#   'inconform',
#   'cre',
#   'aplic',
#   'hac',
#   'fil',
#   'oficin'],
#  ['funcion', 'iphon', 'anterior', 'version', 'mal', 'exclu', 'equip'],
#  ['ofert', 'cupon', 'dispon'],
#  ['practic', 'sab', 'consum', 'sim'],
#  ['internet', 'inest'],
#  ['ten', 'realiz', 'actualiz', 'dat', 'tiemp'],
#  ['dej', 'actualiz', 'numer'],
#  ['lent'],
#  ['año',
#   'pas',
#   'validad',
#   'pag',
#   'equip',
#   'celul',
#   'hech',
#   'val',
#   'escan',
#   'recib'],
#  ['servici', 'client', 'asesor', 'atiend'],
#  ['mejor', 'servici', 'señal'],
#  ['chat', 'habl', 'asesor'],
#  ['contest', 'dej', 'esper'],
#  ['pued', 'inform', 'señal', 'internet', 'cae'],
#  ['pued', 'comunic', 'bn', 'usted'],
#  ['llam', 'cancel', 'plan', 'cancel', 'sig', 'cobr', 'utiliz'],
#  ['ofrec',
#   'plan',
#   'clar',
#   'vide',
#   'clar',
#   'music',
#   'gratis',
#   'plan',
#   'registr',
#   'pid',
#   'cobr'],
#  ['servici', 'internet', 'buen'],
#  ['cordial',
#   'salud',
#   'ingres',
#   'app',
#   'compr',
#   'celul',
#   'mot',
#   'g9',
#   'plus',
#   'obsequi',
#   'pag',
#   'factur',
#   'mensual',
#   'nunc',
#   'envi',
#   'codig'],
#  ['encuentr', 'fech', 'deb', 'pag'],
#  ['personaliz'],
#  ['minut', 'compr', 'usuari', 'deb', 'ten', 'vencimient'],
#  ['molest', 'tem', 'cobertur'],
#  ['demor'],
#  ['ayud', 'internet', 'hog', 'llev', 'mes', 'intent'],
#  ['pesim',
#   'servici',
#   'llam',
#   'respet',
#   'clarid',
#   'necesit',
#   'retir',
#   'servici'],
#  ['hac',
#   'dias',
#   'instal',
#   'internet',
#   'cas',
#   'hac',
#   'dias',
#   'conexion',
#   'internet',
#   'cabl',
#   'si',
#   'conexion',
#   'comun',
#   'c'],
#  ['dan',
#   'solucion',
#   'necesit',
#   'siqu',
#   'llam',
#   'mal',
#   'atencion',
#   'pens',
#   'cancel',
#   'plan'],
#  ['funcion', 'permit', 'cancel', 'transaccion', 'erron'],
#  ['cre', 'capac', 'gig', 'funcion', 'rap'],
#  ['dos',
#   'plan',
#   'necesit',
#   'celul',
#   'voy',
#   'punt',
#   'clar',
#   'dic',
#   'supuest',
#   'mor',
#   'mes',
#   'siend',
#   'factur',
#   'may'],
#  ['tod', 'anterior'],
#  ['se', 'cuent', 'posibil', 'carg', 'pqr'],
#  ['señal', 'baj', 'calid', 'dan', 'solucionesrap'],
#  ['internet', 'mal', 'señal', 'mal'],
#  ['eleg', 'numer', 'espos', 'marc', 'sal', 'llam', 'eleg'],
#  ['mal', 'servici', 'hog', 'cerc', 'cambi', 'compañ'],
#  ['lentitud'],
#  ['acces', 'direct', 'insemin'],
#  ['atiend',
#   'nunc',
#   'cobr',
#   'dobl',
#   'plan',
#   'da',
#   'opcion',
#   'app',
#   'hac',
#   'cambi',
#   'plan'],
#  ['bloque', 'product', 'bancari'],
#  ['pod', 'cambi', 'celul', 'numer', 'plan', 'hog', 'adquir'],
#  ['inoper', 'falt', 'atencion', 'requer'],
#  ['fall', 'carg', 'funcional', 'aplic'],
#  ['app',
#   'veo',
#   'servicii',
#   'movil',
#   'sid',
#   'posibl',
#   'agreg',
#   'servici',
#   'hog'],
#  ['present',
#   'problem',
#   'servici',
#   'servici',
#   'mod',
#   'emergent',
#   'dej',
#   'sal',
#   'llam',
#   'entran',
#   'dat',
#   'intermitent'],
#  ['internet', 'deficient', 'meet'],
#  ['ve', 'reflej', 'pag'],
#  ['dese', 'sab', 'inform', 'plan', 'calr', 'hog'],
#  ['casi', 'tramit', 'intent', 'hac', 'sal', 'error'],
#  ['pud', 'inscrib', 'eleg'],
#  ['solicit',
#   'portabil',
#   'sim',
#   'lleg',
#   'cas',
#   'dur',
#   'dos',
#   'dias',
#   'bien',
#   'empez',
#   'fall',
#   'intermitent',
#   'dur',
#   'seman',
#   'solicit',
#   'cambi'],
#  ['dem', 'dificult', 'tecnolog'],
#  ['posibl', 'alla', 'asesor', 'pued', 'asesor'],
#  ['señal', 'cobr', 'especific', 'factur'],
#  ['sal', 'clar', 'hog'],
#  ['lent', 'respuest'],
#  ['pued', 'cambi', 'corre', 'electron'],
#  ['asesor',
#   'da',
#   'info',
#   'ampli',
#   'gui',
#   'solucion',
#   'apo',
#   'deberi',
#   'permit',
#   'cancel',
#   'asesor'],
#  ['registr', 'autoriz', 'dan', 'dobl', 'ocasion', 'lent', '3g'],
#  ['encuentr', 'opcion', 'pag', 'factur', 'clar'],
#  ['ledi', 'diez', 'demor', 'carg', 'avec', 'cuelg'],
#  ['covertur', 'uso', 'dat', 'mal', 'conexion'],
#  ['pod', 'registr', 'numer', 'app', 'clar'],
#  ['caid', 'señal', 'clar', 'moment', 'mantien', 'caid'],
#  ['entend', 'termin', 'entiend', 'facil'],
#  ['veloc'],
#  ['lent'],
#  ['movil',
#   'se',
#   'realiz',
#   'llam',
#   'voz',
#   'notifiqu',
#   'centr',
#   'atencion',
#   'solucion'],
#  ['cobr', 'despues', 'hab', 'cancel', 'line'],
#  ['much',
#   'vec',
#   'recarg',
#   'tarjet',
#   'pon',
#   'quej',
#   've',
#   'reflej',
#   'si',
#   'incomod',
#   'muchisim'],
#  ['dej', 'ver', 'clar', 'hogar'],
#  ['xxxx'],
#  ['carg', 'dat', 'servici', 'tecnic'],
#  ['ten', 'crefit', 'aprob', 'pagin', 'dej'],
#  ['grup', 'famili', 'pued', 'llam', 'oper'],
#  ['valor',
#   'tan',
#   'alto',
#   'plan',
#   'pospag',
#   'mal',
#   'comun',
#   'asesor',
#   'llam',
#   'chat'],
#  ['nunc',
#   'pued',
#   'llam',
#   'aunqu',
#   'acab',
#   'pon',
#   'sald',
#   'pes',
#   'boy',
#   'llam',
#   'dic',
#   'sald',
#   'pas'],
#  ['señal', 'mal', 'demor', 'envi', 'mensaj', 'wap'],
#  ['solicit',
#   'reduccion',
#   'plan',
#   'motiv',
#   'econom',
#   'fin',
#   'incurr',
#   'mor',
#   'pag',
#   'ahor',
#   'plan',
#   'satisfac',
#   'uso',
#   'dat'],
#  ['pued', 'compr', 'paquet', 'complic', 'entend'],
#  ['cobertur', 'pesim', 'calid', 'servici', 'pesim'],
#  ['pesim'],
#  ['cobertur'],
#  ['realiz',
#   'compr',
#   'googl',
#   'play',
#   'suel',
#   'ocurr',
#   'herror',
#   'descuent',
#   'sald',
#   'realiz',
#   'compr',
#   'exit'],
#  ['dej', 'inscrib', 'eleg'],
#  ['mal', 'actualizacion', 'referent', 'pag'],
#  ['servici', 'line', 'telefon', 'pesim', 'registr', 'pact', 'plan'],
#  ['cambi', 'eleg'],
#  ['app', 'funcion', 'internet'],
#  ['opcion', 'cambi', 'plan'],
#  ['cab',
#   'razon',
#   'dan',
#   'poc',
#   'caracter',
#   'hag',
#   'resum',
#   'clar',
#   'mal',
#   'peg',
#   'mam'],
#  ['pued', 'ver', 'detall', 'plan', 'hog'],
#  ['obsolet'],
#  ['mal', 'calid', 'señal'],
#  ['quit', 'plat'],
#  ['quier', 'cancel', 'line', 'dej'],
#  ['atencion', 'client', 'hac', 'recl'],
#  ['cobertur', 'buen', 'dat', 'lent'],
#  ['plan', 'recarg', 'sol', 'benefici', 'usted'],
#  ['pesim'],
#  ['oper', 'mejor', 'promocion', 'whatsapp', 'gratis', 'año'],
#  ['necesit', 'asesor'],
#  ['factur', 'info', 'hog', 'quit', 'mal', 'funcion', 'app'],
#  ['mal', 'señal', 'cae', 'red'],
#  ['carg', 'paquet', 'compr'],
#  ['dej', 'cancel', 'servici'],
#  ['mejor', 'inform', 'manej', 'asesor', 'mism'],
#  ['quier', 'usar', 'servici', 'supon', 'yno', 'permit', 'realiz'],
#  ['muestr', 'bien', 'sald', 'consum', 'dat', 'pesim'],
#  ['pesim', 'servici'],
#  ['dej', 'consult', 'clar', 'hog'],
#  ['funcional', 'lent', 'inest'],
#  ['much', 'opcion', 'registr', 'app'],
#  ['telefon', 'huawei', 'elimin', 'apple'],
#  ['reiter', 'pag', 'oblig', 'hab', 'pas', 'dias', 'mor'],
#  ['aparec', 'deud'],
#  ['apk',
#   'sirv',
#   'hij',
#   'diseñ',
#   'sab',
#   'apk',
#   'util',
#   'peor',
#   'aun',
#   'usted',
#   'mand',
#   'utiliz',
#   'quej'],
#  ['recarg', 'usad', 'sald'],
#  ['llam', 'cae', 'cort'],
#  ['servici', 'llam', 'internet', 'municipi', 'magang', 'mal', 'demasi', 'mal'],
#  ['plan',
#   'hij',
#   'compr',
#   'paquet',
#   'jueg',
#   'problem',
#   'pag',
#   'deud',
#   'ahor',
#   'pued',
#   'compr',
#   'paquet',
#   'mism',
#   'jueg'],
#  ['pag',
#   'facil',
#   'aplic',
#   'buen',
#   'pod',
#   'pag',
#   'siempr',
#   'complic',
#   'entend'],
#  ['pud', 'hac', 'uso', 'servici'],
#  ['numer', 'registr', 'mio'],
#  ['mes', 'sub', 'factur'],
#  ['regul'],
#  ['sirv'],
#  ['moment', 'dej', 'entrar'],
#  ['señal',
#   'pesim',
#   'app',
#   'cierr',
#   'previ',
#   'avis',
#   'aparec',
#   'deud',
#   'pag',
#   'apart',
#   'servici',
#   'tal',
#   'clar',
#   'peor'],
#  ['pued', 'asoci', 'cuent', 'movil', 'cuent', 'hog'],
#  ['cobr',
#   'paquet',
#   'nunc',
#   'ped',
#   'aplic',
#   'encuentr',
#   'especific',
#   'fue',
#   'tampoc',
#   'si',
#   'van',
#   'cobr',
#   'cas',
#   'mes'],
#  ['na'],
#  ['cambi',
#   'numer',
#   'dej',
#   'ver',
#   'detall',
#   'mifacur',
#   'sig',
#   'sal',
#   'ner',
#   'antigui'],
#  ['p'],
#  ['mal', 'servici'],
#  ['dej', 'ver', 'catalog', 'tabl'],
#  ['aparec', 'consum', 'plan', 'numer', 'celul', 'correspond'],
#  ['bien'],
#  ['servici', 'dat', 'voz', 'ultim', 'mal'],
#  ['tard', 'carg', 'inform'],
#  ['encuentr', 'registr', 'dat', 'dispon'],
#  ['encarg',
#   'cel',
#   'hac',
#   'dias',
#   'aun',
#   'lleg',
#   'ademas',
#   'señal',
#   'sup',
#   'sup',
#   'mal'],
#  ['deud',
#   'abi',
#   'cancel',
#   'result',
#   'des',
#   'pues',
#   'año',
#   'medi',
#   'toc',
#   'bolv',
#   'cancel',
#   'avi',
#   'pag',
#   'perfect'],
#  ['red', 'notici', 'funcion'],
#  ['numer',
#   'ed',
#   'aparec3',
#   'ahi',
#   'realic',
#   'cambi',
#   'nimer',
#   'lps',
#   'dias',
#   'volv',
#   'realiz',
#   'cambi',
#   'autorizacion'],
#  ['pod',
#   'configur',
#   'mas',
#   'cos',
#   'rout',
#   'dar',
#   'algun',
#   'form',
#   'acces',
#   'pagin'],
#  ['veo', 'cambi', 'clav', 'romp', 'cas'],
#  ['atencion', 'telefon', 'app'],
#  ['program', 'tv', 'mal', 'repetit'],
#  ['bloqu', 'line', 'hac', 'dias', 'inform', 'dad', 'app', 'fals'],
#  ['dej', 'compr', 'paquet', 'pse'],
#  ['l'],
#  ['dej', 'compr', 'tarjet'],
#  ['prefier', 'dec'],
#  ['logr', 'reguistr', 'equip'],
#  ['carg', 'internet', 'mov', 'app'],
#  ['necesit', 'asoci', 'cta', 'nombr', 'sistem', 'dej'],
#  ['consult',
#   'qued',
#   'clar',
#   'consum',
#   'compr',
#   'paquet',
#   'recuerd',
#   'hab',
#   'hech'],
#  ['lent', 'nunc', 'solucion', 'dificultad', 'client'],
#  ['permit', 'gestion', 'trat', 'bloqu', 'si', 'pued', 'sol', 'sirv', 'vent'],
#  ['incluyer', 'servici', 'explic', 'acuerd', 'plan', 'igual', 'personal'],
#  ['dej', 'realiz', 'pqr'],
#  ['lent', 'aun', 'dat', 'funcion', 'correct'],
#  ['inform', 'product', 'com', 'reloj', 'inteligent'],
#  ['nunc', 'sirv', 'compr', 'paquet'],
#  ['dan', 'detall', 'llam', 'mensaj', 'salient', 'necesit', 'segur'],
#  ['app', 'rellen', 'sirv'],
#  ['actualiz', 'inform'],
#  ['fidel', 'client', 'cuent'],
#  ['identif', 'benefici', 'dat', 'adicional', 'brind', 'oper', 'line'],
#  ['dat', 'otorg', 'mentir', 'dur', 'suficient', 'deb', 'ser'],
#  ['encontr', 'clar', 'club'],
#  ['encuentr',
#   'line',
#   'atencion',
#   'direct',
#   'permit',
#   'expon',
#   'problem',
#   'television'],
#  ['pas',
#   'pag',
#   'plan',
#   'espos',
#   'dias',
#   'cad',
#   'mes',
#   'pues',
#   'tom',
#   'servici',
#   'habl',
#   'suced'],
#  ['asesor', 'asesor'],
#  ['aparec', 'psp', 'realiz', 'pag'],
#  ['mal', 'señal', 'pon', 'cad', 'rat', 'sincervici'],
#  ['ayud', 'necesit', 'mal', 'servici', 'part', 'asesor'],
#  ['quit', 'señal', 'anterior', 'oper', 'aun', 'lleg', 'clar', 'portabil'],
#  ['factur', 'electron', 'papel', 'fisic', '2do', 'mensaj', 'lleg', 'numer'],
#  ['dan',
#   'solucion',
#   'problemat',
#   'tiend',
#   'virtual',
#   'sol',
#   'mand',
#   'corre',
#   'automat',
#   'dan',
#   'solucion'],
#  ['moment', 'inform', 'error', 'funcion'],
#  ['dej', 'entrar', 'renov', 'elej'],
#  ['falt', 'mas', 'opcion'],
#  ['mal'],
#  ['numer', 'aparec', 'alli', 'da', 'mas', 'opcion'],
#  ['poc', 'opcion', 'cambi', 'plan'],
#  ['lent'],
#  ['quit',
#   'opcion',
#   'financi',
#   'equip',
#   'opcion',
#   'buen',
#   'asi',
#   'teni',
#   'estim',
#   'ver',
#   'preci',
#   'sal',
#   'equip'],
#  ['solicit',
#   'factur',
#   'fisic',
#   'lleg',
#   'deb',
#   'busc',
#   'canal',
#   'pag',
#   'app',
#   'funcion'],
#  ['sent', 'bien', 'cos', 'dej', 'satisfech'],
#  ['n0',
#   'pued',
#   'sab',
#   'consum',
#   'paquet',
#   'ke',
#   'activ',
#   'ke',
#   'qued',
#   'meg',
#   'minut',
#   'mensaj'],
#  ['ocasion',
#   'aplic',
#   'termin',
#   'carg',
#   'problem',
#   'recarg',
#   'plan',
#   'si',
#   'aplic',
#   'carg'],
#  ['andres', 'señal', 'va', 'convers', 'interrump'],
#  ['dej', 'hac', 'seguimient', 'tecnic'],
#  ['mal', 'atencion', 'client'],
#  ['actualiz', 'inmediat'],
#  ['mal', 'servici'],
#  ['comun', 'uds', 'sol', 'depend', 'chat', 'barrer'],
#  ['cobr', 'equip', 'movil', 'recibi'],
#  ['atend'],
#  ['dej', 'cancel', 'pag', 'automat'],
#  ['pod', 'reaolv', 'in', 'probñem', 'medi', 'aplicacion'],
#  ['aguilud'],
#  ['mentir'],
#  ['descuent', '500pes', 'sald', 'sab', 'autorizacion'],
#  ['señal'],
#  ['jsjdjudjhehhehehueududjuddudjududhdhhejdjejudjdjejejjej'],
#  ['cumpl', 'promet'],
#  ['mejor', 'cobertur', 'cort', 'llam', 'dat'],
#  ['mal', 'servici'],
#  ['tal', 'vez', 'hac', 'didact', 'app'],
#  ['report', 'hurt', 'equip', 'espos', 'nuev', 'noch', 'pod'],
#  ['bastant',
#   'antigu',
#   'usted',
#   'solicit',
#   'telefon',
#   'nieg',
#   'pag',
#   'puntual',
#   'sirv'],
#  ['celul',
#   'machuch',
#   'compr',
#   'dos',
#   'galaxy',
#   '2j',
#   'prim',
#   'usted',
#   'sabran',
#   'rwsult'],
#  ['necesit', 'hac', 'recarg', 'carg', 'factur', 'numer', 'clar'],
#  ['q', 'mas', 'rrap'],
#  ['realic',
#   'pag',
#   'clar',
#   'hog',
#   'dia',
#   'may',
#   'aplic',
#   'recib',
#   'gener',
#   'numer',
#   'factur',
#   'cuent',
#   'hog',
#   'continu'],
#  ['exist',
#   'mod',
#   'offlin',
#   'permit',
#   'compr',
#   'paquet',
#   'das',
#   'click',
#   'hac',
#   'requier',
#   'ten',
#   'conexion',
#   'iron'],
#  ['encuentr',
#   'facil',
#   'pag',
#   'pued',
#   'asoci',
#   'line',
#   'movil',
#   'servici',
#   'hog',
#   'cancel',
#   'año',
#   'pas'],
#  ['ningun'],
#  ['posibl',
#   'activ',
#   'menu',
#   'cobr',
#   'mas',
#   'plan',
#   'servici',
#   'client',
#   'ide',
#   'pregunt'],
#  ['arbitrari', 'sald', 'cuent', 'va', 'desaparec'],
#  ['expliqu', 'famili', 'anot', 'pued', 'marc', 'entonc', 'cual', 'benefici'],
#  ['internet', 'vec', 'pierd'],
#  ['internet',
#   'demasi',
#   'lent',
#   'dic',
#   'coloc',
#   '60gb',
#   'naveg',
#   'pesim',
#   'mo',
#   'señal',
#   'ningun',
#   'lug'],
#  ['inform', 'necesit'],
#  ['internet', 'pesim'],
#  ['pued', 'ver', 'cuent', 'clar', 'hog'],
#  ['medi', 'pag'],
#  ['aqui',
#   'correspond',
#   'si',
#   'posibl',
#   'factur',
#   'digital',
#   'sin',
#   'fisic',
#   'entreg',
#   'cas',
#   'graci',
#   'atencion'],
#  ['ofrec',
#   'product',
#   'porcient',
#   'interes',
#   'hac',
#   'cuent',
#   'cuot',
#   'manej',
#   'termin',
#   'pag',
#   'compr'],
#  ['solicit',
#   'transl',
#   'clar',
#   'viv',
#   'pis',
#   'ahor',
#   'viv',
#   'pis',
#   'mism',
#   'cas',
#   'program',
#   'cit',
#   'nunc',
#   'vin'],
#  ['dificil',
#   'ubic',
#   'necesit',
#   'anter',
#   'mas',
#   'facil',
#   'definit',
#   'cambi',
#   'usted',
#   'hac',
#   'termin',
#   'dañ'],
#  ['increment', 'hac', 'mensual', 'factur', 'movil', 'hog'],
#  ['suscripcion', 'via', 'mensaj', 'autoriz'],
#  ['cobr', 'deb'],
#  ['benefici', 'plan'],
#  ['seleccion',
#   'plan',
#   'bien',
#   'especific',
#   'mejor',
#   'pid',
#   'plan',
#   'sal',
#   'diferent'],
#  ['pued', 'configur', 'numer', 'eleg', 'benefici'],
#  ['app', 'sirv', 'resolv', 'problem', 'tecnic', 'servici', 'hog'],
#  ['pas',
#   'dia',
#   'hac',
#   'pag',
#   'sig',
#   'aparec',
#   'mal',
#   'intencion',
#   'correct',
#   'si',
#   'cancel',
#   'factur',
#   'salg',
#   'cancel'],
#  ['eleg', 'cualqui', 'oper'],
#  ['inform', 'plan', 'clar', 'hog'],
#  ['respond'],
#  ['cobertur', 'comun', 'llam', 'internet', 'dat', 'mal', 'ciudad', 'capital'],
#  ['mal', 'servici', 'internet', 'satelital'],
#  ['sac', 'plataform'],
#  ['razon'],
#  ['permit', 'inscripcion', 'line', 'servici', 'famili', 'amig'],
#  ['dej', 'agreg', 'servici'],
#  ['ocasion', 'funcion', 'correct', 'naveg', 'parec', 'internet'],
#  ['aparec', 'cuent', 'celul'],
#  ['manej', 'clar', 'recarg'],
#  ['vec', 'entra', 'demor', 'entrar', 'app'],
#  ['dan', 'ayud', 'suficient'],
#  ['trat',
#   'hac',
#   'recarg',
#   'salg',
#   'app',
#   'gener',
#   'clav',
#   'dinam',
#   'cae',
#   'transaccion',
#   'toc',
#   'empez',
#   'nuev',
#   'proces'],
#  ['poc', 'opcion'],
#  ['ofrec',
#   'plan',
#   'cerr',
#   'cobr',
#   'final',
#   'valor',
#   'ofrec',
#   'regal',
#   'año',
#   'pued',
#   'usar',
#   'cancel',
#   'cad',
#   'rat'],
#  ['encuentr', 'opcion', 'inform', 'personal', 'clar', 'chat'],
#  ['encuentr'],
#  ['asesor', 'telefon'],
#  ['complic'],
#  ['permit', 'actualiz', 'contact', 'amig', 'famili', 'vari', 'oportun'],
#  ['avec', 'tiend', 'ser', 'confus', 'inform', 'app'],
#  ['solucion', 'problem', 'product'],
#  ['complic', 'contraseñ'],
#  ['si',
#   'boi',
#   'eleg',
#   'numer',
#   'eleg',
#   'ai',
#   'much',
#   'trab',
#   'toi',
#   'asiend',
#   'intent',
#   'vari',
#   'vec',
#   'nos',
#   'pas'],
#  ['apk',
#   'quit',
#   'ejempl',
#   'si',
#   'credit',
#   'pod',
#   'sab',
#   'ten',
#   'llam',
#   'apk',
#   'funcion',
#   'si',
#   'dat',
#   'wifi'],
#  ['aparec', 'sim', 'postpag', 'lin'],
#  ['pued',
#   'contact',
#   'servici',
#   'tecnic',
#   'plan',
#   'hog',
#   'mal',
#   'internet',
#   'cae',
#   'red',
#   'vec',
#   'desaparec'],
#  ['mal', 'señal', 'mal', 'servici'],
#  ['ver', 'factur', 'descarg'],
#  ['dic', 'pod', 'personaliz', 'wifi', 'ciert', 'pued'],
#  ['estan',
#   'dispon',
#   'seeivi',
#   'atencion',
#   'client',
#   'valor',
#   'dat',
#   'real',
#   'mal',
#   'poc',
#   'atencion',
#   'client',
#   'engorr'],
#  ['oblig', 'permanec', 'plan', 'postpag', 'costos'],
#  ['ningun', 'servici', 'perfect'],
#  ...]

# %%
Lista_general = list_Q4+list_Q10+list_Q12+list_Q15+list_Q18 #Q10
#print(Lista_general)

# %%
bigram = gensim.models.Phrases(Lista_general, min_count=5, threshold=10) 
trigram = gensim.models.Phrases(bigram[Lista_general], threshold=10)  


bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

#print(trigram_mod[bigram_mod[Lista_general[15]]])

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# %%
data_words_bigrams = make_bigrams(Lista_general)

# %%
diccionario = Dictionary(data_words_bigrams)
print(f'Número de tokens: {len(diccionario)}')
# Out:
# Número de tokens: 4786

# %%
diccionario.filter_extremes(no_below=2, no_above = 0.9)
print(f'Número de tokens: {len(diccionario)}')
# Out:
# Número de tokens: 2246

# %%
corpus = [diccionario.doc2bow(noticia) for noticia in data_words_bigrams]
# Mostramos el BOW de una noticia
print(corpus[6])
# Out:
# [(23, 1)]

# %%
lda = LdaModel(corpus=corpus, id2word=diccionario, 
               num_topics=9, random_state=35, 
               chunksize=1000, iterations=200, passes=40, alpha='auto')

# %%
topicos = lda.print_topics(num_words=5, num_topics=20)
for topico in topicos:
    print(topico)
# Out:
# (0, '0.202*"servici" + 0.115*"internet" + 0.109*"mal" + 0.071*"señal" + 0.028*"fall"')
# (1, '0.086*"lent" + 0.070*"realiz" + 0.067*"opcion" + 0.063*"compr" + 0.041*"encontr"')
# (2, '0.131*"pag" + 0.099*"factur" + 0.089*"pued" + 0.050*"clar" + 0.046*"consult"')
# (3, '0.161*"pud" + 0.053*"activ" + 0.048*"famili_amig" + 0.048*"asesor" + 0.047*"telefon"')
# (4, '0.071*"pesim" + 0.044*"client" + 0.041*"demor" + 0.039*"equip_financi" + 0.037*"qued"')
# (5, '0.083*"plan" + 0.076*"hac" + 0.065*"recarg" + 0.033*"line" + 0.032*"sald"')
# (6, '0.052*"ningun" + 0.043*"product" + 0.040*"benefici" + 0.028*"verific" + 0.026*"posibl"')
# (7, '0.085*"dej" + 0.070*"app" + 0.065*"ver" + 0.058*"ingres" + 0.049*"dat"')
# (8, '0.118*"funcion" + 0.075*"sirv" + 0.037*"intent" + 0.030*"error" + 0.026*"muestr"')

# %%
import pyLDAvis.gensim_models

lda_display = pyLDAvis.gensim_models.prepare(lda, corpus, diccionario, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1580824088449282728464310523"></div>
# <script type="text/javascript">
#
# var ldavis_el1580824088449282728464310523_data = {"mdsDat": {"x": [-0.0738481577133214, -0.08278164109476387, 0.26064515525694, -0.07556221259974241, -0.07930634860228299, -0.1138809315701508, -0.08290745749579076, 0.32977286135660405, -0.08213126753749143], "y": [-0.00824841067519494, -0.009029114898274142, 0.3653535486302961, -0.008635197019107296, -0.009667671115584243, -0.006204465261782813, -0.009681157421196846, -0.30417903610516733, -0.00970849613398817], "topics": [1, 2, 3, 4, 5, 6, 7, 8, 9], "cluster": [1, 1, 1, 1, 1, 1, 1, 1, 1], "Freq": [8.578501515050215, 8.442040057659739, 19.134388390828256, 7.360547924115608, 6.054689869249693, 16.828224452284875, 6.322556903287342, 20.919774936404032, 6.359275951120239]}, "tinfo": {"Term": ["servici", "pag", "factur", "pud", "pued", "dej", "plan", "internet", "mal", "app", "hac", "ver", "funcion", "recarg", "ingres", "lent", "dat", "registr", "clar", "se\u00f1al", "realiz", "consult", "opcion", "sirv", "compr", "cuent", "aplic", "equip", "pesim", "numer", "servici", "internet", "mal", "se\u00f1al", "fall", "mejor", "cae", "fij", "buen", "referent", "red", "cas", "graci", "conexion", "tan", "contrase\u00f1", "cobertur", "va", "grup_famili", "hbo", "funcion_bien", "voz", "razon", "molest", "men", "text", "veloc", "television", "caid", "agend_visit", "lent", "realiz", "opcion", "compr", "encontr", "paquet", "compr_paquet", "cambi_numer", "revis", "medi", "tiemp", "minut", "proces", "detall", "toc", "clar_play", "ademas", "baj", "cambi_contrase\u00f1", "complic", "canal", "inclu", "cup", "promocion", "comunic_asesor", "impos", "hbo_max", "hag", "arregl", "obten", "pag", "factur", "pued", "clar", "consult", "cuent", "clar_hog", "aparec", "hog", "inform", "permit", "necesit", "movil", "wifi", "sol", "mir", "encuentr", "conect", "acced", "cambi_clav", "respuest", "valor", "logr", "averigu", "ten", "com", "corre", "asoci_cuent", "veo", "cos", "pud", "activ", "famili_amig", "asesor", "telefon", "busc", "tecnic", "amig", "problem", "facil", "tampoc", "comunic", "se", "famili", "comun", "inscrib", "esper", "naveg", "tv", "ayud", "atiend", "instal", "form", "trabaj", "soport", "dan_solucion", "dond", "continu", "realic", "volv", "pesim", "client", "demor", "equip_financi", "qued", "cuant", "vec", "contest", "dan", "falt", "atencion", "pon", "hic", "agreg", "descarg_factur", "despues", "solucion_problem", "casi", "dificil", "gestion", "cad", "sal_error", "ultim", "present", "n", "demor_carg", "compart", "vari", "demasi", "envi_mensaj", "plan", "hac", "recarg", "line", "sald", "llam", "cambi", "quier", "cancel", "carg", "nunc", "solucion", "sab", "pas", "cobr", "mes", "lleg", "solicit", "dias", "consum_dat", "respond", "nombr", "da", "chat", "usted", "dos", "oper", "asoci", "prepag", "pospag", "ningun", "product", "benefici", "verific", "posibl", "clar_vide", "abrir", "quer", "ofrec", "contact", "pagin", "tiend", "hor", "moment", "usuari", "gig", "visit_tecnic", "rap", "inici", "acces", "pse", "mas", "supuest", "ser", "netflix", "trasl", "quis", "compart_dat", "part", "avec", "dej", "app", "ver", "ingres", "dat", "registr", "aplic", "equip", "numer", "dic", "pod", "celul", "si", "eleg", "entrar", "actualiz", "sal", "consum", "nuev", "siempr", "deb", "adquir", "trat", "abre", "mism", "ahor", "anterior", "bien", "aplicacion", "sac", "funcion", "sirv", "intent", "error", "muestr", "bloque", "dispon", "pid", "habl_asesor", "quej", "much", "reclam", "gratis", "mensaj", "report", "cupon", "cort", "envi", "clav", "tod", "sistem", "agreg_numer", "utiliz", "inscrib_eleg", "modific", "imei", "atencion_client", "valid", "lin", "codig"], "Freq": [1290.0, 1871.0, 1404.0, 882.0, 1265.0, 1319.0, 1036.0, 732.0, 698.0, 1089.0, 946.0, 1008.0, 557.0, 814.0, 897.0, 540.0, 761.0, 755.0, 710.0, 454.0, 441.0, 660.0, 420.0, 357.0, 397.0, 585.0, 588.0, 586.0, 320.0, 556.0, 1289.3970339837003, 731.8092429029296, 697.9608176545992, 453.7617423924807, 179.73614378175404, 124.94811547916838, 118.95936951877145, 113.2611 ...

# %%
lda_5 = LdaModel(corpus=corpus, id2word=diccionario, 
               num_topics=5, random_state=35, 
               chunksize=1000, iterations=200, passes=40, alpha='auto')

# %%
import pyLDAvis.gensim_models

lda_display = pyLDAvis.gensim_models.prepare(lda_5, corpus, diccionario, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1580824081969559363211168516"></div>
# <script type="text/javascript">
#
# var ldavis_el1580824081969559363211168516_data = {"mdsDat": {"x": [0.00476505762264857, -0.32975082319757426, 0.32898221699259744, -0.01730752827333378, 0.013311076855661673], "y": [-0.039816275444712154, 0.21709232965907593, 0.20058011475568838, -0.35333036514191285, -0.024525803828139136], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [13.417528615493222, 23.21999524255889, 31.6016555930896, 20.032111299063057, 11.728709249795234]}, "tinfo": {"Term": ["servici", "pag", "dej", "factur", "app", "dat", "pued", "internet", "ingres", "mal", "pud", "hac", "funcion", "registr", "ver", "plan", "lent", "recarg", "aplic", "se\u00f1al", "numer", "clar", "dic", "consult", "sirv", "pesim", "carg", "cuent", "aparec", "pod", "dat", "internet", "mal", "lent", "se\u00f1al", "sirv", "asesor", "respond", "mejor", "cae", "chat", "abrir", "referent", "red", "usuari", "habl_asesor", "gig", "esper", "naveg", "pon", "visit_tecnic", "conexion", "descarg_factur", "tan", "ayud", "clav", "plataform", "necesit_sab", "cobertur", "contrase\u00f1", "pag", "factur", "pud", "hac", "recarg", "aparec", "pod", "celul", "realiz", "sald", "compr", "quier", "cancel", "mir", "encontr", "paquet", "compr_paquet", "pas", "deb", "cambi_numer", "equip_financi", "qued", "mes", "cuant", "revis", "verific", "dias", "consum_dat", "medi", "posibl", "pued", "ver", "plan", "clar", "consult", "cuent", "equip", "clar_hog", "hog", "inform", "opcion", "si", "necesit", "cambi", "movil", "sal", "activ", "consum", "nunc", "solucion", "wifi", "sol", "ningun", "encuentr", "sab", "busc", "nuev", "product", "conect", "benefici", "dej", "app", "ingres", "registr", "aplic", "numer", "dic", "line", "permit", "llam", "eleg", "entrar", "actualiz", "famili_amig", "telefon", "siempr", "intent", "amig", "error", "tampoc", "clar_vide", "comunic", "trat", "logr", "fij", "abre", "asoci", "bien", "famili", "comun", "servici", "funcion", "pesim", "carg", "tecnic", "client", "fall", "demor", "vec", "contest", "contact", "dan", "buen", "proces", "bloque", "falt", "atencion", "graci", "much", "habl", "fech", "despues", "cort", "casi", "tod", "dificil", "sistem", "transaccion", "agreg_eleg", "ultim"], "Freq": [1353.0, 1817.0, 1351.0, 1363.0, 1114.0, 810.0, 1320.0, 741.0, 918.0, 707.0, 866.0, 860.0, 579.0, 773.0, 1021.0, 1013.0, 550.0, 740.0, 601.0, 460.0, 569.0, 741.0, 513.0, 688.0, 358.0, 326.0, 325.0, 611.0, 478.0, 470.0, 809.9151615683671, 740.6264496632128, 706.3758699637891, 549.4871069869978, 459.26599434585336, 357.27593761303586, 290.48949278002465, 127.41071318075117, 126.52432632885879, 120.46353031654158, 119.20383844723534, 118.96677912133873, 101.22431357298407, 98.18460919252082, 86.82121486997109, 87.16130872236772, 85.01480254912916, 81.63126875713752, 78.99119486428786, 79.62635142591562, 78.78020082039274, 71.92360526512843, 69.30367272655263, 66.4512527404206, 65.32444270092589, 60.42061532800921, 60.42142376991087, 59.30553234230626, 56.11652639823591, 56.22884406795142, 1816.2740145367698, 1362.6626358362098, 865.4237912259516, 860.1238693717626, 739.8375845065858, 477.3984389123591, 469.15147155976996, 451.9665265682977, 397.18000839319075, 363.92599469058007, 357.36363226121694, 333.866838180849, 297.5423394881559, 239.84024677416204, 230.64561276643425, 210.52780591799814, 207.30958270356885, 177.70121512437996, 165.4751895872628, 157.00247398242803, 153.12229925730009, 146.5197016001895, 143.94123780441598, 143.003332453531, 138.7022316347622, 122.13303679135134, 121.08829581475086, 120.48488800773507, 119.60330715132865, 114.75129568820655, 1319.4850902076187, 1020.618828407991, 1012.5291411903685, 740.9034502715648, 687.8041482827325, 610.2727337634714, 593.242824669999, 546.49300837172, 429.9345236962054, 410.4743905162331, 406.9749028493113, 404.9575367164113, 379.57023056178195, 375.07164590684937, 326.7000314704415, 310.8584240410228, 304.2825493199333, 287.7559750025896, 274.0509031058457, 268.31910666595263, 268.11985630497014, 263.26280046566444, 243.527 ...

# %%
lda_4 = LdaModel(corpus=corpus, id2word=diccionario, 
               num_topics=4, random_state=35, 
               chunksize=1000, iterations=200, passes=40, alpha='auto')

# %%
import pyLDAvis.gensim_models

lda_display = pyLDAvis.gensim_models.prepare(lda_4, corpus, diccionario, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1580824080910829283350867304"></div>
# <script type="text/javascript">
#
# var ldavis_el1580824080910829283350867304_data = {"mdsDat": {"x": [-0.09735741578231173, 0.39753447994533164, -0.193425296815726, -0.10675176734729426], "y": [0.1656658069030057, -0.061508118117948894, -0.3399120286444495, 0.2357543398593929], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [14.516872433244071, 39.85059141505186, 30.303380614829674, 15.329155536874401]}, "tinfo": {"Term": ["servici", "pag", "internet", "registr", "mal", "factur", "ver", "plan", "dej", "pued", "lent", "numer", "funcion", "app", "dat", "clar", "se\u00f1al", "hog", "pud", "hac", "ingres", "llam", "recarg", "eleg", "entrar", "sirv", "dic", "pesim", "consult", "cuent", "servici", "internet", "mal", "lent", "se\u00f1al", "hog", "pesim", "client", "mejor", "clar_vide", "cae", "buen", "red", "referent", "bloque", "atencion", "habl_asesor", "graci", "much", "naveg", "pon", "descarg_factur", "tan", "cort", "casi", "clav", "plataform", "cobertur", "necesit_sab", "uso", "contrase\u00f1", "pag", "factur", "dej", "pued", "app", "hac", "pud", "ingres", "recarg", "consult", "cuent", "aplic", "equip", "clar_hog", "aparec", "pod", "celul", "realiz", "opcion", "line", "sald", "compr", "quier", "movil", "carg", "consum", "mir", "encontr", "paquet", "compr_paquet", "sab", "plan", "ver", "dat", "clar", "dic", "inform", "si", "permit", "necesit", "cambi", "cancel", "actualiz", "sal", "activ", "wifi", "sol", "ningun", "encuentr", "siempr", "tecnic", "conect", "benefici", "cobr", "deb", "acced", "lleg", "cambi_clav", "mes", "respuest", "solicit", "verific", "registr", "numer", "funcion", "llam", "eleg", "sirv", "entrar", "famili_amig", "asesor", "nunc", "telefon", "solucion", "amig", "contest", "problem", "tampoc", "comunic", "fij", "abre", "contact", "se", "famili", "comun", "inscrib", "agreg", "hic", "tv", "gratis", "habl", "solucion_problem"], "Freq": [1301.0, 1887.0, 739.0, 759.0, 704.0, 1416.0, 1053.0, 1045.0, 1292.0, 1276.0, 548.0, 559.0, 527.0, 1066.0, 795.0, 764.0, 458.0, 451.0, 899.0, 894.0, 878.0, 376.0, 769.0, 370.0, 338.0, 338.0, 524.0, 313.0, 665.0, 590.0, 1300.6307054825759, 738.2353210390382, 704.1071054027705, 547.7257692434922, 457.80670403859773, 450.3113976303591, 312.83950343183545, 194.93505207104673, 126.14886615039583, 127.95523177756644, 120.11002308779828, 103.3734981228402, 97.89893444573035, 100.90495929311861, 95.00401410407963, 84.26116552069243, 86.88704123961315, 82.98868665202153, 81.05469310447403, 78.77060122636412, 79.38948780784436, 69.10148806133387, 66.26890125832877, 64.38532750050832, 61.10596505926077, 60.254132011583934, 60.23950373759533, 55.9803485530077, 59.13085651069856, 55.157696649833916, 56.06169884783851, 1887.0334111749517, 1415.7559968463631, 1291.9918121881437, 1275.3620386283671, 1065.921809918723, 893.6494088318916, 899.1445158009049, 877.8181819007522, 768.6807528953499, 664.8223866546, 589.8820394675413, 575.2061025714731, 573.4171417479347, 528.2423758930438, 496.019001947803, 487.4440231160631, 469.59134221147025, 412.6793429398316, 393.3892284256684, 394.4189158580256, 378.1303751217947, 371.30996888178, 346.8888045140509, 315.79157616343616, 287.87663920063534, 278.15663712534456, 249.2066033454069, 239.6540714070682, 218.7575352067761, 215.41461820969047, 218.70330336447043, 1044.2402168353988, 1052.5712571501397, 794.9280367387181, 764.1118929366852, 523.3392369328376, 423.3557560249117, 417.6613828107195, 400.9806658217709, 391.4765422313862, 386.8373479375609, 329.861925589788, 323.9632449888705, 320.6182912941165, 313.8305640042976, 276.5435110233862, 271.53289072747936, 251.18148250403743, 244.7470695291153, 225.27024802647475, 206.28305069767086, 196.42804727177923, 192.73838388755814, 186.80669090663872, 183.46864189911972, 172.77386900507977, 159.0398059945046, 156.79799676016484, 159.5782246905946, 141.80199197621636, 134.9917142717045, 135.40314128858807, 758.5856603269884, 558.5610403678731, 526.5887531875222, 375.43850028571813, 369.37371876270964, 337.261423147219, 337.9145835175208,  ...

# %%
lda_6 = LdaModel(corpus=corpus, id2word=diccionario, 
               num_topics=6, random_state=35, 
               chunksize=1000, iterations=500, passes=50, alpha='auto')

# %%
import pyLDAvis.gensim_models

lda_display = pyLDAvis.gensim_models.prepare(lda_6, corpus, diccionario, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1580824081760561285870472750"></div>
# <script type="text/javascript">
#
# var ldavis_el1580824081760561285870472750_data = {"mdsDat": {"x": [-0.07843545123551263, 0.4316355451526619, -0.12791223719954786, -0.08112419535079039, -0.07570755376050108, -0.0684561076063096], "y": [-0.0800991210802376, 0.04212727418804478, 0.3956882096174472, -0.0883152362802638, -0.07453264729265602, -0.19486847915233454], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [9.830355964942887, 32.50952056375824, 21.139421849166126, 10.084582944288922, 9.089976552118847, 17.346142125724977]}, "tinfo": {"Term": ["servici", "pag", "internet", "mal", "factur", "plan", "ver", "dej", "aplic", "pued", "funcion", "lent", "numer", "app", "dat", "registr", "clar", "se\u00f1al", "hac", "pud", "ingres", "equip", "recarg", "eleg", "sirv", "entrar", "dic", "pesim", "consult", "sald", "internet", "mal", "aplic", "lent", "se\u00f1al", "mejor", "clar_vide", "cae", "abre", "red", "bloque", "much", "naveg", "conexion", "tan", "cupon", "clav", "cobertur", "necesit_sab", "contrase\u00f1", "va", "compart_dat", "grup_famili", "obten", "ocasion", "part", "avec", "funcion_bien", "dond", "dificult", "pag", "factur", "dej", "pued", "app", "hac", "ingres", "pud", "recarg", "consult", "cuent", "clar_hog", "aparec", "pod", "celul", "hog", "realiz", "opcion", "line", "compr", "quier", "movil", "sal", "encontr", "encuentr", "paquet", "compr_paquet", "siempr", "deb", "intent", "sol", "plan", "ver", "dat", "registr", "clar", "equip", "dic", "inform", "si", "permit", "cambi", "actualiz", "activ", "consum", "wifi", "mir", "sab", "nuev", "product", "benefici", "acced", "cambi_clav", "cuant", "adquir", "valor", "da", "ofrec", "oper", "ten", "mism", "averigu", "numer", "eleg", "sirv", "entrar", "famili_amig", "asesor", "telefon", "ningun", "amig", "facil", "problem", "tampoc", "comunic", "fij", "contact", "proces", "comun", "famili", "corre", "inscrib", "esper", "hic", "agreg", "acces", "tv", "solucion_problem", "ayud", "atiend", "casi", "dificil", "servici", "funcion", "pesim", "tecnic", "client", "conect", "demor", "fall", "contest", "dan", "buen", "referent", "falt", "atencion", "pon", "descarg_factur", "quis", "present", "ultim", "demor_carg", "n", "vari", "demasi", "continu", "atencion_client", "voz", "imei", "entra", "agend_cit", "mierd", "sald", "llam", "necesit", "cancel", "carg", "nunc", "solucion", "busc", "pas", "cobr", "cambi_numer", "qued", "lleg", "mes", "respuest", "solicit", "dias", "posibl", "respond", "tiemp", "nombr", "chat", "trat", "usted", "quer", "dos", "hor", "se", "ahor", "bien"], "Freq": [1302.0, 1879.0, 739.0, 715.0, 1402.0, 982.0, 978.0, 1304.0, 624.0, 1282.0, 567.0, 562.0, 551.0, 1086.0, 755.0, 746.0, 724.0, 471.0, 901.0, 886.0, 885.0, 572.0, 765.0, 363.0, 339.0, 333.0, 494.0, 314.0, 657.0, 407.0, 738.8376660127791, 715.1361454200326, 623.7164691845071, 561.8255616573852, 470.43420714069725, 128.83597555911425, 127.36012806725059, 122.13297360188487, 113.64358603708646, 98.15093863864288, 96.49622859935171, 82.80943799017793, 81.64140537182371, 71.75485839841254, 65.65641620867567, 63.503774950072916, 61.54644462176099, 58.83459238633315, 57.58606753677326, 56.11956757374707, 52.622785028033206, 52.11233029867318, 48.51246963179129, 45.60168455395206, 45.156635294032355, 43.68464118987591, 43.45149761737837, 43.19508394031676, 43.07829429469232, 38.704791156426474, 1878.2725276466522, 1401.2893799810674, 1303.8022986877027, 1281.9286551420876, 1086.097400128928, 900.1694937206145, 884.944282895006, 885.7244648525724, 764.4071160715301, 656.7751476750863, 588.6729988559823, 526.7851979092029, 499.37192924620814, 487.92244606356036, 466.90566979663225, 417.9377469097008, 412.1301059195613, 402.9671781809433, 395.49461466401993, 370.5524775644168, 347.99575828260754, 315.271547064365, 304.5953338035865, 238.89722252058726, 236.1382170535409, 219.75799830852958, 217.58334129255894, 215.12290424693953, 175.3884253716002, 164.51956444488854, 235.7180463363499, 981.2630172180492, 977.991963053487, 754.6750098737227, 745. ...

# %%
pyLDAvis.save_html(lda_display, 'lda_General_4_V3.html')

# %%
dfc2 = df[df['Q2_NPS_GROUP']!='Promotor']
dfc2 = dfc.fillna('')
dfc2
# Out:
#                                                       Q4 Q10  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...  ..
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                                     Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                        Tokens_Q4 Tokens_Q10  \
# 4                                       [ningun]         []
# 9      [qued, sald, carg, app, pod, recarg, vez]         []
# 10                                            []         []
# 11      [bastant, tiemp, usted, sub, plan, line]         []
# 13                                            []         []
# ...                                          ...        ...
# 48043                                         []         []
# 48048                                         []         []
# 48049                                         []         []
# 48050                                         []         []
# 48052                                         []         []
#
#                             Tokens_Q12  \
# 4                                   []
# 9                                   []
# 10                                  []
# 11                                  []
# 13                                  []
# ...                                ...
# 48043  [mas, facil, encontr, hac, cos]
# 48048                               []
# 48049                               []
# 48050                               []
# 48052                      [lent, app]
#
#                                               Tokens_Q15  \
# 4                                                     []
# 9                                                     []
# 10                                          [mal, señal]
# 11     [cambi, mes, oper, regres, nuev, sub, mil, pes...
# 13     [demor, carg, despues, dic, sient, trabaj, ser...
# ...                                                  ...
# 48043  [pued, pag, factur, tampoc, pued, ver, consum,...
# 48048                                                 []
# 48049                                                 []
# 48050                                               [bn]
# 48052                             [demor, entrar, aplic]
#
#                                          Tokens_Q18     Tokens_Q20
# 4                                                []             []
# 9                                                []  [parec, bien]
# 10                                               []             []
# 11                                               []             []
# 13                                               []             []
# ...                                             ...            ...
# 48043  [pud, ver, consum, dat, tampoc, pag, factur]             []
# 48048                                            []             []
# 48049                                            []             []
# 48050                         [entend, bien, graci]             []
# 48052                                            []             []
#
# [22263 rows x 12 columns]

# %%
def Limpiar_Caracter(texto):
    if len(texto) == 1 or texto == ',':
        texto = ''
    else:
        texto = texto
    return texto

# %%
dfc2["Tokens_Q4"]
# Out:
# 4                                         [ningun]
# 9        [qued, sald, carg, app, pod, recarg, vez]
# 10                                              []
# 11        [bastant, tiemp, usted, sub, plan, line]
# 13                                              []
#                            ...
# 48043                                           []
# 48048                                           []
# 48049                                           []
# 48050                                           []
# 48052                                           []
# Name: Tokens_Q4, Length: 22263, dtype: object

# %%
dfc2["Tokens_Q4_T"]
# Out:
# 4                                         [ningun]
# 9        [qued, sald, carg, app, pod, recarg, vez]
# 10                                              []
# 11        [bastant, tiemp, usted, sub, plan, line]
# 13                                              []
#                            ...
# 48043                                           []
# 48048                                           []
# 48049                                           []
# 48050                                           []
# 48052                                           []
# Name: Tokens_Q4_T, Length: 22263, dtype: object

# %%
dfc2["Tokens_Q4_T"] =  dfc2["Tokens_Q4"]

# %%
dfc2["Tokens_Q4_T"] =  dfc2["Tokens_Q4"]
dfc2["Tokens_Q10_T"] =  dfc2["Tokens_Q10"]
dfc2["Tokens_Q12_T"] =  dfc2["Tokens_Q12"]
dfc2["Tokens_Q15_T"] =  dfc2["Tokens_Q15"]
dfc2["Tokens_Q18_T"] =  dfc2["Tokens_Q18"]
dfc2["Tokens_Q20_T"] =  dfc2["Tokens_Q20"]


dfc2["Tokens_Q4"] =  dfc2.Q4.apply(limpiar_texto)
dfc2["Tokens_Q10"] =  dfc2.Q10.apply(limpiar_texto) #Q10
dfc2["Tokens_Q12"] =  dfc2.Q12.apply(limpiar_texto)
dfc2["Tokens_Q15"] =  dfc2.Q15.apply(limpiar_texto)
dfc2["Tokens_Q18"] =  dfc2.Q18.apply(limpiar_texto)
dfc2["Tokens_Q20"] =  dfc2.Q20.apply(limpiar_texto)

dfc2["Tokens_Q4"] =  dfc2.Q4.apply(Limpiar_Caracter)
dfc2["Tokens_Q10"] =  dfc2.Q10.apply(Limpiar_Caracter)#Q10
dfc2["Tokens_Q12"] =  dfc2.Q12.apply(Limpiar_Caracter)
dfc2["Tokens_Q15"] =  dfc2.Q15.apply(Limpiar_Caracter)
dfc2["Tokens_Q18"] =  dfc2.Q18.apply(Limpiar_Caracter)
dfc2["Tokens_Q20"] =  dfc2.Q20.apply(Limpiar_Caracter)

dfc2
# Out:
#                                                       Q4 Q10  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...  ..
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                                     Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                Tokens_Q4 Tokens_Q10  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...        ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                              Tokens_Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                               Tokens_Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                               Tokens_Q18       Tokens_Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                      Tokens_Q4_T Tokens_Q10_T  \
# 4                                       [ningun]           []
# 9      [qued, sald, carg, app, pod, recarg, vez]           []
# 10                                            []           []
# 11      [bastant, tiemp, usted, sub, plan, line]           []
# 13                                            []           []
# ...                                          ...          ...
# 48043                                         []           []
# 48048                                         []           []
# 48049                                         []           []
# 48050                                         []           []
# 48052                                         []           []
#
#                           Tokens_Q12_T  \
# 4                                   []
# 9                                   []
# 10                                  []
# 11                                  []
# 13                                  []
# ...                                ...
# 48043  [mas, facil, encontr, hac, cos]
# 48048                               []
# 48049                               []
# 48050                               []
# 48052                      [lent, app]
#
#                                             Tokens_Q15_T  \
# 4                                                     []
# 9                                                     []
# 10                                          [mal, señal]
# 11     [cambi, mes, oper, regres, nuev, sub, mil, pes...
# 13     [demor, carg, despues, dic, sient, trabaj, ser...
# ...                                                  ...
# 48043  [pued, pag, factur, tampoc, pued, ver, consum,...
# 48048                                                 []
# 48049                                                 []
# 48050                                               [bn]
# 48052                             [demor, entrar, aplic]
#
#                                        Tokens_Q18_T   Tokens_Q20_T
# 4                                                []             []
# 9                                                []  [parec, bien]
# 10                                               []             []
# 11                                               []             []
# 13                                               []             []
# ...                                             ...            ...
# 48043  [pud, ver, consum, dat, tampoc, pag, factur]             []
# 48048                                            []             []
# 48049                                            []             []
# 48050                         [entend, bien, graci]             []
# 48052                                            []             []
#
# [22263 rows x 18 columns]

# %%
dfc2["Tokens_Q4_T"]
# Out:
# 4                                         [ningun]
# 9        [qued, sald, carg, app, pod, recarg, vez]
# 10                                              []
# 11        [bastant, tiemp, usted, sub, plan, line]
# 13                                              []
#                            ...
# 48043                                           []
# 48048                                           []
# 48049                                           []
# 48050                                           []
# 48052                                           []
# Name: Tokens_Q4_T, Length: 22263, dtype: object

# %%
dfc2['Opinion'] = ''

for i in dfc2.index:
    #dfc2.loc[i,'Opinion'] =str(dfc2.loc[i,'Tokens_Q4'])+" "+str(dfc2.loc[i,'Tokens_Q10'])+" "+str(dfc2.loc[i,'Tokens_Q12']) + " " + str(dfc2.loc[i,'Tokens_Q15']) + " " + str(dfc2.loc[i,'Tokens_Q18']) 
    dfc2.loc[i,'Opinion'] =str(dfc2.loc[i,'Tokens_Q12']) + " " + str(dfc2.loc[i,'Tokens_Q15']) + " " + str(dfc2.loc[i,'Tokens_Q18']) 
dfc2
# Out:
#                                                       Q4 Q10  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...  ..
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                                     Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18              Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                Tokens_Q4 Tokens_Q10  \
# 4                                                Ninguna
# 9      Cuando me quedo sin saldo no carga la app para...
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# ...                                                  ...        ...
# 48043
# 48048
# 48049
# 48050
# 48052
#
#                                              Tokens_Q12  \
# 4
# 9
# 10
# 11
# 13
# ...                                                 ...
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48048
# 48049
# 48050
# 48052                           Es un poco lenta la app
#
#                                               Tokens_Q15  \
# 4
# 9
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# ...                                                  ...
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48048
# 48049
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                               Tokens_Q18       Tokens_Q20  \
# 4
# 9                                                         Me parece bien
# 10
# 11
# 13                                                  Nada
# ...                                                  ...              ...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48048
# 48049
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                      Tokens_Q4_T Tokens_Q10_T  \
# 4                                       [ningun]           []
# 9      [qued, sald, carg, app, pod, recarg, vez]           []
# 10                                            []           []
# 11      [bastant, tiemp, usted, sub, plan, line]           []
# 13                                            []           []
# ...                                          ...          ...
# 48043                                         []           []
# 48048                                         []           []
# 48049                                         []           []
# 48050                                         []           []
# 48052                                         []           []
#
#                           Tokens_Q12_T  \
# 4                                   []
# 9                                   []
# 10                                  []
# 11                                  []
# 13                                  []
# ...                                ...
# 48043  [mas, facil, encontr, hac, cos]
# 48048                               []
# 48049                               []
# 48050                               []
# 48052                      [lent, app]
#
#                                             Tokens_Q15_T  \
# 4                                                     []
# 9                                                     []
# 10                                          [mal, señal]
# 11     [cambi, mes, oper, regres, nuev, sub, mil, pes...
# 13     [demor, carg, despues, dic, sient, trabaj, ser...
# ...                                                  ...
# 48043  [pued, pag, factur, tampoc, pued, ver, consum,...
# 48048                                                 []
# 48049                                                 []
# 48050                                               [bn]
# 48052                             [demor, entrar, aplic]
#
#                                        Tokens_Q18_T   Tokens_Q20_T  \
# 4                                                []             []
# 9                                                []  [parec, bien]
# 10                                               []             []
# 11                                               []             []
# 13                                               []             []
# ...                                             ...            ...
# 48043  [pud, ver, consum, dat, tampoc, pag, factur]             []
# 48048                                            []             []
# 48049                                            []             []
# 48050                         [entend, bien, graci]             []
# 48052                                            []             []
#
#                                                  Opinion
# 4
# 9
# 10                                           Mala señal
# 11      Me cambié x un mes a otro operador y me regre...
# 13      Se demora para cargar y después dice lo sient...
# ...                                                  ...
# 48043  Antes era mas facil encontrar y hacer las cosa...
# 48048
# 48049
# 48050                   Bn  No lo entendí bien gracias 😊
# 48052  Es un poco lenta la app Se demora un poco al e...
#
# [22263 rows x 19 columns]

# %%
dfc2['Opinion'] = dfc2['Opinion'].apply(tokenizer.tokenize)
dfc2['Opinion'] = dfc2['Opinion'].apply(filtrar_stopword_digitos)
dfc2['Opinion'] = dfc2['Opinion'].apply(stem_palabras)
dfc2['Opinion']
# Out:
# 4                                                       []
# 9                                                       []
# 10                                            [mal, señal]
# 11       [me, cambi, x, mes, oper, regres, nuev, sub, m...
# 13       [se, demor, carg, despues, dic, sient, trabaj,...
#                                ...
# 48043    [antes, mas, facil, encontr, hac, cos, ya, pue...
# 48048                                                   []
# 48049                                                   []
# 48050                     [bn, no, entend, bien, graci, 😊]
# 48052            [es, lent, app, se, demor, entrar, aplic]
# Name: Opinion, Length: 22263, dtype: object

# %%
for i in dfc2.index:
    
    if dfc2.loc[i,'Opinion']==[]:
        dfc2.drop([i], inplace=True)

dfc2
# Out:
#                                                       Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                    Q10  \
# 10
# 11
# 13
# 27
# 32     No me d ja entrar a claro video
# ...                                ...
# 48041
# 48042
# 48043
# 48050
# 48052
#
#                                                     Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18 Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...  ..
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                Tokens_Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                             Tokens_Q10  \
# 10
# 11
# 13
# 27
# 32     No me d ja entrar a claro video
# ...                                ...
# 48041
# 48042
# 48043
# 48050
# 48052
#
#                                              Tokens_Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                               Tokens_Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                               Tokens_Q18 Tokens_Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...        ...
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                              Tokens_Q4_T  \
# 10                                                    []
# 11              [bastant, tiemp, usted, sub, plan, line]
# 13                                                    []
# 27                                                    []
# 32                                                    []
# ...                                                  ...
# 48041  [plan, versus, competent, costos, benefici, es...
# 48042                            [aparec, factur, agost]
# 48043                                                 []
# 48050                                                 []
# 48052                                                 []
#
#                    Tokens_Q10_T                     Tokens_Q12_T  \
# 10                           []                               []
# 11                           []                               []
# 13                           []                               []
# 27                           []                   [muestr, line]
# 32     [ja, entrar, clar, vide]                               []
# ...                         ...                              ...
# 48041                        []                               []
# 48042                        []                               []
# 48043                        []  [mas, facil, encontr, hac, cos]
# 48050                        []                               []
# 48052                        []                      [lent, app]
#
#                                             Tokens_Q15_T  \
# 10                                          [mal, señal]
# 11     [cambi, mes, oper, regres, nuev, sub, mil, pes...
# 13     [demor, carg, despues, dic, sient, trabaj, ser...
# 27                          [aparec, dat, line, consult]
# 32                                               [jjjjj]
# ...                                                  ...
# 48041  [llev, vari, mes, trat, den, mejor, preci, pla...
# 48042                                                 []
# 48043  [pued, pag, factur, tampoc, pued, ver, consum,...
# 48050                                               [bn]
# 48052                             [demor, entrar, aplic]
#
#                                        Tokens_Q18_T Tokens_Q20_T  \
# 10                                               []           []
# 11                                               []           []
# 13                                               []           []
# 27                      [pid, consult, acerc, line]           []
# 32                                               []           []
# ...                                             ...          ...
# 48041                                            []           []
# 48042                       [aparec, factur, agost]           []
# 48043  [pud, ver, consum, dat, tampoc, pag, factur]           []
# 48050                         [entend, bien, graci]           []
# 48052                                            []           []
#
#                                                  Opinion
# 10                                          [mal, señal]
# 11     [me, cambi, x, mes, oper, regres, nuev, sub, m...
# 13     [se, demor, carg, despues, dic, sient, trabaj,...
# 27     [no, muestr, line, no, aparec, dat, line, cons...
# 32                                               [jjjjj]
# ...                                                  ...
# 48041  [llev, vari, mes, trat, den, mejor, preci, pla...
# 48042                        [no, aparec, factur, agost]
# 48043  [antes, mas, facil, encontr, hac, cos, ya, pue...
# 48050                   [bn, no, entend, bien, graci, 😊]
# 48052          [es, lent, app, se, demor, entrar, aplic]
#
# [7131 rows x 19 columns]

# %%
diccionario.doc2bow(dfc2.loc[10,'Opinion'])
# Out:
# [(44, 1), (54, 1)]

# %%
dfc2['Tópico'] = ""
for i in dfc2.index:
    try:
        
        bow_comentario = diccionario.doc2bow(dfc2.loc[i,'Opinion'])
        distribucion_noticia = lda_4[bow_comentario]

        dist_contrib = [topico[1] for topico in lda_4[bow_comentario]]

        if (dist_contrib[0] > dist_contrib[1]) & (dist_contrib[0] > dist_contrib[2]) & (dist_contrib[0] > dist_contrib[3]):
            dfc2.loc[i,'Tópico'] = 1
        elif (dist_contrib[1] > dist_contrib[0]) & (dist_contrib[1] > dist_contrib[2]) & (dist_contrib[1] > dist_contrib[3]):
            dfc2.loc[i,'Tópico'] = 2
        elif (dist_contrib[2] > dist_contrib[0]) & (dist_contrib[2] > dist_contrib[1]) & (dist_contrib[2] > dist_contrib[3]):
            dfc2.loc[i,'Tópico'] = 3
        elif (dist_contrib[3] > dist_contrib[0]) & (dist_contrib[3] > dist_contrib[1]) & (dist_contrib[3] > dist_contrib[2]):
            dfc2.loc[i,'Tópico'] = 4
        
    except:
        print('No')

# %%
lda_4[diccionario.doc2bow(dfc2.loc[10,'Opinion'])]
#[topico[1] for topico in lda_4[diccionario.doc2bow(dfc2.loc[10,'Opinion'])]]
# Out:
# [(0, 0.3246431), (1, 0.32007217), (2, 0.23206992), (3, 0.12321475)]

# %%
topicos_4 = lda_4.print_topics(num_words=15, num_topics=20)
i=0
for topico in topicos_4:
    i=i+1
    textoAux = re.sub(r'\W', ' ', str(topico))
    textoAux = re.sub(r'\s+[a-zA-Z]\s+', ' ', textoAux)
    textoAux = re.sub(r'[0-9]', ' ', textoAux)
    textoAux = re.sub(r'\s+', ' ', textoAux, flags=re.I)
    print(str(i),textoAux)
# Out:
# 1  servici internet mal lent señal hog pesim client clar_vide mejor cae buen referent red bloque
# 2  pag factur dej pued app pud hac ingres recarg consult cuent aplic equip clar_hog aparec
# 3  ver plan dat clar dic inform si permit necesit cambi cancel actualiz sal activ wifi
# 4  registr numer funcion llam eleg entrar sirv famili_amig asesor nunc telefon solucion amig contest problem

# %%
dfc2.Tópico.value_counts()
# Out:
# 2    4275
# 3    2124
# 4     409
# 1     323
# Name: Tópico, dtype: int64

# %%
topicos_5 = lda_5.print_topics(num_words=15, num_topics=20)
i=0
for topico in topicos_5:
    i=i+1
    textoAux = re.sub(r'\W', ' ', str(topico))
    textoAux = re.sub(r'\s+[a-zA-Z]\s+', ' ', textoAux)
    textoAux = re.sub(r'[0-9]', ' ', textoAux)
    textoAux = re.sub(r'\s+', ' ', textoAux, flags=re.I)
    print(str(i),textoAux)
# Out:
# 1  dat internet mal lent señal sirv asesor respond mejor cae chat abrir referent red habl_asesor
# 2  pag factur pud hac recarg aparec pod celul realiz sald compr quier cancel mir encontr
# 3  pued ver plan clar consult cuent equip clar_hog hog inform opcion si necesit cambi movil
# 4  dej app ingres registr aplic numer dic line permit llam eleg entrar actualiz famili_amig telefon
# 5  servici funcion pesim carg tecnic client fall demor vec contest contact dan buen proces bloque

# %% [markdown]
# Asignación 5 Tópicos

# %%
dfc2['Tópico_5'] = ""
sumaTopicos = [0,0,0,0,0,0]
for i in dfc2.index:
    try:
        
        bow_comentario = diccionario.doc2bow(dfc2.loc[i,'Opinion'])
        distribucion_noticia = lda_5[bow_comentario]

        dist_contrib = [topico[1] for topico in lda_5[bow_comentario]]

        if (dist_contrib[0] > dist_contrib[1]) & (dist_contrib[0] > dist_contrib[2]) & (dist_contrib[0] > dist_contrib[3]) & (dist_contrib[0] > dist_contrib[4]):
            dfc2.loc[i,'Tópico_5'] = 1
        elif (dist_contrib[1] > dist_contrib[0]) & (dist_contrib[1] > dist_contrib[2]) & (dist_contrib[1] > dist_contrib[3]) & (dist_contrib[1] > dist_contrib[4]):
            dfc2.loc[i,'Tópico_5'] = 2
        elif (dist_contrib[2] > dist_contrib[0]) & (dist_contrib[2] > dist_contrib[1]) & (dist_contrib[2] > dist_contrib[3]) & (dist_contrib[2] > dist_contrib[4]):
            dfc2.loc[i,'Tópico_5'] = 3
        elif (dist_contrib[3] > dist_contrib[0]) & (dist_contrib[3] > dist_contrib[1]) & (dist_contrib[3] > dist_contrib[2]) & (dist_contrib[3] > dist_contrib[4]):
            dfc2.loc[i,'Tópico_5'] = 4
        elif (dist_contrib[4] > dist_contrib[0]) & (dist_contrib[4] > dist_contrib[1]) & (dist_contrib[4] > dist_contrib[2]) & (dist_contrib[4] > dist_contrib[3]):
            dfc2.loc[i,'Tópico_5'] = 5
        # sumar pertenencias a los tópicos
        sumaTopicos[1]=sumaTopicos[1]+ dist_contrib[0] 
        sumaTopicos[2]=sumaTopicos[2]+ dist_contrib[1] 
        sumaTopicos[3]=sumaTopicos[3]+ dist_contrib[2] 
        sumaTopicos[4]=sumaTopicos[4]+ dist_contrib[3] 
        sumaTopicos[5]=sumaTopicos[5]+ dist_contrib[4]         
    except:
        print('No')

# %%
sumaTopicos
# Out:
# [0,
#  962.1096249707043,
#  1631.4038111753762,
#  2291.003124445677,
#  1433.0946134887636,
#  813.3888281472027]

# %%
dfc2.Tópico_5.value_counts()
# Out:
# 3    4273
# 2    1481
# 4     762
# 1     428
# 5     187
# Name: Tópico_5, dtype: int64

# %% [markdown]
# #####  Validación asignación de Tópicos

# %%
print(dfc2[dfc2['ID cuenta o Telefono App']=='3134385817'].Opinion)
print("{0!r}".format(dfc2[dfc2['ID cuenta o Telefono App']=='3134385817'].Opinion))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ID cuenta o Telefono App'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-f9b23bf06ffd> in <module>
# ----> 1 print(dfc2[dfc2['ID cuenta o Telefono App']=='3134385817'].Opinion)
#       2 print("{0!r}".format(dfc2[dfc2['ID cuenta o Telefono App']=='3134385817'].Opinion))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ID cuenta o Telefono App'

# %%
bow_comentario = diccionario.doc2bow(dfc2.loc[625,'Opinion'])
bow_comentario
# Out:
# [(1, 1),
#  (60, 1),
#  (78, 1),
#  (110, 1),
#  (140, 1),
#  (155, 1),
#  (205, 1),
#  (207, 1),
#  (228, 1),
#  (229, 1),
#  (312, 1),
#  (969, 1)]

# %%
distribucion_noticia_4 = lda_4[bow_comentario]
distribucion_noticia_4
# Out:
# [(0, 0.10733623), (1, 0.5145547), (2, 0.266763), (3, 0.111346066)]

# %%
distribucion_noticia_5 = lda_5[bow_comentario]
distribucion_noticia_5
# Out:
# [(0, 0.10554537),
#  (1, 0.2903579),
#  (2, 0.32489777),
#  (3, 0.22894378),
#  (4, 0.05025515)]

# %%
for index,score in sorted(lda_4[bow_comentario], key=lambda tup: -1*tup[1]):
    print("Score:{}\t Topic:{}".format(score,lda_4.print_topic(index,5)))
# Out:
# Score:0.5145546793937683	 Topic:0.064*"pag" + 0.048*"factur" + 0.044*"dej" + 0.043*"pued" + 0.036*"app"
# Score:0.26676300168037415	 Topic:0.047*"ver" + 0.046*"plan" + 0.035*"dat" + 0.034*"clar" + 0.023*"dic"
# Score:0.11134606599807739	 Topic:0.067*"registr" + 0.049*"numer" + 0.046*"funcion" + 0.033*"llam" + 0.032*"eleg"
# Score:0.10733623057603836	 Topic:0.120*"servici" + 0.068*"internet" + 0.065*"mal" + 0.051*"lent" + 0.042*"señal"

# %%
for index,score in sorted(lda_5[bow_comentario], key=lambda tup: -1*tup[1]):
    print("Score:{}\t Topic:{}".format(score,lda_5.print_topic(index,5)))
# Out:
# Score:0.32489776611328125	 Topic:0.056*"pued" + 0.043*"ver" + 0.043*"plan" + 0.032*"clar" + 0.029*"consult"
# Score:0.29035788774490356	 Topic:0.105*"pag" + 0.079*"factur" + 0.050*"pud" + 0.050*"hac" + 0.043*"recarg"
# Score:0.22894378006458282	 Topic:0.091*"dej" + 0.075*"app" + 0.062*"ingres" + 0.052*"registr" + 0.040*"aplic"
# Score:0.10554537177085876	 Topic:0.081*"dat" + 0.074*"internet" + 0.071*"mal" + 0.055*"lent" + 0.046*"señal"
# Score:0.05025514215230942	 Topic:0.155*"servici" + 0.066*"funcion" + 0.037*"pesim" + 0.037*"carg" + 0.025*"tecnic"

# %% [markdown]
# ####  fin validacion

# %% [markdown]
# ###  zoom al topico_5  número 3

# %%
dfc2.columns
# Out:
# Index(['Q4', 'Q10', 'Q12', 'Q15', 'Q18', 'Q20', 'Tokens_Q4', 'Tokens_Q10',
#        'Tokens_Q12', 'Tokens_Q15', 'Tokens_Q18', 'Tokens_Q20', 'Tokens_Q4_T',
#        'Tokens_Q10_T', 'Tokens_Q12_T', 'Tokens_Q15_T', 'Tokens_Q18_T',
#        'Tokens_Q20_T', 'Opinion', 'Tópico', 'Tópico_5'],
#       dtype='object')

# %%
## Quitar pag pactur
dfc2_5_3=dfc2.copy()
#dfc2_5_3['contienePagFact']=np.where(['pag','factur'] in dfc2_5_3['Opinion'].tolist(),1,0)
#dfc2_5_3['contienePagFact']=np.where(['pag','factur'] in dfc2_5_3['Opinion'].tolist(),1,0)
#dfc2_5_3['contienePagFact']=any(np.equal(dfc2_5_3['Opinion'],['pag','factur']).all(1))
#dfc2_5_3['contienePagFact']=dfc2_5_3['Opinion'].apply(lambda x: any(np.equal(x,['pag','factur']).all(1)))
#dfc2_5_3['contienePagFact']=dfc2_5_3['Opinion'].apply(lambda x: 1 if ['pag','factur'] in x.tolist() else 0)
#dfc2_5_3['contienePagFact']=dfc2_5_3['Opinion'].apply(lambda x: 1 if ['pag','factur'] in x else 0)
dfc2_5_3['contienePagFact']=dfc2_5_3['Opinion'].apply(lambda x: 1 if 'pag' in x else 0)
#if [x,y] in pixel_array.tolist():

# %%
dfc2_5_3=dfc2_5_3[dfc2_5_3['contienePagFact']==0]

# %%
dfc2_5_3=dfc2_5_3[dfc2_5_3['Tópico_5']==3]

# %%
#dfc2_5_3.head(10)
dfc2_5_3['Opinion']
# Out:
# 27       [no, muestr, line, no, aparec, dat, line, cons...
# 32                                                 [jjjjj]
# 42                       [consult, si, credit, sac, celul]
# 64                      [no, encuentr, necesit, facil, no]
# 76       [no, dan, respuest, no, favor, diseñ, sol, emp...
#                                ...
# 48021                                      [la, dron, nad]
# 48025    [quier, sab, com, registr, vide, clar, nuev, p...
# 48034    [no, dej, acced, aplic, no, mostr, consum, dat...
# 48035    [no, pued, ver, cual, line, movil, no, pued, a...
# 48041    [llev, vari, mes, trat, den, mejor, preci, pla...
# Name: Opinion, Length: 3959, dtype: object

# %%
dfc2["Tokens_Q4_T"].count()
# Out:
# 7131

# %%
dfc2_5_3["Tokens_Q4_T"].count()
# Out:
# 4273

# %%
list_Q4_5_3 = dfc2_5_3["Tokens_Q4_T"].tolist()
list_Q10_5_3 = dfc2_5_3["Tokens_Q10_T"].tolist() #Q10
list_Q12_5_3 = dfc2_5_3["Tokens_Q12_T"].tolist()
list_Q15_5_3 = dfc2_5_3["Tokens_Q15_T"].tolist()
list_Q18_5_3 = dfc2_5_3["Tokens_Q18_T"].tolist()
list_Q20_5_3 = dfc2_5_3["Tokens_Q20_T"].tolist()

# %%
list_Q4_5_3 = [x for x in list_Q4_5_3 if x!= []]
list_Q10_5_3 = [x for x in list_Q10_5_3 if x!= []] #Q10
list_Q12_5_3 = [x for x in list_Q12_5_3 if x!= []]
list_Q15_5_3 = [x for x in list_Q15_5_3 if x!= []]
list_Q18_5_3 = [x for x in list_Q18_5_3 if x!= []]
list_Q20_5_3 = [x for x in list_Q20_5_3 if x!= []]

Lista_general_5_3 = list_Q4_5_3+list_Q10_5_3+list_Q12_5_3+list_Q15_5_3+list_Q18_5_3 #Q10

bigram_5_3 = gensim.models.Phrases(Lista_general_5_3, min_count=5, threshold=10) 
trigram_5_3 = gensim.models.Phrases(bigram_5_3[Lista_general_5_3], threshold=10)  

bigram_mod_5_3 = gensim.models.phrases.Phraser(bigram_5_3)
trigram_mod_5_3 = gensim.models.phrases.Phraser(trigram_5_3)

#print(trigram_mod[bigram_mod[Lista_general[15]]])

def make_bigrams_5_3(texts):
    return [bigram_mod_5_3[doc] for doc in texts]

def make_trigrams_5_3(texts):
    return [trigram_mod_5_3[bigram_mod_5_3[doc]] for doc in texts]

data_words_bigrams_5_3 = make_bigrams_5_3(Lista_general_5_3)
diccionario_5_3 = Dictionary(data_words_bigrams_5_3)
diccionario_5_3.filter_extremes(no_below=2, no_above = 0.9)
corpus_5_3 = [diccionario_5_3.doc2bow(noticia) for noticia in data_words_bigrams_5_3]

# %%
lda_5_3 = LdaModel(corpus=corpus_5_3, id2word=diccionario_5_3, 
               num_topics=5, random_state=35, 
               chunksize=1000, iterations=200, passes=40, alpha='auto')

# %%
lda_display = pyLDAvis.gensim_models.prepare(lda_5_3, corpus_5_3, diccionario_5_3, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1580824089264944967533931509"></div>
# <script type="text/javascript">
#
# var ldavis_el1580824089264944967533931509_data = {"mdsDat": {"x": [0.16350997289514801, 0.09722355389919875, -0.40728329683436687, 0.07449945808621988, 0.07205031195380028], "y": [-0.33752587851143884, 0.2850758667150457, -0.049170745637795436, 0.05084534848948155, 0.050775408944707064], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [26.547555561449833, 18.789752357647203, 29.832595594612343, 12.296936765205627, 12.533159721084994]}, "tinfo": {"Term": ["pued", "servici", "clar", "plan", "ver", "app", "aplic", "lent", "pud", "si", "funcion", "dej", "inform", "consult", "equip", "hog", "factur", "internet", "clar_hog", "nunc", "llam", "cuent", "ingres", "wifi", "hac", "ningun", "registr", "dat", "mal", "opcion", "servici", "app", "internet", "hac", "mal", "pod", "solucion", "asesor", "busc", "se\u00f1al", "encontr", "pesim", "benefici", "dic", "cambi_numer", "respuest", "telefon", "siempr", "fall", "client", "facil", "da", "problem", "intent", "demor", "pagin", "ten", "respond", "buen", "contest", "clar", "pud", "inform", "hog", "registr", "encuentr", "line", "tecnic", "acced", "product", "nuev", "registr_equip", "recarg", "lleg", "solicit", "clar_vide", "pas", "qued", "se", "muestr", "hor", "dan", "mism", "nombr", "anterior", "contrat", "ped", "mes", "valor", "logr", "clar_play", "pued", "plan", "ver", "dej", "consult", "factur", "clar_hog", "cuent", "ingres", "dat", "opcion", "cambi", "necesit", "aparec", "sal", "movil", "celul", "activ", "numer", "consum", "quier", "sol", "permit", "sab", "sald", "eleg", "mir", "actualiz", "realiz", "consum_dat", "si", "equip", "wifi", "ningun", "entrar", "cancel", "compr", "cambi_clav", "conect", "deb", "ofrec", "sac", "visit_tecnic", "mejor", "cambi_contrase\u00f1", "tv", "solicitud", "cas", "asoci_cuent", "trat", "dos", "pag", "bien", "resuelv", "voy", "meg", "ser", "dese", "impos", "obten", "aplic", "lent", "funcion", "nunc", "llam", "sirv", "carg", "cobr", "averigu", "oper", "tiend", "vec", "revis", "abrir", "cos", "cupon", "sim", "asi", "recib", "abre", "utiliz", "naveg", "proces", "llev", "famili_amig", "cup", "soport", "casi", "peor", "supuest"], "Freq": [717.0, 622.0, 482.0, 600.0, 592.0, 505.0, 267.0, 263.0, 327.0, 255.0, 254.0, 438.0, 310.0, 415.0, 234.0, 290.0, 374.0, 326.0, 351.0, 200.0, 199.0, 345.0, 341.0, 194.0, 304.0, 185.0, 231.0, 314.0, 260.0, 279.0, 621.4698177178151, 504.68985688805174, 325.26475185140225, 303.9745942767173, 259.95078253322237, 226.20821381137299, 198.46689061078305, 154.37500116070674, 154.51991418551788, 152.77837799016456, 148.69524247346575, 130.18915421225722, 128.9326475446007, 222.8950285564507, 117.86273684069161, 109.24893254670498, 106.10208048696829, 100.72046670289929, 96.94378616776031, 93.50734498777462, 89.7417123815588, 87.23047162896418, 80.46150473706919, 80.0344790300095, 77.19551230323412, 76.54694008185892, 71.34235641541979, 70.21077734118239, 66.2018621444456, 65.33889516576234, 482.08775816530107, 326.96718598547955, 309.60381086807047, 289.63572576687983, 230.6927375089702, 177.98847001210981, 151.5300374144917, 133.18956998307502, 132.83080593256437, 132.30914347618165, 127.19315966913165, 107.90035640707649, 106.86254673696831, 106.58420088682487, 89.58298094885762, 88.71755987694165, 78.82641935299854, 65.03834376416457, 61.28593538467262, 60.284117641590086, 58.33023113479955, 58.387358614485805, 58.17811477988806, 57.41272580058209, 57.31599788487935, 56.28725606868963, 54.95979057447534, 51.74251600420797, 50.21540555774592, 49.77595002907872, 49.84659854847763, 716.3641250517035, 599.7751292511001, 591.6688616902488, 437.27190391792254, 415.1759713622794, 373.49235416812996, 350.833515400418, 344.44515508182275, 340.7806833685698, 313.4002128537765, 278.4656324832435, 270.7395070721235, 268.10555092866315, 212.7566369854613, 202.62974872677827, 193.4922950470765, 184.62893815580347, 182.07876120051736, 177.97070156343798, 167.9309057941564, 157.73416210126595, 152.01965428077398, 148.95572827597178, 148.296 ...

# %%
# asignacion topicos
dfc2_5_3['Tópico_5_3_5'] = ""
for i in dfc2_5_3.index:
    try:
        
        bow_comentario = diccionario_5_3.doc2bow(dfc2_5_3.loc[i,'Opinion'])
        distribucion_noticia = lda_5_3[bow_comentario]

        dist_contrib = [topico[1] for topico in lda_5_3[bow_comentario]]

        if (dist_contrib[0] > dist_contrib[1]) & (dist_contrib[0] > dist_contrib[2]) & (dist_contrib[0] > dist_contrib[3]) & (dist_contrib[0] > dist_contrib[4]):
            dfc2_5_3.loc[i,'Tópico_5_3_5'] = 1
        elif (dist_contrib[1] > dist_contrib[0]) & (dist_contrib[1] > dist_contrib[2]) & (dist_contrib[1] > dist_contrib[3]) & (dist_contrib[1] > dist_contrib[4]):
            dfc2_5_3.loc[i,'Tópico_5_3_5'] = 2
        elif (dist_contrib[2] > dist_contrib[0]) & (dist_contrib[2] > dist_contrib[1]) & (dist_contrib[2] > dist_contrib[3]) & (dist_contrib[2] > dist_contrib[4]):
            dfc2_5_3.loc[i,'Tópico_5_3_5'] = 3
        elif (dist_contrib[3] > dist_contrib[0]) & (dist_contrib[3] > dist_contrib[1]) & (dist_contrib[3] > dist_contrib[2]) & (dist_contrib[3] > dist_contrib[4]):
            dfc2_5_3.loc[i,'Tópico_5_3_5'] = 4
        elif (dist_contrib[4] > dist_contrib[0]) & (dist_contrib[4] > dist_contrib[1]) & (dist_contrib[4] > dist_contrib[2]) & (dist_contrib[4] > dist_contrib[3]):
            dfc2_5_3.loc[i,'Tópico_5_3_5'] = 5
    except:
        print('No',str(i))

# %%
dfc2_5_3.Tópico_5_3_5.value_counts()
# Out:
# 3    2236
# 1    1117
# 2     424
# 5     128
# 4      54
# Name: Tópico_5_3_5, dtype: int64

# %%
#import pyLDAvis.gensim_models

lda_display = pyLDAvis.gensim_models.prepare(lda_5_3, corpus_5_3, diccionario_5_3, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el158082408968882096757112047"></div>
# <script type="text/javascript">
#
# var ldavis_el158082408968882096757112047_data = {"mdsDat": {"x": [-0.24061089818291687, -0.0974027063948405, -0.027568467541637994, 0.36558207211939514], "y": [0.287428445152039, -0.3126849897095465, -0.07495528871992573, 0.10021183327743316], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [32.835737274276205, 21.72295417153555, 15.774012305544193, 29.66729624864405]}, "tinfo": {"Term": ["plan", "pued", "clar", "ver", "servici", "app", "dej", "opcion", "cambi", "pud", "necesit", "consult", "inform", "factur", "clar_hog", "cuent", "ingres", "si", "aparec", "dat", "internet", "hog", "hac", "numer", "encuentr", "movil", "lent", "mal", "funcion", "equip", "servici", "app", "dat", "internet", "hac", "mal", "funcion", "pod", "nunc", "llam", "solucion", "activ", "se\u00f1al", "asesor", "busc", "tecnic", "pesim", "benefici", "cambi_numer", "eleg", "respuest", "siempr", "fall", "client", "problem", "intent", "demor", "ten", "respond", "tiend", "aplic", "dic", "pud", "inform", "clar", "si", "movil", "sol", "line", "permit", "sald", "carg", "cobr", "registr_equip", "recarg", "lleg", "actualiz", "telefon", "solicit", "da", "pas", "equip_financi", "qued", "contest", "se", "dan", "mism", "hor", "ped", "deb", "tv", "solucion_problem", "clar_play", "mes", "plan", "opcion", "cambi", "necesit", "aparec", "numer", "encuentr", "sab", "cancel", "facil", "averigu", "nombr", "revis", "contrat", "asoci", "pospag", "valor", "da_opcion", "usuari", "veo", "clav", "netflix", "proces", "pqr", "resuelv", "aplicacion", "impos", "minut", "pon", "atiend", "oper", "quier", "pued", "ver", "dej", "consult", "factur", "clar_hog", "cuent", "ingres", "hog", "lent", "equip", "registr", "sal", "wifi", "ningun", "celul", "consum", "sirv", "entrar", "encontr", "acced", "product", "nuev", "compr", "cambi_clav", "conect", "mir", "realiz", "clar_vide", "consum_dat", "quier"], "Freq": [604.0, 711.0, 487.0, 587.0, 622.0, 505.0, 434.0, 281.0, 273.0, 330.0, 270.0, 412.0, 313.0, 371.0, 348.0, 342.0, 338.0, 263.0, 215.0, 335.0, 326.0, 283.0, 304.0, 180.0, 177.0, 199.0, 248.0, 260.0, 258.0, 233.0, 621.4959973747843, 504.70531051972773, 335.1981040061597, 325.2918117676446, 303.9997826438391, 259.98522988706014, 257.620145921334, 226.23053914322875, 203.4612578178358, 201.797756312182, 198.49404531757182, 194.74950088858196, 152.8153723948633, 154.40353844483383, 154.53660467256415, 140.326021553468, 130.2233535190047, 128.9545030008307, 117.87918162231745, 116.91508098523742, 109.27730744098709, 100.7543395790368, 96.97907921004067, 93.53811246372756, 80.49182627620455, 80.05870981473811, 77.23053692523904, 71.37350100889607, 70.24324667302244, 70.60363799102174, 264.6420051731689, 201.88873193378362, 330.15239424982826, 312.63350512546924, 486.38148831764755, 262.4929034772519, 198.37009693112805, 155.85961868164964, 153.02677300275477, 152.7203990953953, 144.53109377086827, 114.8333894628842, 111.53348657066542, 108.96901604789379, 107.93069945232314, 107.64857380326387, 106.67256884095622, 101.72593850854358, 90.47731724548639, 83.63340610446795, 79.61397545995774, 76.13723333012648, 65.69916592847285, 62.65074985849457, 61.90468329581596, 58.981174118719274, 58.76959244764944, 58.91675144372093, 55.51897591757828, 65.54866444965373, 51.151550095576205, 49.5534986823344, 50.33943090390632, 50.60288029598045, 604.2107676030503, 280.54342552425203, 272.76039376804465, 270.1063319284723, 214.34412894895047, 179.3040723078222, 176.6336592983072, 149.40739713744938, 135.2039867364816, 84.56214011085717, 73.83372351820023, 56.998947911193405, 56.68741015479204, 55.87162963882885, 53.234701072353324, 52.365690615718975, 49.856834047745316, 46.45766253321838, 43.735529042119715, 40.608816196392, 39.38367767552793, 37.340912875256876, 36.442391059606095, 35.204788421475456, 34.663179380219056, 34.477716652265975, 32.92628208848181, 31.377324184685776, 30.70040086972012, 29.717294597948484, 67.8165868316753, 40.82905905160994, 710.738724143595, 587.0259476161162, 433.85226587 ...

# %%
#dfc2_5_3.head()
bow_comentario = diccionario.doc2bow(dfc2_5_3.loc[27,'Opinion'])
bow_comentario
# Out:
# [(9, 3), (15, 1), (229, 1), (337, 2), (381, 1), (502, 1), (671, 1)]

# %%
# asignacion topicos
dfc2_5_3['Tópico_5_3_4'] = ""
for i in dfc2_5_3.index:
    try:
        
        bow_comentario = diccionario_5_3.doc2bow(dfc2_5_3.loc[i,'Opinion'])
        distribucion_noticia = lda_5_3[bow_comentario]

        dist_contrib = [topico[1] for topico in lda_5_3[bow_comentario]]

        if (dist_contrib[0] > dist_contrib[1]) & (dist_contrib[0] > dist_contrib[2]) & (dist_contrib[0] > dist_contrib[3]) :
            dfc2_5_3.loc[i,'Tópico_5_3_4'] = 1
        elif (dist_contrib[1] > dist_contrib[0]) & (dist_contrib[1] > dist_contrib[2]) & (dist_contrib[1] > dist_contrib[3]):
            dfc2_5_3.loc[i,'Tópico_5_3_4'] = 2
        elif (dist_contrib[2] > dist_contrib[0]) & (dist_contrib[2] > dist_contrib[1]) & (dist_contrib[2] > dist_contrib[3]):
            dfc2_5_3.loc[i,'Tópico_5_3_4'] = 3
        elif (dist_contrib[3] > dist_contrib[0]) & (dist_contrib[3] > dist_contrib[1]) & (dist_contrib[3] > dist_contrib[2]):
            dfc2_5_3.loc[i,'Tópico_5_3_4'] = 4
    except:
        print('No',str(i))

# %%
dfc2_5_3.Tópico_5_3_4.value_counts()
# Out:
# 3    2327
# 1    1138
# 2     435
# 4      59
# Name: Tópico_5_3_4, dtype: int64

# %%
dfc2.Tópico_5_3.value_counts()
# Out:
# 5.0    2833
# 1.0     197
# 4.0     146
# 3.0      87
# 2.0      67
# Name: Tópico_5_3, dtype: int64

# %% [markdown]
# ### Plan
# * sumar probabilidades OK
# * quitar pago factura del segundo ejercicio  OK, no es claro el tópico
# * Hacer presentación OK
# * Arreglar código

# %% [markdown]
# ######  fin Zoom

# %%
dfc2
# Out:
#                      RecordedDate Q2_NPS_GROUP Q2  \
# 10     2021-05-01 01:13:29.173000    Detractor  5
# 11     2021-05-01 01:21:26.392000    Detractor  5
# 13     2021-05-01 01:35:12.335000    Detractor  0
# 27     2021-05-01 05:46:19.079000    Detractor  0
# 32     2021-05-01 06:03:56.409000    Detractor  1
# ...                           ...          ... ..
# 48041  2021-08-08 23:05:23.967000    Detractor  5
# 48042  2021-08-08 23:07:34.573000       Pasivo  8
# 48043  2021-08-08 23:08:27.483000    Detractor  1
# 48050  2021-08-08 23:43:19.277000    Detractor  6
# 48052  2021-08-08 23:49:45.987000    Detractor  5
#
#                                                       Q3  \
# 10                           El funcionamiento de la app
# 11                                         Otras razones
# 13                           El funcionamiento de la app
# 27                           El funcionamiento de la app
# 32                        El registro o ingreso a la app
# ...                                                  ...
# 48041                                      Otras razones
# 48042                                      Otras razones
# 48043                        El funcionamiento de la app
# 48050  El registro o ingreso a la app,El funcionamien...
# 48052                        El funcionamiento de la app
#
#                                                       Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                                       Q9  \
# 10                                                   NaN
# 11                                                   NaN
# 13                                                   NaN
# 27                                                   NaN
# 32                                     Por otras razones
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                                NaN
# 48050  La facilidad para registrarte,La facilidad par...
# 48052                                                NaN
#
#                                                     Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q11  \
# 10                    La facilidad para descargar la app
# 11                                                   NaN
# 13                              Rapidez de la aplicación
# 27                                     Por otras razones
# 32                                                   NaN
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                  Por otras razones
# 48050  La facilidad para descargar la app,La facilida...
# 48052                                  Por otras razones
#
#                                                      Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18  ...  \
# 10                                                        ...
# 11                                                        ...
# 13                                                  Nada  ...
# 27     No pide consultar nada acerca de mi línea 3132...  ...
# 32                                                        ...
# ...                                                  ...  ...
# 48041                                                     ...
# 48042  No me aparece factura para el 3102177480 de ag...  ...
# 48043  No pude ver el consumo de mis datos y tampoco ...  ...
# 48050                       No lo entendí bien gracias 😊  ...
# 48052                                                     ...
#
#                                                  Opinion Tópico Segmento App  \
# 10                                          [mal, señal]      1          pre
# 11     [me, cambi, x, mes, oper, regres, nuev, sub, m...      3          pre
# 13     [se, demor, carg, despues, dic, sient, trabaj,...      1          pre
# 27     [no, muestr, line, no, aparec, dat, line, cons...      2          pre
# 32                                               [jjjjj]      2          pre
# ...                                                  ...    ...          ...
# 48041  [llev, vari, mes, trat, den, mejor, preci, pla...      3          pre
# 48042                        [no, aparec, factur, agost]      2          pre
# 48043  [antes, mas, facil, encontr, hac, cos, ya, pue...      2          pre
# 48050                   [bn, no, entend, bien, graci, 😊]      3          pre
# 48052          [es, lent, app, se, demor, entrar, aplic]      2          pre
#
#                  Modulo App                Nombre del cliente App  \
# 10         pre_detalle_plan                    Heyder Mesa Prieto
# 11             pre_elegidos   Maria Elvi Acero           Gonzalez
# 13       pre_consulta_saldo       Jerson Steven Builes Castrillon
# 27       pre_consulta_saldo           Omar Jairo Moreno Hernandez
# 32         pre_detalle_plan                 Robinson Butron Alian
# ...                     ...                                   ...
# 48041  pre_gestionar_equipo             Yeimy Milena Diaz Jimenez
# 48042      pre_detalle_plan                 Paulina Zambrano Diaz
# 48043    pre_consulta_saldo            Maria Paula Cardona Lozano
# 48050          pre_elegidos  Prospero Guillermo Coronado Cantillo
# 48052          pre_elegidos         Freenzen Armando Osorio Tovar
#
#       ID cuenta o Telefono App                     email App Segmento App  \
# 10                  3144597332        heidermesa@hotmail.com          pre
# 11                  3114559290       elviraacero14@gmail.com          pre
# 13                  3117710110           yozmansbc@gmail.com          pre
# 27                  3132339396        prensaenmoto@gmail.com          pre
# 32                  3226216529     solucionesgenco@gmail.com          pre
# ...                        ...                           ...          ...
# 48041               3102624152          mileosanwo@gmail.com          pre
# 48042               3102177480       dentalceramica@yahoo.es          pre
# 48043               3224311507     cardonapaula191@gmail.com          pre
# 48050               3126177396  prosperocoronado30@gmail.com          pre
# 48052               3175080765    osorioeljunior10@gmail.com          pre
#
#       Tema Tópico_5
# 10       1        1
# 11       3        2
# 13       1        1
# 27       2        3
# 32       2        3
# ...    ...      ...
# 48041    3        3
# 48042    2        2
# 48043    2        3
# 48050    3        1
# 48052    2        4
#
# [7131 rows x 21 columns]

# %%
dfc2['RecordedDate'] = df['RecordedDate']
dfc2['Q2_NPS_GROUP'] = df['Q2_NPS_GROUP']
dfc2['Q2'] = df['Q2']
dfc2['Q3'] = df['Q3']
dfc2['Q9'] = df['Q9']
dfc2['Q11'] = df['Q11']
dfc2['Nombre del cliente App'] = df['Nombre del cliente App']
dfc2['ID cuenta o Telefono App'] = df['ID cuenta o Telefono App']
dfc2['email App'] = df['email App']
dfc2['Segmento App'] = df['Segmento App']
dfc2['Modulo App'] = df['Modulo App']
dfc2['Latitud'] = df['LocationLatitude']
dfc2['Longitud'] = df['LocationLongitude']

# %%
dfc2
# Out:
#                      RecordedDate Q2_NPS_GROUP Q2  \
# 10     2021-05-01 01:13:29.173000    Detractor  5
# 11     2021-05-01 01:21:26.392000    Detractor  5
# 13     2021-05-01 01:35:12.335000    Detractor  0
# 27     2021-05-01 05:46:19.079000    Detractor  0
# 32     2021-05-01 06:03:56.409000    Detractor  1
# ...                           ...          ... ..
# 48041  2021-08-08 23:05:23.967000    Detractor  5
# 48042  2021-08-08 23:07:34.573000       Pasivo  8
# 48043  2021-08-08 23:08:27.483000    Detractor  1
# 48050  2021-08-08 23:43:19.277000    Detractor  6
# 48052  2021-08-08 23:49:45.987000    Detractor  5
#
#                                                       Q3  \
# 10                           El funcionamiento de la app
# 11                                         Otras razones
# 13                           El funcionamiento de la app
# 27                           El funcionamiento de la app
# 32                        El registro o ingreso a la app
# ...                                                  ...
# 48041                                      Otras razones
# 48042                                      Otras razones
# 48043                        El funcionamiento de la app
# 48050  El registro o ingreso a la app,El funcionamien...
# 48052                        El funcionamiento de la app
#
#                                                       Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                                       Q9  \
# 10                                                   NaN
# 11                                                   NaN
# 13                                                   NaN
# 27                                                   NaN
# 32                                     Por otras razones
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                                NaN
# 48050  La facilidad para registrarte,La facilidad par...
# 48052                                                NaN
#
#                                                     Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q11  \
# 10                    La facilidad para descargar la app
# 11                                                   NaN
# 13                              Rapidez de la aplicación
# 27                                     Por otras razones
# 32                                                   NaN
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                  Por otras razones
# 48050  La facilidad para descargar la app,La facilida...
# 48052                                  Por otras razones
#
#                                                      Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18  ...  \
# 10                                                        ...
# 11                                                        ...
# 13                                                  Nada  ...
# 27     No pide consultar nada acerca de mi línea 3132...  ...
# 32                                                        ...
# ...                                                  ...  ...
# 48041                                                     ...
# 48042  No me aparece factura para el 3102177480 de ag...  ...
# 48043  No pude ver el consumo de mis datos y tampoco ...  ...
# 48050                       No lo entendí bien gracias 😊  ...
# 48052                                                     ...
#
#                                                  Opinion Tópico Segmento App  \
# 10                                          [mal, señal]      1          pre
# 11     [me, cambi, x, mes, oper, regres, nuev, sub, m...      3          pre
# 13     [se, demor, carg, despues, dic, sient, trabaj,...      1          pre
# 27     [no, muestr, line, no, aparec, dat, line, cons...      2          pre
# 32                                               [jjjjj]      2          pre
# ...                                                  ...    ...          ...
# 48041  [llev, vari, mes, trat, den, mejor, preci, pla...      3          pre
# 48042                        [no, aparec, factur, agost]      2          pre
# 48043  [antes, mas, facil, encontr, hac, cos, ya, pue...      2          pre
# 48050                   [bn, no, entend, bien, graci, 😊]      3          pre
# 48052          [es, lent, app, se, demor, entrar, aplic]      2          pre
#
#                  Modulo App                Nombre del cliente App  \
# 10         pre_detalle_plan                    Heyder Mesa Prieto
# 11             pre_elegidos   Maria Elvi Acero           Gonzalez
# 13       pre_consulta_saldo       Jerson Steven Builes Castrillon
# 27       pre_consulta_saldo           Omar Jairo Moreno Hernandez
# 32         pre_detalle_plan                 Robinson Butron Alian
# ...                     ...                                   ...
# 48041  pre_gestionar_equipo             Yeimy Milena Diaz Jimenez
# 48042      pre_detalle_plan                 Paulina Zambrano Diaz
# 48043    pre_consulta_saldo            Maria Paula Cardona Lozano
# 48050          pre_elegidos  Prospero Guillermo Coronado Cantillo
# 48052          pre_elegidos         Freenzen Armando Osorio Tovar
#
#       ID cuenta o Telefono App                     email App Segmento App  \
# 10                  3144597332        heidermesa@hotmail.com          pre
# 11                  3114559290       elviraacero14@gmail.com          pre
# 13                  3117710110           yozmansbc@gmail.com          pre
# 27                  3132339396        prensaenmoto@gmail.com          pre
# 32                  3226216529     solucionesgenco@gmail.com          pre
# ...                        ...                           ...          ...
# 48041               3102624152          mileosanwo@gmail.com          pre
# 48042               3102177480       dentalceramica@yahoo.es          pre
# 48043               3224311507     cardonapaula191@gmail.com          pre
# 48050               3126177396  prosperocoronado30@gmail.com          pre
# 48052               3175080765    osorioeljunior10@gmail.com          pre
#
#       Tema Tópico_5
# 10       1        1
# 11       3        2
# 13       1        1
# 27       2        3
# 32       2        3
# ...    ...      ...
# 48041    3        3
# 48042    2        2
# 48043    2        3
# 48050    3        1
# 48052    2        4
#
# [7131 rows x 21 columns]

# %%
lista_ordenada = ['RecordedDate', 'Q2_NPS_GROUP', 'Q2', 'Q3', 'Q4', 'Q9', 'Q12', 'Q11', 'Q15', 'Q18', 'Q20', 'Opinion', 'Tópico', 'Segmento App', 'Modulo App', 'Nombre del cliente App', 'ID cuenta o Telefono App', 'email App', 'Segmento App']
dfc2 = dfc2[lista_ordenada]
dfc2
# Out:
#                      RecordedDate Q2_NPS_GROUP Q2  \
# 10     2021-05-01 01:13:29.173000    Detractor  5
# 11     2021-05-01 01:21:26.392000    Detractor  5
# 13     2021-05-01 01:35:12.335000    Detractor  0
# 27     2021-05-01 05:46:19.079000    Detractor  0
# 32     2021-05-01 06:03:56.409000    Detractor  1
# ...                           ...          ... ..
# 48041  2021-08-08 23:05:23.967000    Detractor  5
# 48042  2021-08-08 23:07:34.573000       Pasivo  8
# 48043  2021-08-08 23:08:27.483000    Detractor  1
# 48050  2021-08-08 23:43:19.277000    Detractor  6
# 48052  2021-08-08 23:49:45.987000    Detractor  5
#
#                                                       Q3  \
# 10                           El funcionamiento de la app
# 11                                         Otras razones
# 13                           El funcionamiento de la app
# 27                           El funcionamiento de la app
# 32                        El registro o ingreso a la app
# ...                                                  ...
# 48041                                      Otras razones
# 48042                                      Otras razones
# 48043                        El funcionamiento de la app
# 48050  El registro o ingreso a la app,El funcionamien...
# 48052                        El funcionamiento de la app
#
#                                                       Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                                       Q9  \
# 10                                                   NaN
# 11                                                   NaN
# 13                                                   NaN
# 27                                                   NaN
# 32                                     Por otras razones
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                                NaN
# 48050  La facilidad para registrarte,La facilidad par...
# 48052                                                NaN
#
#                                                     Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q11  \
# 10                    La facilidad para descargar la app
# 11                                                   NaN
# 13                              Rapidez de la aplicación
# 27                                     Por otras razones
# 32                                                   NaN
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                  Por otras razones
# 48050  La facilidad para descargar la app,La facilida...
# 48052                                  Por otras razones
#
#                                                      Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18 Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...  ..
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                  Opinion Tópico Segmento App  \
# 10                                          [mal, señal]      1          pre
# 11     [me, cambi, x, mes, oper, regres, nuev, sub, m...      3          pre
# 13     [se, demor, carg, despues, dic, sient, trabaj,...      1          pre
# 27     [no, muestr, line, no, aparec, dat, line, cons...      2          pre
# 32                                               [jjjjj]      2          pre
# ...                                                  ...    ...          ...
# 48041  [llev, vari, mes, trat, den, mejor, preci, pla...      3          pre
# 48042                        [no, aparec, factur, agost]      2          pre
# 48043  [antes, mas, facil, encontr, hac, cos, ya, pue...      2          pre
# 48050                   [bn, no, entend, bien, graci, 😊]      3          pre
# 48052          [es, lent, app, se, demor, entrar, aplic]      2          pre
#
#                  Modulo App                Nombre del cliente App  \
# 10         pre_detalle_plan                    Heyder Mesa Prieto
# 11             pre_elegidos   Maria Elvi Acero           Gonzalez
# 13       pre_consulta_saldo       Jerson Steven Builes Castrillon
# 27       pre_consulta_saldo           Omar Jairo Moreno Hernandez
# 32         pre_detalle_plan                 Robinson Butron Alian
# ...                     ...                                   ...
# 48041  pre_gestionar_equipo             Yeimy Milena Diaz Jimenez
# 48042      pre_detalle_plan                 Paulina Zambrano Diaz
# 48043    pre_consulta_saldo            Maria Paula Cardona Lozano
# 48050          pre_elegidos  Prospero Guillermo Coronado Cantillo
# 48052          pre_elegidos         Freenzen Armando Osorio Tovar
#
#       ID cuenta o Telefono App                     email App Segmento App
# 10                  3144597332        heidermesa@hotmail.com          pre
# 11                  3114559290       elviraacero14@gmail.com          pre
# 13                  3117710110           yozmansbc@gmail.com          pre
# 27                  3132339396        prensaenmoto@gmail.com          pre
# 32                  3226216529     solucionesgenco@gmail.com          pre
# ...                        ...                           ...          ...
# 48041               3102624152          mileosanwo@gmail.com          pre
# 48042               3102177480       dentalceramica@yahoo.es          pre
# 48043               3224311507     cardonapaula191@gmail.com          pre
# 48050               3126177396  prosperocoronado30@gmail.com          pre
# 48052               3175080765    osorioeljunior10@gmail.com          pre
#
# [7131 rows x 19 columns]

# %%
dfc2['Tema'] = dfc2['Tópico']

# %%
dfc2
# Out:
#                      RecordedDate Q2_NPS_GROUP Q2  \
# 10     2021-05-01 01:13:29.173000    Detractor  5
# 11     2021-05-01 01:21:26.392000    Detractor  5
# 13     2021-05-01 01:35:12.335000    Detractor  0
# 27     2021-05-01 05:46:19.079000    Detractor  0
# 32     2021-05-01 06:03:56.409000    Detractor  1
# ...                           ...          ... ..
# 48041  2021-08-08 23:05:23.967000    Detractor  5
# 48042  2021-08-08 23:07:34.573000       Pasivo  8
# 48043  2021-08-08 23:08:27.483000    Detractor  1
# 48050  2021-08-08 23:43:19.277000    Detractor  6
# 48052  2021-08-08 23:49:45.987000    Detractor  5
#
#                                                       Q3  \
# 10                           El funcionamiento de la app
# 11                                         Otras razones
# 13                           El funcionamiento de la app
# 27                           El funcionamiento de la app
# 32                        El registro o ingreso a la app
# ...                                                  ...
# 48041                                      Otras razones
# 48042                                      Otras razones
# 48043                        El funcionamiento de la app
# 48050  El registro o ingreso a la app,El funcionamien...
# 48052                        El funcionamiento de la app
#
#                                                       Q4  \
# 10
# 11     Tengo bastante tiempo con ustedes y me le subi...
# 13
# 27
# 32
# ...                                                  ...
# 48041  Los planes versus la competencia son muy costo...
# 48042       No aparece factura de agosto para 3102177480
# 48043
# 48050
# 48052
#
#                                                       Q9  \
# 10                                                   NaN
# 11                                                   NaN
# 13                                                   NaN
# 27                                                   NaN
# 32                                     Por otras razones
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                                NaN
# 48050  La facilidad para registrarte,La facilidad par...
# 48052                                                NaN
#
#                                                     Q12  \
# 10
# 11
# 13
# 27                                  No muestra mi linea
# 32
# ...                                                 ...
# 48041
# 48042
# 48043  Antes era mas facil encontrar y hacer las cosas
# 48050
# 48052                           Es un poco lenta la app
#
#                                                      Q11  \
# 10                    La facilidad para descargar la app
# 11                                                   NaN
# 13                              Rapidez de la aplicación
# 27                                     Por otras razones
# 32                                                   NaN
# ...                                                  ...
# 48041                                                NaN
# 48042                                                NaN
# 48043                                  Por otras razones
# 48050  La facilidad para descargar la app,La facilida...
# 48052                                  Por otras razones
#
#                                                      Q15  \
# 10                                            Mala señal
# 11     Me cambié x un mes a otro operador y me regres...
# 13     Se demora para cargar y después dice lo siente...
# 27     No aparecen datos de mi línea consultada 31323...
# 32                                                 Jjjjj
# ...                                                  ...
# 48041  Llevo varios meses tratando de que me den un m...
# 48042
# 48043  Ya no se puede pagar la factura y tampoco se p...
# 48050                                                Bn
# 48052        Se demora un poco al entrar a la aplicación
#
#                                                      Q18 Q20  \
# 10
# 11
# 13                                                  Nada
# 27     No pide consultar nada acerca de mi línea 3132...
# 32
# ...                                                  ...  ..
# 48041
# 48042  No me aparece factura para el 3102177480 de ag...
# 48043  No pude ver el consumo de mis datos y tampoco ...
# 48050                       No lo entendí bien gracias 😊
# 48052
#
#                                                  Opinion Tópico Segmento App  \
# 10                                          [mal, señal]      1          pre
# 11     [me, cambi, x, mes, oper, regres, nuev, sub, m...      3          pre
# 13     [se, demor, carg, despues, dic, sient, trabaj,...      1          pre
# 27     [no, muestr, line, no, aparec, dat, line, cons...      2          pre
# 32                                               [jjjjj]      2          pre
# ...                                                  ...    ...          ...
# 48041  [llev, vari, mes, trat, den, mejor, preci, pla...      3          pre
# 48042                        [no, aparec, factur, agost]      2          pre
# 48043  [antes, mas, facil, encontr, hac, cos, ya, pue...      2          pre
# 48050                   [bn, no, entend, bien, graci, 😊]      3          pre
# 48052          [es, lent, app, se, demor, entrar, aplic]      2          pre
#
#                  Modulo App                Nombre del cliente App  \
# 10         pre_detalle_plan                    Heyder Mesa Prieto
# 11             pre_elegidos   Maria Elvi Acero           Gonzalez
# 13       pre_consulta_saldo       Jerson Steven Builes Castrillon
# 27       pre_consulta_saldo           Omar Jairo Moreno Hernandez
# 32         pre_detalle_plan                 Robinson Butron Alian
# ...                     ...                                   ...
# 48041  pre_gestionar_equipo             Yeimy Milena Diaz Jimenez
# 48042      pre_detalle_plan                 Paulina Zambrano Diaz
# 48043    pre_consulta_saldo            Maria Paula Cardona Lozano
# 48050          pre_elegidos  Prospero Guillermo Coronado Cantillo
# 48052          pre_elegidos         Freenzen Armando Osorio Tovar
#
#       ID cuenta o Telefono App                     email App Segmento App Tema
# 10                  3144597332        heidermesa@hotmail.com          pre    1
# 11                  3114559290       elviraacero14@gmail.com          pre    3
# 13                  3117710110           yozmansbc@gmail.com          pre    1
# 27                  3132339396        prensaenmoto@gmail.com          pre    2
# 32                  3226216529     solucionesgenco@gmail.com          pre    2
# ...                        ...                           ...          ...  ...
# 48041               3102624152          mileosanwo@gmail.com          pre    3
# 48042               3102177480       dentalceramica@yahoo.es          pre    2
# 48043               3224311507     cardonapaula191@gmail.com          pre    2
# 48050               3126177396  prosperocoronado30@gmail.com          pre    3
# 48052               3175080765    osorioeljunior10@gmail.com          pre    2
#
# [7131 rows x 20 columns]

# %%
dfc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7131 entries, 10 to 48052
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   RecordedDate              7131 non-null   object
#  1   Q2_NPS_GROUP              7054 non-null   object
#  2   Q2                        7054 non-null   object
#  3   Q3                        6963 non-null   object
#  4   Q4                        7131 non-null   object
#  5   Q9                        1574 non-null   object
#  6   Q12                       7131 non-null   object
#  7   Q11                       4263 non-null   object
#  8   Q15                       7131 non-null   object
#  9   Q18                       7131 non-null   object
#  10  Q20                       7131 non-null   object
#  11  Opinion                   7131 non-null   object
#  12  Tópico                    7131 non-null   object
#  13  Segmento App              7008 non-null   object
#  14  Modulo App                7131 non-null   object
#  15  Nombre del cliente App    7130 non-null   object
#  16  ID cuenta o Telefono App  6684 non-null   object
#  17  email App                 7126 non-null   object
#  18  Segmento App              7008 non-null   object
#  19  Tema                      7131 non-null   object
# dtypes: object(20)
# memory usage: 1.4+ MB

# %%
dfc2.to_csv('Modelamiento_Topicos_General_Consolidado_CI_6.csv', index=False, sep=';')

# %% [markdown]
# #### Tabla Total

# %%
TablaFinal=df.copy()
TablaFinal['Sent_Q4']=dfSent["Sent_Q4"] 
TablaFinal['Sent_Q10']=dfSent["Sent_Q10"]
TablaFinal['Sent_Q12']=dfSent["Sent_Q12"] 
TablaFinal['Sent_Q15']=dfSent["Sent_Q15"] 
TablaFinal['Sent_Q18']=dfSent["Sent_Q18"] 
TablaFinal['Sent_Q20']=dfSent["Sent_Q20"]
TablaFinal['Opinion']=dfc2['Opinion']
TablaFinal['Topico_4']=dfc2['Tópico']
TablaFinal['Topico_5']=dfc2['Tópico_5']

# %%
TablaFinal.to_csv('TablaFinal.csv', index=False, sep=';')
